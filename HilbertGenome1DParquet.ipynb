# %%
import os
import json
import gzip
import time
import math
import hilbert
import pyarrow
import pandas as pd
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# ## Prepare the signal data

# %%
chromosomes_to_exclude = ['chrY']

# %%
# setup the data directory if it doesn't already exist
data_dir = 'hilbert_genome_cooler_data'
if not os.path.exists(data_dir): 
    os.makedirs(data_dir)

# %%
# setup the data directory if it doesn't already exist
parquet_data_dir = 'hilbert_genome_cooler_data/parquet_data'
if not os.path.exists(parquet_data_dir): 
    os.makedirs(parquet_data_dir)

# %%
signal_categories = 18
input_signal_NA_category_value = signal_categories - 1

# %%
# Get the data file and store it locally
#
# ref. /net/seq/data/projects/Epilogos
#          /multivec-for-browser-2022-redo/epilogos_tracks/single/human
#          /Boix_et_al_833_sample/hg19/18/All_833_biosamples/S1/scores.txt.filledGap.versionSorted.txt.gz
#
signal_remote_URI = 'https://resources.altius.org/~areynolds/public/Boix_et_al_833_sample.hg19.18.All_833_biosamples.S1.scores.txt.gz'
signal_local_fn = os.path.join(data_dir, 'Boix_et_al_833_sample.hg19.18.All_833_biosamples.S1.scores.txt.gz')

# %%
if not os.path.exists(signal_local_fn):
    try:
        r = requests.get(signal_remote_URI)
        with open(signal_local_fn, "wb") as ofh:
            b = io.BytesIO(r.content)
            ofh.write(b.getbuffer())
    except requests.exceptions.RequestException as e:
        raise SystemExit(e)

# %%
input_signal_dir = os.path.split(os.path.abspath(signal_local_fn))[0]

# %%
def generate_categorical_data(ifn):
    signals = {}
    signals['__all'] = []
    with gzip.open(ifn, 'rb') as ifh:
        for line in ifh:
            elems = line.decode().rstrip().split('\t')
            chromosome = elems[0]
            signal = np.array([float(x) for x in elems[3:]])
            if chromosome not in signals:
                signals[chromosome] = []
            if chromosome not in chromosomes_to_exclude:
                signals[chromosome].append({'argmax': np.argmax(signal), 'sum': np.sum(signal)})
                signals['__all'].append({'argmax': np.argmax(signal), 'sum': np.sum(signal)})
            else:
                signals[chromosome].append({'argmax': input_signal_NA_category_value, 'sum': 0})
                signals['__all'].append({'argmax': input_signal_NA_category_value, 'sum': 0})
    return signals

# %%
def generate_categorical_data_file(ofn, categorical_data):
    with gzip.open(ofn, 'wb') as ofh:
        categorical_data_json = json.dumps(categorical_data, cls=NumpyEncoder)
        ofh.write(categorical_data_json.encode())

# %%
class NumpyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        if isinstance(obj, np.bool_):
            return bool(obj)
        return super(NumpyEncoder, self).default(obj)

# %%
categorical_data_fn = os.path.join(data_dir,'{}.categorical_data.json.gz'.format(os.path.basename(signal_local_fn)))

# %%
if not os.path.exists(categorical_data_fn):
    categorical_data = generate_categorical_data(signal_local_fn)
    generate_categorical_data_file(categorical_data_fn, categorical_data)
else:
    with gzip.open(categorical_data_fn, 'rb') as ifh:
        categorical_data = json.load(ifh)

# %% [markdown]
# ## Hilbert Genome

# %%
import hilbertgenome.chromsizes

# %%
genome = hilbertgenome.chromsizes["hg38"]

# %%
genome.total_size
# Out:
# 3088269832

# %%
maxOrder = 16 # 16 is the order that can contain the full genome

# %%
pow(4, maxOrder)
# Out:
# 4294967296

# %%
# convert a hilbert position from one order to another
def hilbert_pos_to_order(pos, fro, to):
    return math.floor(pos / pow(4, fro - to))

# %%
# spread our genome positions evenly across the 16th order hilbert curve
def spread_scale(gpos):
    i_min = 0
    i_max = genome.total_size
    o_min = 0
    o_max = pow(4, maxOrder)
    return round(o_min + (gpos - i_min) * ((o_max - o_min) / (i_max - i_min)))

# %%
# get the genome position for a given hilbert position (may return duplicates)
def spread_scale_invert(pos):
    i_min = 0
    i_max = genome.total_size
    o_min = 0
    o_max = pow(4, maxOrder)
    return round((pos - o_min) / ((o_max - o_min) / (i_max - i_min)) + i_min)

# %%
# get the global genome position from something like "chr2:12345"
def get_genome_from_base(start):
    chr = start.split(":")[0]
    offset = int(start.split(":")[1])
    return genome.sizes_acc[chr] + offset

# %%
def get_hilbert_from_genome(gpos):
    return spread_scale(gpos)

# %%
def get_genome_from_hilbert(pos):
  gpos = spread_scale_invert(pos)
  if pos != spread_scale(gpos): 
    return None
  return gpos;

# %%
# get the first base at the maximum order resolution 
# that comes after the starting pos and before the next pos at the current order
def scan_spread(pos, order):
  if(order == maxOrder):
    return get_genome_from_hilbert(pos)
  start = hilbert_pos_to_order(pos, order, maxOrder)
  found = get_genome_from_hilbert(start)
  # need to scan everything at the highest order
  # but only until we find something which should usually happen in a few loops
  for l in range(pow(4, maxOrder - order)):
    if found is not None:
        return found
    found = get_genome_from_hilbert(start+l)

# %%
# get the last base at the maximum order resolution 
# that comes after the starting pos and before the next pos at the current order
def scan_spread_reverse(pos, order):
  start = hilbert_pos_to_order(pos+1, order, maxOrder) - 1
  found = get_genome_from_hilbert(start)
  # need to scan everything at the highest order
  # but only until we find something which should usually happen in a few loops
  for l in range(pow(4, maxOrder - order)):
    if found is not None:
        return found
    found = get_genome_from_hilbert(start-l)

# %% [markdown]
# ## Aggregation

# %%
#find_maxvecsum_label = lambda x: x[np.argmax(np.array([i['sum'] for i in x]))]['argmax']
def aggregate(data):
    return data[np.argmax(np.array([i['sum'] for i in data]))]['argmax']

# %%
def accessor(d):
    return d["argmax"]

# %%
signal_resolution = 200

# %%
def aggregate_chromosome(chromosome, order):
    start_time = time.time()
    
    samples = categorical_data[chromosome]
    nsamples = len(samples)
    print("samples", nsamples)
    # sample resolution 
    sr = signal_resolution
    
    gstart = genome.sizes_acc[chromosome]
    gstop = genome.sizes_acc[chromosome] + genome.sizes[chromosome]
    hbstart = get_hilbert_from_genome(gstart)
    hbstop = get_hilbert_from_genome(gstop)
    
    # TODO: break this up into pieces for the highest orders
    hstart = hilbert_pos_to_order(hbstart, 16, order)
    hstop = hilbert_pos_to_order(hbstop, 16, order)
    
    print("chromosome", chromosome, "order", order)
    print("genome", gstart, gstop)
    print("hilbert", hstart, hstop)
    print("length", hstop - hstart)

    # if there are more hilbert indices than samples we dont need to aggregate
    individual = (hstop - hstart) / len(samples) > 1
    print("individual", individual)
    
    #hp = Hilbert(order, hstart, hstop)
    hp = np.arange(hstart, hstop)
    v = np.arange(hstart, hstop)
    # loop over the hilbert points for this order
    # can get bounds in genome position
    for i, pos in enumerate(hp):
        # global genome pos
        gpos = scan_spread(pos, order)          
        # at order 16 we may get None values for individual hilbert coordinates
        if(gpos is None):
            v[i] = input_signal_NA_category_value
            continue
        
        # local position
        lpos = gpos - gstart                    
        if(lpos < 0): 
            lpos = 0
        
        # the starting index in our sample
        datum_idx = round(lpos/sr)              
        
        if individual:
            # we have a single point, this will happen for higher orders
            # print("single data",  pos, lpos, slpos, datum_idx)
            if datum_idx >= nsamples:
                v[i] = input_signal_NA_category_value
                #print(i,pos,datum_idx)
            else:
                v[i] = accessor(samples[datum_idx])
        else:
            # we know multiple samples will fit in our hilbert cell
            # so we get the last genome pos in the hilbert cell
            sgpos = scan_spread_reverse(pos, order) # global genome pos           
            slpos = sgpos - gstart                  # local position
            sdatum_idx = round(slpos/sr)            #the ending index in our samples
            # we need to aggregate at lower orders
            # we grab all the samples from the starting index to the ending index
            data = samples[datum_idx:sdatum_idx+1]  # include the last sample
            # if there are no samples in our list, we save NA
            if(len(data) == 0):
                #print("aggregate data", pos, gpos, lpos, slpos, datum_idx, sdatum_idx, len(data))
                v[i] = input_signal_NA_category_value
            else:
                # we save the output of the user supplied aggregate function
                v[i] = aggregate(data)

    # can convert genome position bounds to sample index range (multiple of 200)
    # collect the datapoints that have the same point
    print("done in: %s" % (time.time() - start_time))
    return [hp,v]

# %%
agg1 = aggregate_chromosome("chr1", 11)
# Out:
# samples 1246254
# chromosome chr1 order 11
# genome 0 248956422
# hilbert 0 338117
# length 338117
# individual False
# done in: 2.274808883666992

# %%
agg1
# Out:
# [array([     0,      1,      2, ..., 338114, 338115, 338116]),
#  array([17, 17, 17, ..., 17, 17, 17])]

# %%
pq.write_table(pa.table({
    # "index": agg1[0], 
    "value": agg1[1]
}), "test_chr1_13.parquet", compression='gzip')

# %% [markdown]
# ## Generate parquet files

# %%
def write_parquet(chromosome, order):
    pfn = os.path.join(parquet_data_dir, chromosome + "_" + str(order) + ".parquet")
    agg = aggregate_chromosome(chromosome, order)
    table = {
        "index": agg[0], 
        "value": agg[1],
    }
    pq.write_table(
        pa.table(table), 
        pfn, 
        compression='gzip',
    )

# %%
from hilbertgenome.coalesce import coalesce_parquets

# %%
def combine(order):
    paths = [os.path.join(parquet_data_dir, (c + "_" + str(order) + ".parquet")) for c in genome.chromosomes]
    print(paths)
    coalesce_parquets(paths, os.path.join(parquet_data_dir,"order_" + str(order) + ".parquet"))

# %%
for o in range(5, 14):
    for c in genome.chromosomes:
        write_parquet(c, o)
    combine(o)
# Out:
# samples 1246254
# chromosome chr1 order 5
# genome 0 248956422
# hilbert 0 82
# length 82
# individual False
# done in: 0.13564395904541016
# samples 1215997
# chromosome chr2 order 5
# genome 248956422 491149951
# hilbert 82 162
# length 80
# individual False
# done in: 0.17184996604919434
# samples 990113
# chromosome chr3 order 5
# genome 491149951 689445510
# hilbert 162 228
# length 66
# individual False
# done in: 0.1242990493774414
# samples 955772
# chromosome chr4 order 5
# genome 689445510 879660065
# hilbert 228 291
# length 63
# individual False
# done in: 0.13890933990478516
# samples 904577
# chromosome chr5 order 5
# genome 879660065 1061198324
# hilbert 291 351
# length 60
# individual False
# done in: 0.11014986038208008
# samples 855576
# chromosome chr6 order 5
# genome 1061198324 1232004303
# hilbert 351 408
# length 57
# individual False
# done in: 0.14290785789489746
# samples 795694
# chromosome chr7 order 5
# genome 1232004303 1391350276
# hilbert 408 461
# length 53
# individual False
# done in: 0.11730718612670898
# samples 731821
# chromosome chr8 order 5
# genome 1391350276 1536488912
# hilbert 461 509
# length 48
# individual False
# done in: 0.09004068374633789
# samples 706068
# chromosome chr9 order 5
# genome 1536488912 1674883629
# hilbert 509 555
# length 46
# individual False
# done in: 0.10235977172851562
# samples 677674
# chromosome chr10 order 5
# genome 1674883629 1808681051
# hilbert 555 599
# length 44
# individual False
# done in: 0.11961698532104492
# samples 675033
# chromosome chr11 order 5
# genome 1808681051 1943767673
# hilbert 599 644
# length 45
# individual False
# done in: 0.16165471076965332
# samples 669260
# chromosome chr12 order 5
# genome 1943767673 2077042982
# hilbert 644 688
# length 44
# individual False
# done in: 0.10389900207519531
# samples 575850
# chromosome chr13 order 5
# genome 2077042982 2191407310
# hilbert 688 726
# length 38
# individual False
# done in: 0.0969541072845459
# samples 536748
# chromosome chr14 order 5
# genome 2191407310 2298451028
# hilbert 726 762
# length 36
# individual False
# done in: 0.09166908264160156
# samples 512657
# chromosome chr15 order 5
# genome 2298451028 2400442217
# hilbert 762 795
# length 33
# individual False
# done in: 0.06847000122070312
# samples 451774
# chromosome chr16 order 5
# genome 2400442217 2490780562
# hilbert 795 825
# length 30
# individual False
# done in: 0.06369996070861816
# samples 405977
# chromosome chr17 order 5
# genome 2490780562 2574038003
# hilbert 825 853
# length 28
# individual False
# done in: 0.06477785110473633
# samples 390387
# chromosome chr18 order 5
# genome 2574038003 2654411288
# hilbert 853 880
# length 27
# individual False
# done in: 0.058920860290527344
# samples 295645
# chromosome chr19 order 5
# genome 2654411288 2713028904
# hilbert 880 899
# length 19
# individual False
# done in: 0.038823843002319336
# samples 315128
# chromosome chr20 order 5
# genome 2713028904 2777473071
# hilbert 899 920
# length 21
# individual False
# done in: 0.05769920349121094
# samples 240650
# chromosome chr21 order 5
# genome 2777473071 2824183054
# hilbert 920 936
# length 16
# individual False
# done in: 0.034349679946899414
# samples 256523
# chromosome chr22 order 5
# genome 2824183054 2875001522
# hilbert 936 953
# length 17
# individual False
# done in: 0.04103708267211914
# samples 776353
# chromosome chrX order 5
# genome 2875001522 3031042417
# hilbert 953 1005
# length 52
# individual False
# done in: 0.15031194686889648
# samples 296868
# chromosome chrY order 5
# genome 3031042417 3088269832
# hilbert 1005 1024
# length 19
# individual False
# done in: 0.04276895523071289
# ['hilbert_genome_cooler_data/parquet_data/chr1_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_5.parquet']
# samples 1246254
# chromosome chr1 order 6
# genome 0 248956422
# hilbert 0 330
# length 330
# individual False
# done in: 0.07532811164855957
# samples 1215997
# chromosome chr2 order 6
# genome 248956422 491149951
# hilbert 330 651
# length 321
# individual False
# done in: 0.07687091827392578
# samples 990113
# chromosome chr3 order 6
# genome 491149951 689445510
# hilbert 651 914
# length 263
# individual False
# done in: 0.06144118309020996
# samples 955772
# chromosome chr4 order 6
# genome 689445510 879660065
# hilbert 914 1166
# length 252
# individual False
# done in: 0.05797934532165527
# samples 904577
# chromosome chr5 order 6
# genome 879660065 1061198324
# hilbert 1166 1407
# length 241
# individual False
# done in: 0.055237770080566406
# samples 855576
# chromosome chr6 order 6
# genome 1061198324 1232004303
# hilbert 1407 1634
# length 227
# individual False
# done in: 0.0518341064453125
# samples 795694
# chromosome chr7 order 6
# genome 1232004303 1391350276
# hilbert 1634 1845
# length 211
# individual False
# done in: 0.04829812049865723
# samples 731821
# chromosome chr8 order 6
# genome 1391350276 1536488912
# hilbert 1845 2037
# length 192
# individual False
# done in: 0.04352116584777832
# samples 706068
# chromosome chr9 order 6
# genome 1536488912 1674883629
# hilbert 2037 2221
# length 184
# individual False
# done in: 0.04165792465209961
# samples 677674
# chromosome chr10 order 6
# genome 1674883629 1808681051
# hilbert 2221 2398
# length 177
# individual False
# done in: 0.04278898239135742
# samples 675033
# chromosome chr11 order 6
# genome 1808681051 1943767673
# hilbert 2398 2578
# length 180
# individual False
# done in: 0.04138326644897461
# samples 669260
# chromosome chr12 order 6
# genome 1943767673 2077042982
# hilbert 2578 2754
# length 176
# individual False
# done in: 0.040566205978393555
# samples 575850
# chromosome chr13 order 6
# genome 2077042982 2191407310
# hilbert 2754 2906
# length 152
# individual False
# done in: 0.03586006164550781
# samples 536748
# chromosome chr14 order 6
# genome 2191407310 2298451028
# hilbert 2906 3048
# length 142
# individual False
# done in: 0.03313422203063965
# samples 512657
# chromosome chr15 order 6
# genome 2298451028 2400442217
# hilbert 3048 3183
# length 135
# individual False
# done in: 0.03188610076904297
# samples 451774
# chromosome chr16 order 6
# genome 2400442217 2490780562
# hilbert 3183 3303
# length 120
# individual False
# done in: 0.028306961059570312
# samples 405977
# chromosome chr17 order 6
# genome 2490780562 2574038003
# hilbert 3303 3413
# length 110
# individual False
# done in: 0.024227142333984375
# samples 390387
# chromosome chr18 order 6
# genome 2574038003 2654411288
# hilbert 3413 3520
# length 107
# individual False
# done in: 0.023530006408691406
# samples 295645
# chromosome chr19 order 6
# genome 2654411288 2713028904
# hilbert 3520 3598
# length 78
# individual False
# done in: 0.01926398277282715
# samples 315128
# chromosome chr20 order 6
# genome 2713028904 2777473071
# hilbert 3598 3683
# length 85
# individual False
# done in: 0.0207521915435791
# samples 240650
# chromosome chr21 order 6
# genome 2777473071 2824183054
# hilbert 3683 3745
# length 62
# individual False
# done in: 0.015601158142089844
# samples 256523
# chromosome chr22 order 6
# genome 2824183054 2875001522
# hilbert 3745 3813
# length 68
# individual False
# done in: 0.01596212387084961
# samples 776353
# chromosome chrX order 6
# genome 2875001522 3031042417
# hilbert 3813 4020
# length 207
# individual False
# done in: 0.04816293716430664
# samples 296868
# chromosome chrY order 6
# genome 3031042417 3088269832
# hilbert 4020 4096
# length 76
# individual False
# done in: 0.017889976501464844
# ['hilbert_genome_cooler_data/parquet_data/chr1_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_6.parquet']
# samples 1246254
# chromosome chr1 order 7
# genome 0 248956422
# hilbert 0 1320
# length 1320
# individual False
# done in: 0.0827629566192627
# samples 1215997
# chromosome chr2 order 7
# genome 248956422 491149951
# hilbert 1320 2605
# length 1285
# individual False
# done in: 0.08306503295898438
# samples 990113
# chromosome chr3 order 7
# genome 491149951 689445510
# hilbert 2605 3657
# length 1052
# individual False
# done in: 0.06848311424255371
# samples 955772
# chromosome chr4 order 7
# genome 689445510 879660065
# hilbert 3657 4666
# length 1009
# individual False
# done in: 0.06404399871826172
# samples 904577
# chromosome chr5 order 7
# genome 879660065 1061198324
# hilbert 4666 5629
# length 963
# individual False
# done in: 0.06011486053466797
# samples 855576
# chromosome chr6 order 7
# genome 1061198324 1232004303
# hilbert 5629 6536
# length 907
# individual False
# done in: 0.05943870544433594
# samples 795694
# chromosome chr7 order 7
# genome 1232004303 1391350276
# hilbert 6536 7381
# length 845
# individual False
# done in: 0.056982994079589844
# samples 731821
# chromosome chr8 order 7
# genome 1391350276 1536488912
# hilbert 7381 8151
# length 770
# individual False
# done in: 0.050755977630615234
# samples 706068
# chromosome chr9 order 7
# genome 1536488912 1674883629
# hilbert 8151 8885
# length 734
# individual False
# done in: 0.04601168632507324
# samples 677674
# chromosome chr10 order 7
# genome 1674883629 1808681051
# hilbert 8885 9595
# length 710
# individual False
# done in: 0.04630088806152344
# samples 675033
# chromosome chr11 order 7
# genome 1808681051 1943767673
# hilbert 9595 10312
# length 717
# individual False
# done in: 0.04484891891479492
# samples 669260
# chromosome chr12 order 7
# genome 1943767673 2077042982
# hilbert 10312 11019
# length 707
# individual False
# done in: 0.044682979583740234
# samples 575850
# chromosome chr13 order 7
# genome 2077042982 2191407310
# hilbert 11019 11625
# length 606
# individual False
# done in: 0.038928985595703125
# samples 536748
# chromosome chr14 order 7
# genome 2191407310 2298451028
# hilbert 11625 12193
# length 568
# individual False
# done in: 0.036904096603393555
# samples 512657
# chromosome chr15 order 7
# genome 2298451028 2400442217
# hilbert 12193 12734
# length 541
# individual False
# done in: 0.03409886360168457
# samples 451774
# chromosome chr16 order 7
# genome 2400442217 2490780562
# hilbert 12734 13214
# length 480
# individual False
# done in: 0.03099989891052246
# samples 405977
# chromosome chr17 order 7
# genome 2490780562 2574038003
# hilbert 13214 13655
# length 441
# individual False
# done in: 0.02724289894104004
# samples 390387
# chromosome chr18 order 7
# genome 2574038003 2654411288
# hilbert 13655 14082
# length 427
# individual False
# done in: 0.026436805725097656
# samples 295645
# chromosome chr19 order 7
# genome 2654411288 2713028904
# hilbert 14082 14393
# length 311
# individual False
# done in: 0.020228862762451172
# samples 315128
# chromosome chr20 order 7
# genome 2713028904 2777473071
# hilbert 14393 14735
# length 342
# individual False
# done in: 0.02143120765686035
# samples 240650
# chromosome chr21 order 7
# genome 2777473071 2824183054
# hilbert 14735 14982
# length 247
# individual False
# done in: 0.015841007232666016
# samples 256523
# chromosome chr22 order 7
# genome 2824183054 2875001522
# hilbert 14982 15252
# length 270
# individual False
# done in: 0.017580032348632812
# samples 776353
# chromosome chrX order 7
# genome 2875001522 3031042417
# hilbert 15252 16080
# length 828
# individual False
# done in: 0.054579973220825195
# samples 296868
# chromosome chrY order 7
# genome 3031042417 3088269832
# hilbert 16080 16384
# length 304
# individual False
# done in: 0.019701004028320312
# ['hilbert_genome_cooler_data/parquet_data/chr1_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_7.parquet']
# samples 1246254
# chromosome chr1 order 8
# genome 0 248956422
# hilbert 0 5283
# length 5283
# individual False
# done in: 0.11401104927062988
# samples 1215997
# chromosome chr2 order 8
# genome 248956422 491149951
# hilbert 5283 10422
# length 5139
# individual False
# done in: 0.1106119155883789
# samples 990113
# chromosome chr3 order 8
# genome 491149951 689445510
# hilbert 10422 14630
# length 4208
# individual False
# done in: 0.09149384498596191
# samples 955772
# chromosome chr4 order 8
# genome 689445510 879660065
# hilbert 14630 18667
# length 4037
# individual False
# done in: 0.08781003952026367
# samples 904577
# chromosome chr5 order 8
# genome 879660065 1061198324
# hilbert 18667 22519
# length 3852
# individual False
# done in: 0.08395195007324219
# samples 855576
# chromosome chr6 order 8
# genome 1061198324 1232004303
# hilbert 22519 26144
# length 3625
# individual False
# done in: 0.0780491828918457
# samples 795694
# chromosome chr7 order 8
# genome 1232004303 1391350276
# hilbert 26144 29525
# length 3381
# individual False
# done in: 0.07228398323059082
# samples 731821
# chromosome chr8 order 8
# genome 1391350276 1536488912
# hilbert 29525 32605
# length 3080
# individual False
# done in: 0.06769490242004395
# samples 706068
# chromosome chr9 order 8
# genome 1536488912 1674883629
# hilbert 32605 35542
# length 2937
# individual False
# done in: 0.06706094741821289
# samples 677674
# chromosome chr10 order 8
# genome 1674883629 1808681051
# hilbert 35542 38381
# length 2839
# individual False
# done in: 0.06312394142150879
# samples 675033
# chromosome chr11 order 8
# genome 1808681051 1943767673
# hilbert 38381 41248
# length 2867
# individual False
# done in: 0.0633699893951416
# samples 669260
# chromosome chr12 order 8
# genome 1943767673 2077042982
# hilbert 41248 44076
# length 2828
# individual False
# done in: 0.06230807304382324
# samples 575850
# chromosome chr13 order 8
# genome 2077042982 2191407310
# hilbert 44076 46503
# length 2427
# individual False
# done in: 0.05211687088012695
# samples 536748
# chromosome chr14 order 8
# genome 2191407310 2298451028
# hilbert 46503 48775
# length 2272
# individual False
# done in: 0.04899406433105469
# samples 512657
# chromosome chr15 order 8
# genome 2298451028 2400442217
# hilbert 48775 50939
# length 2164
# individual False
# done in: 0.04925203323364258
# samples 451774
# chromosome chr16 order 8
# genome 2400442217 2490780562
# hilbert 50939 52856
# length 1917
# individual False
# done in: 0.04175400733947754
# samples 405977
# chromosome chr17 order 8
# genome 2490780562 2574038003
# hilbert 52856 54623
# length 1767
# individual False
# done in: 0.03748607635498047
# samples 390387
# chromosome chr18 order 8
# genome 2574038003 2654411288
# hilbert 54623 56329
# length 1706
# individual False
# done in: 0.03594803810119629
# samples 295645
# chromosome chr19 order 8
# genome 2654411288 2713028904
# hilbert 56329 57573
# length 1244
# individual False
# done in: 0.02690887451171875
# samples 315128
# chromosome chr20 order 8
# genome 2713028904 2777473071
# hilbert 57573 58940
# length 1367
# individual False
# done in: 0.02909994125366211
# samples 240650
# chromosome chr21 order 8
# genome 2777473071 2824183054
# hilbert 58940 59931
# length 991
# individual False
# done in: 0.021950960159301758
# samples 256523
# chromosome chr22 order 8
# genome 2824183054 2875001522
# hilbert 59931 61010
# length 1079
# individual False
# done in: 0.024464845657348633
# samples 776353
# chromosome chrX order 8
# genome 2875001522 3031042417
# hilbert 61010 64321
# length 3311
# individual False
# done in: 0.07214498519897461
# samples 296868
# chromosome chrY order 8
# genome 3031042417 3088269832
# hilbert 64321 65536
# length 1215
# individual False
# done in: 0.026900053024291992
# ['hilbert_genome_cooler_data/parquet_data/chr1_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_8.parquet']
# samples 1246254
# chromosome chr1 order 9
# genome 0 248956422
# hilbert 0 21132
# length 21132
# individual False
# done in: 0.2229759693145752
# samples 1215997
# chromosome chr2 order 9
# genome 248956422 491149951
# hilbert 21132 41690
# length 20558
# individual False
# done in: 0.20839977264404297
# samples 990113
# chromosome chr3 order 9
# genome 491149951 689445510
# hilbert 41690 58522
# length 16832
# individual False
# done in: 0.16756296157836914
# samples 955772
# chromosome chr4 order 9
# genome 689445510 879660065
# hilbert 58522 74668
# length 16146
# individual False
# done in: 0.17280912399291992
# samples 904577
# chromosome chr5 order 9
# genome 879660065 1061198324
# hilbert 74668 90078
# length 15410
# individual False
# done in: 0.15509915351867676
# samples 855576
# chromosome chr6 order 9
# genome 1061198324 1232004303
# hilbert 90078 104577
# length 14499
# individual False
# done in: 0.1544351577758789
# samples 795694
# chromosome chr7 order 9
# genome 1232004303 1391350276
# hilbert 104577 118103
# length 13526
# individual False
# done in: 0.13772201538085938
# samples 731821
# chromosome chr8 order 9
# genome 1391350276 1536488912
# hilbert 118103 130422
# length 12319
# individual False
# done in: 0.12904810905456543
# samples 706068
# chromosome chr9 order 9
# genome 1536488912 1674883629
# hilbert 130422 142170
# length 11748
# individual False
# done in: 0.11980891227722168
# samples 677674
# chromosome chr10 order 9
# genome 1674883629 1808681051
# hilbert 142170 153527
# length 11357
# individual False
# done in: 0.12066411972045898
# samples 675033
# chromosome chr11 order 9
# genome 1808681051 1943767673
# hilbert 153527 164994
# length 11467
# individual False
# done in: 0.11667418479919434
# samples 669260
# chromosome chr12 order 9
# genome 1943767673 2077042982
# hilbert 164994 176307
# length 11313
# individual False
# done in: 0.11911296844482422
# samples 575850
# chromosome chr13 order 9
# genome 2077042982 2191407310
# hilbert 176307 186014
# length 9707
# individual False
# done in: 0.09941816329956055
# samples 536748
# chromosome chr14 order 9
# genome 2191407310 2298451028
# hilbert 186014 195101
# length 9087
# individual False
# done in: 0.0932149887084961
# samples 512657
# chromosome chr15 order 9
# genome 2298451028 2400442217
# hilbert 195101 203758
# length 8657
# individual False
# done in: 0.08889174461364746
# samples 451774
# chromosome chr16 order 9
# genome 2400442217 2490780562
# hilbert 203758 211426
# length 7668
# individual False
# done in: 0.07770299911499023
# samples 405977
# chromosome chr17 order 9
# genome 2490780562 2574038003
# hilbert 211426 218494
# length 7068
# individual False
# done in: 0.07447504997253418
# samples 390387
# chromosome chr18 order 9
# genome 2574038003 2654411288
# hilbert 218494 225316
# length 6822
# individual False
# done in: 0.0688169002532959
# samples 295645
# chromosome chr19 order 9
# genome 2654411288 2713028904
# hilbert 225316 230292
# length 4976
# individual False
# done in: 0.0509800910949707
# samples 315128
# chromosome chr20 order 9
# genome 2713028904 2777473071
# hilbert 230292 235762
# length 5470
# individual False
# done in: 0.05496811866760254
# samples 240650
# chromosome chr21 order 9
# genome 2777473071 2824183054
# hilbert 235762 239727
# length 3965
# individual False
# done in: 0.04264998435974121
# samples 256523
# chromosome chr22 order 9
# genome 2824183054 2875001522
# hilbert 239727 244040
# length 4313
# individual False
# done in: 0.0446782112121582
# samples 776353
# chromosome chrX order 9
# genome 2875001522 3031042417
# hilbert 244040 257286
# length 13246
# individual False
# done in: 0.13483881950378418
# samples 296868
# chromosome chrY order 9
# genome 3031042417 3088269832
# hilbert 257286 262144
# length 4858
# individual False
# done in: 0.05337333679199219
# ['hilbert_genome_cooler_data/parquet_data/chr1_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_9.parquet']
# samples 1246254
# chromosome chr1 order 10
# genome 0 248956422
# hilbert 0 84529
# length 84529
# individual False
# done in: 0.6246311664581299
# samples 1215997
# chromosome chr2 order 10
# genome 248956422 491149951
# hilbert 84529 166762
# length 82233
# individual False
# done in: 0.6082439422607422
# samples 990113
# chromosome chr3 order 10
# genome 491149951 689445510
# hilbert 166762 234090
# length 67328
# individual False
# done in: 0.4911220073699951
# samples 955772
# chromosome chr4 order 10
# genome 689445510 879660065
# hilbert 234090 298675
# length 64585
# individual False
# done in: 0.48040103912353516
# samples 904577
# chromosome chr5 order 10
# genome 879660065 1061198324
# hilbert 298675 360314
# length 61639
# individual False
# done in: 0.4531240463256836
# samples 855576
# chromosome chr6 order 10
# genome 1061198324 1232004303
# hilbert 360314 418308
# length 57994
# individual False
# done in: 0.44098901748657227
# samples 795694
# chromosome chr7 order 10
# genome 1232004303 1391350276
# hilbert 418308 472412
# length 54104
# individual False
# done in: 0.41118311882019043
# samples 731821
# chromosome chr8 order 10
# genome 1391350276 1536488912
# hilbert 472412 521691
# length 49279
# individual False
# done in: 0.3938910961151123
# samples 706068
# chromosome chr9 order 10
# genome 1536488912 1674883629
# hilbert 521691 568681
# length 46990
# individual False
# done in: 0.3554260730743408
# samples 677674
# chromosome chr10 order 10
# genome 1674883629 1808681051
# hilbert 568681 614110
# length 45429
# individual False
# done in: 0.35021400451660156
# samples 675033
# chromosome chr11 order 10
# genome 1808681051 1943767673
# hilbert 614110 659977
# length 45867
# individual False
# done in: 0.3471970558166504
# samples 669260
# chromosome chr12 order 10
# genome 1943767673 2077042982
# hilbert 659977 705228
# length 45251
# individual False
# done in: 0.3459470272064209
# samples 575850
# chromosome chr13 order 10
# genome 2077042982 2191407310
# hilbert 705228 744059
# length 38831
# individual False
# done in: 0.29273414611816406
# samples 536748
# chromosome chr14 order 10
# genome 2191407310 2298451028
# hilbert 744059 780404
# length 36345
# individual False
# done in: 0.27193593978881836
# samples 512657
# chromosome chr15 order 10
# genome 2298451028 2400442217
# hilbert 780404 815034
# length 34630
# individual False
# done in: 0.25744175910949707
# samples 451774
# chromosome chr16 order 10
# genome 2400442217 2490780562
# hilbert 815034 845707
# length 30673
# individual False
# done in: 0.23191404342651367
# samples 405977
# chromosome chr17 order 10
# genome 2490780562 2574038003
# hilbert 845707 873976
# length 28269
# individual False
# done in: 0.20948576927185059
# samples 390387
# chromosome chr18 order 10
# genome 2574038003 2654411288
# hilbert 873976 901265
# length 27289
# individual False
# done in: 0.20311403274536133
# samples 295645
# chromosome chr19 order 10
# genome 2654411288 2713028904
# hilbert 901265 921168
# length 19903
# individual False
# done in: 0.14785099029541016
# samples 315128
# chromosome chr20 order 10
# genome 2713028904 2777473071
# hilbert 921168 943049
# length 21881
# individual False
# done in: 0.17296314239501953
# samples 240650
# chromosome chr21 order 10
# genome 2777473071 2824183054
# hilbert 943049 958909
# length 15860
# individual False
# done in: 0.11721277236938477
# samples 256523
# chromosome chr22 order 10
# genome 2824183054 2875001522
# hilbert 958909 976163
# length 17254
# individual False
# done in: 0.13495707511901855
# samples 776353
# chromosome chrX order 10
# genome 2875001522 3031042417
# hilbert 976163 1029145
# length 52982
# individual False
# done in: 0.39524197578430176
# samples 296868
# chromosome chrY order 10
# genome 3031042417 3088269832
# hilbert 1029145 1048576
# length 19431
# individual False
# done in: 0.14424395561218262
# ['hilbert_genome_cooler_data/parquet_data/chr1_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_10.parquet']
# samples 1246254
# chromosome chr1 order 11
# genome 0 248956422
# hilbert 0 338117
# length 338117
# individual False
# done in: 2.295534133911133
# samples 1215997
# chromosome chr2 order 11
# genome 248956422 491149951
# hilbert 338117 667050
# length 328933
# individual False
# done in: 2.1921021938323975
# samples 990113
# chromosome chr3 order 11
# genome 491149951 689445510
# hilbert 667050 936363
# length 269313
# individual False
# done in: 1.8018429279327393
# samples 955772
# chromosome chr4 order 11
# genome 689445510 879660065
# hilbert 936363 1194701
# length 258338
# individual False
# done in: 1.7215979099273682
# samples 904577
# chromosome chr5 order 11
# genome 879660065 1061198324
# hilbert 1194701 1441256
# length 246555
# individual False
# done in: 1.666412115097046
# samples 855576
# chromosome chr6 order 11
# genome 1061198324 1232004303
# hilbert 1441256 1673234
# length 231978
# individual False
# done in: 1.7848787307739258
# samples 795694
# chromosome chr7 order 11
# genome 1232004303 1391350276
# hilbert 1673234 1889649
# length 216415
# individual False
# done in: 1.534883737564087
# samples 731821
# chromosome chr8 order 11
# genome 1391350276 1536488912
# hilbert 1889649 2086767
# length 197118
# individual False
# done in: 1.4513227939605713
# samples 706068
# chromosome chr9 order 11
# genome 1536488912 1674883629
# hilbert 2086767 2274727
# length 187960
# individual False
# done in: 1.3027808666229248
# samples 677674
# chromosome chr10 order 11
# genome 1674883629 1808681051
# hilbert 2274727 2456442
# length 181715
# individual False
# done in: 1.2733409404754639
# samples 675033
# chromosome chr11 order 11
# genome 1808681051 1943767673
# hilbert 2456442 2639909
# length 183467
# individual False
# done in: 1.2941739559173584
# samples 669260
# chromosome chr12 order 11
# genome 1943767673 2077042982
# hilbert 2639909 2820915
# length 181006
# individual False
# done in: 1.2312850952148438
# samples 575850
# chromosome chr13 order 11
# genome 2077042982 2191407310
# hilbert 2820915 2976238
# length 155323
# individual False
# done in: 1.0499629974365234
# samples 536748
# chromosome chr14 order 11
# genome 2191407310 2298451028
# hilbert 2976238 3121619
# length 145381
# individual False
# done in: 0.9984710216522217
# samples 512657
# chromosome chr15 order 11
# genome 2298451028 2400442217
# hilbert 3121619 3260137
# length 138518
# individual False
# done in: 0.9548590183258057
# samples 451774
# chromosome chr16 order 11
# genome 2400442217 2490780562
# hilbert 3260137 3382829
# length 122692
# individual False
# done in: 0.8538110256195068
# samples 405977
# chromosome chr17 order 11
# genome 2490780562 2574038003
# hilbert 3382829 3495904
# length 113075
# individual False
# done in: 0.7850651741027832
# samples 390387
# chromosome chr18 order 11
# genome 2574038003 2654411288
# hilbert 3495904 3605063
# length 109159
# individual False
# done in: 0.7458579540252686
# samples 295645
# chromosome chr19 order 11
# genome 2654411288 2713028904
# hilbert 3605063 3684674
# length 79611
# individual False
# done in: 0.5529308319091797
# samples 315128
# chromosome chr20 order 11
# genome 2713028904 2777473071
# hilbert 3684674 3772198
# length 87524
# individual False
# done in: 0.6077797412872314
# samples 240650
# chromosome chr21 order 11
# genome 2777473071 2824183054
# hilbert 3772198 3835637
# length 63439
# individual False
# done in: 0.44029784202575684
# samples 256523
# chromosome chr22 order 11
# genome 2824183054 2875001522
# hilbert 3835637 3904655
# length 69018
# individual False
# done in: 0.4787561893463135
# samples 776353
# chromosome chrX order 11
# genome 2875001522 3031042417
# hilbert 3904655 4116581
# length 211926
# individual False
# done in: 1.431169033050537
# samples 296868
# chromosome chrY order 11
# genome 3031042417 3088269832
# hilbert 4116581 4194304
# length 77723
# individual False
# done in: 0.5560357570648193
# ['hilbert_genome_cooler_data/parquet_data/chr1_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_11.parquet']
# samples 1246254
# chromosome chr1 order 12
# genome 0 248956422
# hilbert 0 1352471
# length 1352471
# individual True
# done in: 3.5284299850463867
# samples 1215997
# chromosome chr2 order 12
# genome 248956422 491149951
# hilbert 1352471 2668202
# length 1315731
# individual True
# done in: 3.4278388023376465
# samples 990113
# chromosome chr3 order 12
# genome 491149951 689445510
# hilbert 2668202 3745455
# length 1077253
# individual True
# done in: 2.782066822052002
# samples 955772
# chromosome chr4 order 12
# genome 689445510 879660065
# hilbert 3745455 4778807
# length 1033352
# individual True
# done in: 2.8277599811553955
# samples 904577
# chromosome chr5 order 12
# genome 879660065 1061198324
# hilbert 4778807 5765025
# length 986218
# individual True
# done in: 2.712885856628418
# samples 855576
# chromosome chr6 order 12
# genome 1061198324 1232004303
# hilbert 5765025 6692939
# length 927914
# individual True
# done in: 2.5508298873901367
# samples 795694
# chromosome chr7 order 12
# genome 1232004303 1391350276
# hilbert 6692939 7558596
# length 865657
# individual True
# done in: 2.3257360458374023
# samples 731821
# chromosome chr8 order 12
# genome 1391350276 1536488912
# hilbert 7558596 8347070
# length 788474
# individual True
# done in: 2.110387086868286
# samples 706068
# chromosome chr9 order 12
# genome 1536488912 1674883629
# hilbert 8347070 9098908
# length 751838
# individual True
# done in: 2.0168328285217285
# samples 677674
# chromosome chr10 order 12
# genome 1674883629 1808681051
# hilbert 9098908 9825771
# length 726863
# individual True
# done in: 1.962169885635376
# samples 675033
# chromosome chr11 order 12
# genome 1808681051 1943767673
# hilbert 9825771 10559637
# length 733866
# individual True
# done in: 2.0266740322113037
# samples 669260
# chromosome chr12 order 12
# genome 1943767673 2077042982
# hilbert 10559637 11283663
# length 724026
# individual True
# done in: 2.0327951908111572
# samples 575850
# chromosome chr13 order 12
# genome 2077042982 2191407310
# hilbert 11283663 11904955
# length 621292
# individual True
# done in: 1.736116886138916
# samples 536748
# chromosome chr14 order 12
# genome 2191407310 2298451028
# hilbert 11904955 12486476
# length 581521
# individual True
# done in: 1.6950998306274414
# samples 512657
# chromosome chr15 order 12
# genome 2298451028 2400442217
# hilbert 12486476 13040550
# length 554074
# individual True
# done in: 1.528412103652954
# samples 451774
# chromosome chr16 order 12
# genome 2400442217 2490780562
# hilbert 13040550 13531318
# length 490768
# individual True
# done in: 1.366835117340088
# samples 405977
# chromosome chr17 order 12
# genome 2490780562 2574038003
# hilbert 13531318 13983619
# length 452301
# individual True
# done in: 1.2674241065979004
# samples 390387
# chromosome chr18 order 12
# genome 2574038003 2654411288
# hilbert 13983619 14420252
# length 436633
# individual True
# done in: 1.207021951675415
# samples 295645
# chromosome chr19 order 12
# genome 2654411288 2713028904
# hilbert 14420252 14738696
# length 318444
# individual True
# done in: 0.899205207824707
# samples 315128
# chromosome chr20 order 12
# genome 2713028904 2777473071
# hilbert 14738696 15088793
# length 350097
# individual True
# done in: 0.9788222312927246
# samples 240650
# chromosome chr21 order 12
# genome 2777473071 2824183054
# hilbert 15088793 15342548
# length 253755
# individual True
# done in: 0.7052462100982666
# samples 256523
# chromosome chr22 order 12
# genome 2824183054 2875001522
# hilbert 15342548 15618622
# length 276074
# individual True
# done in: 0.766632080078125
# samples 776353
# chromosome chrX order 12
# genome 2875001522 3031042417
# hilbert 15618622 16466324
# length 847702
# individual True
# done in: 2.3574678897857666
# samples 296868
# chromosome chrY order 12
# genome 3031042417 3088269832
# hilbert 16466324 16777216
# length 310892
# individual True
# done in: 0.8650879859924316
# ['hilbert_genome_cooler_data/parquet_data/chr1_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_12.parquet']
# samples 1246254
# chromosome chr1 order 13
# genome 0 248956422
# hilbert 0 5409884
# length 5409884
# individual True
# done in: 14.099778175354004
# samples 1215997
# chromosome chr2 order 13
# genome 248956422 491149951
# hilbert 5409884 10672809
# length 5262925
# individual True
# done in: 13.703557014465332
# samples 990113
# chromosome chr3 order 13
# genome 491149951 689445510
# hilbert 10672809 14981820
# length 4309011
# individual True
# done in: 11.284101963043213
# samples 955772
# chromosome chr4 order 13
# genome 689445510 879660065
# hilbert 14981820 19115229
# length 4133409
# individual True
# done in: 10.863027095794678
# samples 904577
# chromosome chr5 order 13
# genome 879660065 1061198324
# hilbert 19115229 23060100
# length 3944871
# individual True
# done in: 10.453773975372314
# samples 855576
# chromosome chr6 order 13
# genome 1061198324 1232004303
# hilbert 23060100 26771756
# length 3711656
# individual True
# done in: 10.04826283454895
# samples 795694
# chromosome chr7 order 13
# genome 1232004303 1391350276
# hilbert 26771756 30234384
# length 3462628
# individual True
# done in: 9.42732286453247
# samples 731821
# chromosome chr8 order 13
# genome 1391350276 1536488912
# hilbert 30234384 33388282
# length 3153898
# individual True
# done in: 8.575408220291138
# samples 706068
# chromosome chr9 order 13
# genome 1536488912 1674883629
# hilbert 33388282 36395633
# length 3007351
# individual True
# done in: 8.157828092575073
# samples 677674
# chromosome chr10 order 13
# genome 1674883629 1808681051
# hilbert 36395633 39303084
# length 2907451
# individual True
# done in: 8.005363941192627
# samples 675033
# chromosome chr11 order 13
# genome 1808681051 1943767673
# hilbert 39303084 42238550
# length 2935466
# individual True
# done in: 8.084594011306763
# samples 669260
# chromosome chr12 order 13
# genome 1943767673 2077042982
# hilbert 42238550 45134655
# length 2896105
# individual True
# done in: 7.96789288520813
# samples 575850
# chromosome chr13 order 13
# genome 2077042982 2191407310
# hilbert 45134655 47619820
# length 2485165
# individual True
# done in: 6.812591791152954
# samples 536748
# chromosome chr14 order 13
# genome 2191407310 2298451028
# hilbert 47619820 49945906
# length 2326086
# individual True
# done in: 6.372720003128052
# samples 512657
# chromosome chr15 order 13
# genome 2298451028 2400442217
# hilbert 49945906 52162200
# length 2216294
# individual True
# done in: 5.988490104675293
# samples 451774
# chromosome chr16 order 13
# genome 2400442217 2490780562
# hilbert 52162200 54125275
# length 1963075
# individual True
# done in: 5.391571760177612
# samples 405977
# chromosome chr17 order 13
# genome 2490780562 2574038003
# hilbert 54125275 55934479
# length 1809204
# individual True
# done in: 5.010189771652222
# samples 390387
# chromosome chr18 order 13
# genome 2574038003 2654411288
# hilbert 55934479 57681011
# length 1746532
# individual True
# done in: 4.8170201778411865
# samples 295645
# chromosome chr19 order 13
# genome 2654411288 2713028904
# hilbert 57681011 58954786
# length 1273775
# individual True
# done in: 3.483328104019165
# samples 315128
# chromosome chr20 order 13
# genome 2713028904 2777473071
# hilbert 58954786 60355173
# length 1400387
# individual True
# done in: 3.760410785675049
# samples 240650
# chromosome chr21 order 13
# genome 2777473071 2824183054
# hilbert 60355173 61370193
# length 1015020
# individual True
# done in: 2.747469663619995
# samples 256523
# chromosome chr22 order 13
# genome 2824183054 2875001522
# hilbert 61370193 62474491
# length 1104298
# individual True
# done in: 2.9798293113708496
# samples 776353
# chromosome chrX order 13
# genome 2875001522 3031042417
# hilbert 62474491 65865298
# length 3390807
# individual True
# done in: 9.180539846420288
# samples 296868
# chromosome chrY order 13
# genome 3031042417 3088269832
# hilbert 65865298 67108864
# length 1243566
# individual True
# done in: 3.3527820110321045
# ['hilbert_genome_cooler_data/parquet_data/chr1_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_13.parquet']

# %%
# this will take a while
for o in range(14, 17):
    for c in genome.chromosomes:
        write_parquet(c, o)
    combine(o)
# Out:
# samples 1246254
# chromosome chr1 order 14
# genome 0 248956422
# hilbert 0 21639537
# length 21639537
# individual True
# done in: 57.42068934440613
# samples 1215997
# chromosome chr2 order 14
# genome 248956422 491149951
# hilbert 21639537 42691237
# length 21051700
# individual True
# done in: 54.94024968147278
# samples 990113
# chromosome chr3 order 14
# genome 491149951 689445510
# hilbert 42691237 59927282
# length 17236045
# individual True
# done in: 44.740792989730835
# samples 955772
# chromosome chr4 order 14
# genome 689445510 879660065
# hilbert 59927282 76460919
# length 16533637
# individual True
# done in: 43.428744077682495
# samples 904577
# chromosome chr5 order 14
# genome 879660065 1061198324
# hilbert 76460919 92240403
# length 15779484
# individual True
# done in: 41.952877044677734
# samples 855576
# chromosome chr6 order 14
# genome 1061198324 1232004303
# hilbert 92240403 107087027
# length 14846624
# individual True
# done in: 39.83639311790466
# samples 795694
# chromosome chr7 order 14
# genome 1232004303 1391350276
# hilbert 107087027 120937536
# length 13850509
# individual True
# done in: 37.54508709907532
# samples 731821
# chromosome chr8 order 14
# genome 1391350276 1536488912
# hilbert 120937536 133553129
# length 12615593
# individual True
# done in: 34.30879092216492
# samples 706068
# chromosome chr9 order 14
# genome 1536488912 1674883629
# hilbert 133553129 145582534
# length 12029405
# individual True
# done in: 32.45147204399109
# samples 677674
# chromosome chr10 order 14
# genome 1674883629 1808681051
# hilbert 145582534 157212338
# length 11629804
# individual True
# done in: 31.44705891609192
# samples 675033
# chromosome chr11 order 14
# genome 1808681051 1943767673
# hilbert 157212338 168954200
# length 11741862
# individual True
# done in: 31.87006115913391
# samples 669260
# chromosome chr12 order 14
# genome 1943767673 2077042982
# hilbert 168954200 180538622
# length 11584422
# individual True
# done in: 31.262634992599487
# samples 575850
# chromosome chr13 order 14
# genome 2077042982 2191407310
# hilbert 180538622 190479282
# length 9940660
# individual True
# done in: 26.958611249923706
# samples 536748
# chromosome chr14 order 14
# genome 2191407310 2298451028
# hilbert 190479282 199783627
# length 9304345
# individual True
# done in: 25.35883903503418
# samples 512657
# chromosome chr15 order 14
# genome 2298451028 2400442217
# hilbert 199783627 208648802
# length 8865175
# individual True
# done in: 24.175798177719116
# samples 451774
# chromosome chr16 order 14
# genome 2400442217 2490780562
# hilbert 208648802 216501100
# length 7852298
# individual True
# done in: 21.2480947971344
# samples 405977
# chromosome chr17 order 14
# genome 2490780562 2574038003
# hilbert 216501100 223737918
# length 7236818
# individual True
# done in: 19.628317832946777
# samples 390387
# chromosome chr18 order 14
# genome 2574038003 2654411288
# hilbert 223737918 230724044
# length 6986126
# individual True
# done in: 18.943855047225952
# samples 295645
# chromosome chr19 order 14
# genome 2654411288 2713028904
# hilbert 230724044 235819144
# length 5095100
# individual True
# done in: 13.917894840240479
# samples 315128
# chromosome chr20 order 14
# genome 2713028904 2777473071
# hilbert 235819144 241420695
# length 5601551
# individual True
# done in: 15.19627594947815
# samples 240650
# chromosome chr21 order 14
# genome 2777473071 2824183054
# hilbert 241420695 245480773
# length 4060078
# individual True
# done in: 10.974689960479736
# samples 256523
# chromosome chr22 order 14
# genome 2824183054 2875001522
# hilbert 245480773 249897964
# length 4417191
# individual True
# done in: 12.06527304649353
# samples 776353
# chromosome chrX order 14
# genome 2875001522 3031042417
# hilbert 249897964 263461192
# length 13563228
# individual True
# done in: 36.82208466529846
# samples 296868
# chromosome chrY order 14
# genome 3031042417 3088269832
# hilbert 263461192 268435456
# length 4974264
# individual True
# done in: 13.486297130584717
# ['hilbert_genome_cooler_data/parquet_data/chr1_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_14.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_14.parquet']
# samples 1246254
# chromosome chr1 order 15
# genome 0 248956422
# hilbert 0 86558149
# length 86558149
# individual True
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[173], line 4
#       2 for o in range(14, 17):
#       3     for c in genome.chromosomes:
# ----> 4         write_parquet(c, o)
#       5     combine(o)
#
# Cell In[171], line 3, in write_parquet(chromosome, order)
#       1 def write_parquet(chromosome, order):
#       2     pfn = os.path.join(parquet_data_dir, chromosome + "_" + str(order) + ".parquet")
# ----> 3     agg = aggregate_chromosome(chromosome, order)
#       4     table = {
#       5         "index": agg[0],
#       6         "value": agg[1],
#       7     }
#       8     pq.write_table(
#       9         pa.table(table),
#      10         pfn,
#      11         compression='gzip',
#      12     )
#
# Cell In[78], line 35, in aggregate_chromosome(chromosome, order)
#      31 # loop over the hilbert points for this order
#      32 # can get bounds in genome position
#      33 for i, pos in enumerate(hp):
#      34     # global genome pos
# ---> 35     gpos = scan_spread(pos, order)
#      36     # at order 16 we may get None values for individual hilbert coordinates
#      37     if(gpos is None):
#
# Cell In[43], line 7, in scan_spread(pos, order)
#       5   return get_genome_from_hilbert(pos)
#       6 start = hilbert_pos_to_order(pos, order, 16)
# ----> 7 found = get_genome_from_hilbert(start)
#       8 # need to scan everything at the highest order
#       9 # but only until we find something which should usually happen in a few loops
#      10 for l in range(pow(4, 16 - order)):
#
# Cell In[40], line 2, in get_genome_from_hilbert(pos)
#       1 def get_genome_from_hilbert(pos):
# ----> 2   gpos = spread_scale_invert(pos)
#       3   if pos != spread_scale(gpos):
#       4     return None
#
# Cell In[37], line 6, in spread_scale_invert(pos)
#       4 i_max = genome.total_size
#       5 o_min = 0
# ----> 6 o_max = pow(4, maxOrder)
#       7 return round((pos - o_min) / ((o_max - o_min) / (i_max - i_min)) + i_min)
#
# KeyboardInterrupt:

# %%
write_parquet("chr1", 13)
# Out:
# samples 1246254
# chromosome chr1 order 13
# genome 0 248956422
# hilbert 0 5409884
# length 5409884
# individual True
# done in: 14.15534496307373

# %%
write_parquet_test("chr1", 13)
# Out:
# samples 1246254
# chromosome chr1 order 13
# genome 0 248956422
# hilbert 0 5409884
# length 5409884
# individual True
# done in: 14.050719976425171

# %%
def write_parquet_test(chromosome, order):
    pfn = os.path.join(parquet_data_dir, chromosome + "_" + str(order) + ".parquet")
    agg = aggregate_chromosome(chromosome, order)
    table = {
        "index": agg[0+], 
        "value": agg[1],
    }
    pq.write_table(pa.table(table), 
                   pfn, 
                   #compression='gzip'
                  )

# %%
def combine_test(order, size):
    paths = [os.path.join(parquet_data_dir, (c + "_" + str(order) + ".parquet")) for c in genome.chromosomes]
    print(paths)
    coalesce_parquets(paths, 
                      os.path.join(parquet_data_dir,"order_" + str(order) + ".parquet"),
                      size
                     )

# %%
pqf = pq.ParquetFile(os.path.join(parquet_data_dir, 'order_13.parquet'))

# %%
pqf.metadata
# Out:
# <pyarrow._parquet.FileMetaData object at 0x98e82a7c0>
#   created_by: parquet-cpp-arrow version 10.0.1
#   num_columns: 2
#   num_rows: 67108864
#   num_row_groups: 65
#   format_version: 2.6
#   serialized_size: 16836

# %%
pqf.schema
# Out:
# <pyarrow._parquet.ParquetSchema object at 0x4f20ad400>
# required group field_id=-1 schema {
#   optional int64 field_id=-1 index;
#   optional int64 field_id=-1 value;
# }

# %%
ptable = pq.read_table(os.path.join(old_dir, 'order_13.parquet'))

# %%
pdf = ptable.to_pandas()

# %%
pnp = pdf.to_numpy(dtype=np.int8)

# %%
pnp[:,0]
# Out:
# array([17, 17, 17, ..., 17, 17, 17], dtype=int8)

# %%
with open(os.path.join(parquet_data_dir, 'order_13.bytes'), 'wb') as f:
    f.write(pnp[:,1].tobytes())

# %%
old_dir = 'hilbert_genome_cooler_data/old_parquet_data'

# %%
for order in range(5, 17):
    print("reading", order)
    ptable = pq.read_table(os.path.join(old_dir, 'order_' + str(order) + '.parquet'))
    pdf = ptable.to_pandas()
    pnp = pdf.to_numpy(dtype=np.int8)
    print("writing", order)
    with open(os.path.join(parquet_data_dir, 'order_' + str(order) + '.bytes'), 'wb') as f:
        f.write(pnp[:,0].tobytes())
# Out:
# reading 5
# writing 5
# reading 6
# writing 6
# reading 7
# writing 7
# reading 8
# writing 8
# reading 9
# writing 9
# reading 10
# writing 10
# reading 11
# writing 11
# reading 12
# writing 12
# reading 13
# writing 13
# reading 14
# writing 14
# reading 15
# writing 15
# reading 16
# writing 16

# %%
tnp = np.arange(0, 1024, dtype=np.int8)

# %%
with open(os.path.join(parquet_data_dir, 'test_int8.bytes'), 'wb') as f:
    f.write(tnp.tobytes())

# %%
1321 * 4096
# Out:
# 5410816

# %%
math.sqrt(67108864)
# Out:
# 8192.0

# %%
4**8
# Out:
# 65536

# %%
combine_test(5, 4**8)
# Out:
# ['hilbert_genome_cooler_data/parquet_data/chr1_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_5.parquet']

# %%
import os
import json
import gzip
import time
import math
import hilbert
import pyarrow
import pandas as pd
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# ## Prepare the signal data

# %%
chromosomes_to_exclude = ['chrY']

# %%
# setup the data directory if it doesn't already exist
data_dir = 'hilbert_genome_cooler_data'
if not os.path.exists(data_dir): 
    os.makedirs(data_dir)

# %%
# setup the data directory if it doesn't already exist
parquet_data_dir = 'hilbert_genome_cooler_data/parquet_data'
if not os.path.exists(parquet_data_dir): 
    os.makedirs(parquet_data_dir)

# %%
signal_categories = 18
input_signal_NA_category_value = signal_categories - 1

# %%
# Get the data file and store it locally
#
# ref. /net/seq/data/projects/Epilogos
#          /multivec-for-browser-2022-redo/epilogos_tracks/single/human
#          /Boix_et_al_833_sample/hg19/18/All_833_biosamples/S1/scores.txt.filledGap.versionSorted.txt.gz
#
signal_remote_URI = 'https://resources.altius.org/~areynolds/public/Boix_et_al_833_sample.hg19.18.All_833_biosamples.S1.scores.txt.gz'
signal_local_fn = os.path.join(data_dir, 'Boix_et_al_833_sample.hg19.18.All_833_biosamples.S1.scores.txt.gz')

# %%
if not os.path.exists(signal_local_fn):
    try:
        r = requests.get(signal_remote_URI)
        with open(signal_local_fn, "wb") as ofh:
            b = io.BytesIO(r.content)
            ofh.write(b.getbuffer())
    except requests.exceptions.RequestException as e:
        raise SystemExit(e)

# %%
input_signal_dir = os.path.split(os.path.abspath(signal_local_fn))[0]

# %%
def generate_categorical_data(ifn):
    signals = {}
    signals['__all'] = []
    with gzip.open(ifn, 'rb') as ifh:
        for line in ifh:
            elems = line.decode().rstrip().split('\t')
            chromosome = elems[0]
            signal = np.array([float(x) for x in elems[3:]])
            if chromosome not in signals:
                signals[chromosome] = []
            if chromosome not in chromosomes_to_exclude:
                signals[chromosome].append({'argmax': np.argmax(signal), 'sum': np.sum(signal)})
                signals['__all'].append({'argmax': np.argmax(signal), 'sum': np.sum(signal)})
            else:
                signals[chromosome].append({'argmax': input_signal_NA_category_value, 'sum': 0})
                signals['__all'].append({'argmax': input_signal_NA_category_value, 'sum': 0})
    return signals

# %%
def generate_categorical_data_file(ofn, categorical_data):
    with gzip.open(ofn, 'wb') as ofh:
        categorical_data_json = json.dumps(categorical_data, cls=NumpyEncoder)
        ofh.write(categorical_data_json.encode())

# %%
class NumpyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        if isinstance(obj, np.bool_):
            return bool(obj)
        return super(NumpyEncoder, self).default(obj)

# %%
categorical_data_fn = os.path.join(data_dir,'{}.categorical_data.json.gz'.format(os.path.basename(signal_local_fn)))

# %%
if not os.path.exists(categorical_data_fn):
    categorical_data = generate_categorical_data(signal_local_fn)
    generate_categorical_data_file(categorical_data_fn, categorical_data)
else:
    with gzip.open(categorical_data_fn, 'rb') as ifh:
        categorical_data = json.load(ifh)

# %% [markdown]
# ## Hilbert Genome

# %%
import hilbertgenome.chromsizes

# %%
genome = hilbertgenome.chromsizes["hg38"]

# %%
genome.total_size
# Out:
# 3088269832

# %%
maxOrder = 16 # 16 is the order that can contain the full genome

# %%
pow(4, maxOrder)
# Out:
# 4294967296

# %%
# convert a hilbert position from one order to another
def hilbert_pos_to_order(pos, fro, to):
    return math.floor(pos / pow(4, fro - to))

# %%
# spread our genome positions evenly across the 16th order hilbert curve
def spread_scale(gpos):
    i_min = 0
    i_max = genome.total_size
    o_min = 0
    o_max = pow(4, maxOrder)
    return round(o_min + (gpos - i_min) * ((o_max - o_min) / (i_max - i_min)))

# %%
# get the genome position for a given hilbert position (may return duplicates)
def spread_scale_invert(pos):
    i_min = 0
    i_max = genome.total_size
    o_min = 0
    o_max = pow(4, maxOrder)
    return round((pos - o_min) / ((o_max - o_min) / (i_max - i_min)) + i_min)

# %%
# get the global genome position from something like "chr2:12345"
def get_genome_from_base(start):
    chr = start.split(":")[0]
    offset = int(start.split(":")[1])
    return genome.sizes_acc[chr] + offset

# %%
def get_hilbert_from_genome(gpos):
    return spread_scale(gpos)

# %%
def get_genome_from_hilbert(pos):
  gpos = spread_scale_invert(pos)
  if pos != spread_scale(gpos): 
    return None
  return gpos;

# %%
# get the first base at the maximum order resolution 
# that comes after the starting pos and before the next pos at the current order
def scan_spread(pos, order):
  if(order == maxOrder):
    return get_genome_from_hilbert(pos)
  start = hilbert_pos_to_order(pos, order, maxOrder)
  found = get_genome_from_hilbert(start)
  # need to scan everything at the highest order
  # but only until we find something which should usually happen in a few loops
  for l in range(pow(4, maxOrder - order)):
    if found is not None:
        return found
    found = get_genome_from_hilbert(start+l)

# %%
# get the last base at the maximum order resolution 
# that comes after the starting pos and before the next pos at the current order
def scan_spread_reverse(pos, order):
  start = hilbert_pos_to_order(pos+1, order, maxOrder) - 1
  found = get_genome_from_hilbert(start)
  # need to scan everything at the highest order
  # but only until we find something which should usually happen in a few loops
  for l in range(pow(4, maxOrder - order)):
    if found is not None:
        return found
    found = get_genome_from_hilbert(start-l)

# %% [markdown]
# ## Aggregation

# %%
#find_maxvecsum_label = lambda x: x[np.argmax(np.array([i['sum'] for i in x]))]['argmax']
def aggregate(data):
    return data[np.argmax(np.array([i['sum'] for i in data]))]['argmax']

# %%
def accessor(d):
    return d["argmax"]

# %%
signal_resolution = 200

# %%
def aggregate_chromosome(chromosome, order):
    start_time = time.time()
    
    samples = categorical_data[chromosome]
    nsamples = len(samples)
    print("samples", nsamples)
    # sample resolution 
    sr = signal_resolution
    
    gstart = genome.sizes_acc[chromosome]
    gstop = genome.sizes_acc[chromosome] + genome.sizes[chromosome]
    hbstart = get_hilbert_from_genome(gstart)
    hbstop = get_hilbert_from_genome(gstop)
    
    # TODO: break this up into pieces for the highest orders
    hstart = hilbert_pos_to_order(hbstart, 16, order)
    hstop = hilbert_pos_to_order(hbstop, 16, order)
    
    print("chromosome", chromosome, "order", order)
    print("genome", gstart, gstop)
    print("hilbert", hstart, hstop)
    print("length", hstop - hstart)

    # if there are more hilbert indices than samples we dont need to aggregate
    individual = (hstop - hstart) / len(samples) > 1
    print("individual", individual)
    
    #hp = Hilbert(order, hstart, hstop)
    hp = np.arange(hstart, hstop)
    v = np.arange(hstart, hstop)
    # loop over the hilbert points for this order
    # can get bounds in genome position
    for i, pos in enumerate(hp):
        # global genome pos
        gpos = scan_spread(pos, order)          
        # at order 16 we may get None values for individual hilbert coordinates
        if(gpos is None):
            v[i] = input_signal_NA_category_value
            continue
        
        # local position
        lpos = gpos - gstart                    
        if(lpos < 0): 
            lpos = 0
        
        # the starting index in our sample
        datum_idx = round(lpos/sr)              
        
        if individual:
            # we have a single point, this will happen for higher orders
            # print("single data",  pos, lpos, slpos, datum_idx)
            if datum_idx >= nsamples:
                v[i] = input_signal_NA_category_value
                #print(i,pos,datum_idx)
            else:
                v[i] = accessor(samples[datum_idx])
        else:
            # we know multiple samples will fit in our hilbert cell
            # so we get the last genome pos in the hilbert cell
            sgpos = scan_spread_reverse(pos, order) # global genome pos           
            slpos = sgpos - gstart                  # local position
            sdatum_idx = round(slpos/sr)            #the ending index in our samples
            # we need to aggregate at lower orders
            # we grab all the samples from the starting index to the ending index
            data = samples[datum_idx:sdatum_idx+1]  # include the last sample
            # if there are no samples in our list, we save NA
            if(len(data) == 0):
                #print("aggregate data", pos, gpos, lpos, slpos, datum_idx, sdatum_idx, len(data))
                v[i] = input_signal_NA_category_value
            else:
                # we save the output of the user supplied aggregate function
                v[i] = aggregate(data)

    # can convert genome position bounds to sample index range (multiple of 200)
    # collect the datapoints that have the same point
    print("done in: %s" % (time.time() - start_time))
    return [hp,v]

# %%
agg1 = aggregate_chromosome("chr1", 11)
# Out:
# samples 1246254
# chromosome chr1 order 11
# genome 0 248956422
# hilbert 0 338117
# length 338117
# individual False
# done in: 2.274808883666992

# %%
agg1
# Out:
# [array([     0,      1,      2, ..., 338114, 338115, 338116]),
#  array([17, 17, 17, ..., 17, 17, 17])]

# %%
pq.write_table(pa.table({
    # "index": agg1[0], 
    "value": agg1[1]
}), "test_chr1_13.parquet", compression='gzip')

# %% [markdown]
# ## Generate parquet files

# %%
def write_parquet(chromosome, order):
    pfn = os.path.join(parquet_data_dir, chromosome + "_" + str(order) + ".parquet")
    agg = aggregate_chromosome(chromosome, order)
    table = {
        # "index": agg[0], 
        "value": agg[1],
    }
    pq.write_table(pa.table(table), pfn, compression='gzip')

# %%
from hilbertgenome.coalesce import coalesce_parquets

# %%
def combine(order):
    paths = [os.path.join(parquet_data_dir, (c + "_" + str(order) + ".parquet")) for c in genome.chromosomes]
    print(paths)
    coalesce_parquets(paths, os.path.join(parquet_data_dir,"order_" + str(order) + ".parquet"))

# %%
for o in range(5, 14):
# for o in range(5, 12):
    for c in genome.chromosomes:
        write_parquet(c, o)
    combine(o)
# Out:
# samples 1246254
# chromosome chr1 order 5
# genome 0 248956422
# hilbert 0 82
# length 82
# individual False
# done in: 0.22801518440246582
# samples 1215997
# chromosome chr2 order 5
# genome 248956422 491149951
# hilbert 82 162
# length 80
# individual False
# done in: 0.1953120231628418
# samples 990113
# chromosome chr3 order 5
# genome 491149951 689445510
# hilbert 162 228
# length 66
# individual False
# done in: 0.13689899444580078
# samples 955772
# chromosome chr4 order 5
# genome 689445510 879660065
# hilbert 228 291
# length 63
# individual False
# done in: 0.12675714492797852
# samples 904577
# chromosome chr5 order 5
# genome 879660065 1061198324
# hilbert 291 351
# length 60
# individual False
# done in: 0.11143302917480469
# samples 855576
# chromosome chr6 order 5
# genome 1061198324 1232004303
# hilbert 351 408
# length 57
# individual False
# done in: 0.11091017723083496
# samples 795694
# chromosome chr7 order 5
# genome 1232004303 1391350276
# hilbert 408 461
# length 53
# individual False
# done in: 0.14467406272888184
# samples 731821
# chromosome chr8 order 5
# genome 1391350276 1536488912
# hilbert 461 509
# length 48
# individual False
# done in: 0.12574195861816406
# samples 706068
# chromosome chr9 order 5
# genome 1536488912 1674883629
# hilbert 509 555
# length 46
# individual False
# done in: 0.19681525230407715
# samples 677674
# chromosome chr10 order 5
# genome 1674883629 1808681051
# hilbert 555 599
# length 44
# individual False
# done in: 0.10886597633361816
# samples 675033
# chromosome chr11 order 5
# genome 1808681051 1943767673
# hilbert 599 644
# length 45
# individual False
# done in: 0.11243820190429688
# samples 669260
# chromosome chr12 order 5
# genome 1943767673 2077042982
# hilbert 644 688
# length 44
# individual False
# done in: 0.1603987216949463
# samples 575850
# chromosome chr13 order 5
# genome 2077042982 2191407310
# hilbert 688 726
# length 38
# individual False
# done in: 0.07769989967346191
# samples 536748
# chromosome chr14 order 5
# genome 2191407310 2298451028
# hilbert 726 762
# length 36
# individual False
# done in: 0.09401106834411621
# samples 512657
# chromosome chr15 order 5
# genome 2298451028 2400442217
# hilbert 762 795
# length 33
# individual False
# done in: 0.0874929428100586
# samples 451774
# chromosome chr16 order 5
# genome 2400442217 2490780562
# hilbert 795 825
# length 30
# individual False
# done in: 0.06857609748840332
# samples 405977
# chromosome chr17 order 5
# genome 2490780562 2574038003
# hilbert 825 853
# length 28
# individual False
# done in: 0.08439493179321289
# samples 390387
# chromosome chr18 order 5
# genome 2574038003 2654411288
# hilbert 853 880
# length 27
# individual False
# done in: 0.046906232833862305
# samples 295645
# chromosome chr19 order 5
# genome 2654411288 2713028904
# hilbert 880 899
# length 19
# individual False
# done in: 0.05530977249145508
# samples 315128
# chromosome chr20 order 5
# genome 2713028904 2777473071
# hilbert 899 920
# length 21
# individual False
# done in: 0.06440091133117676
# samples 240650
# chromosome chr21 order 5
# genome 2777473071 2824183054
# hilbert 920 936
# length 16
# individual False
# done in: 0.06129574775695801
# samples 256523
# chromosome chr22 order 5
# genome 2824183054 2875001522
# hilbert 936 953
# length 17
# individual False
# done in: 0.03097987174987793
# samples 776353
# chromosome chrX order 5
# genome 2875001522 3031042417
# hilbert 953 1005
# length 52
# individual False
# done in: 0.11905407905578613
# samples 296868
# chromosome chrY order 5
# genome 3031042417 3088269832
# hilbert 1005 1024
# length 19
# individual False
# done in: 0.06110882759094238
# ['hilbert_genome_cooler_data/parquet_data/chr1_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_5.parquet']
# samples 1246254
# chromosome chr1 order 6
# genome 0 248956422
# hilbert 0 330
# length 330
# individual False
# done in: 0.07883501052856445
# samples 1215997
# chromosome chr2 order 6
# genome 248956422 491149951
# hilbert 330 651
# length 321
# individual False
# done in: 0.07329082489013672
# samples 990113
# chromosome chr3 order 6
# genome 491149951 689445510
# hilbert 651 914
# length 263
# individual False
# done in: 0.061578989028930664
# samples 955772
# chromosome chr4 order 6
# genome 689445510 879660065
# hilbert 914 1166
# length 252
# individual False
# done in: 0.059977054595947266
# samples 904577
# chromosome chr5 order 6
# genome 879660065 1061198324
# hilbert 1166 1407
# length 241
# individual False
# done in: 0.057096004486083984
# samples 855576
# chromosome chr6 order 6
# genome 1061198324 1232004303
# hilbert 1407 1634
# length 227
# individual False
# done in: 0.0542299747467041
# samples 795694
# chromosome chr7 order 6
# genome 1232004303 1391350276
# hilbert 1634 1845
# length 211
# individual False
# done in: 0.05111813545227051
# samples 731821
# chromosome chr8 order 6
# genome 1391350276 1536488912
# hilbert 1845 2037
# length 192
# individual False
# done in: 0.047753334045410156
# samples 706068
# chromosome chr9 order 6
# genome 1536488912 1674883629
# hilbert 2037 2221
# length 184
# individual False
# done in: 0.042691946029663086
# samples 677674
# chromosome chr10 order 6
# genome 1674883629 1808681051
# hilbert 2221 2398
# length 177
# individual False
# done in: 0.0410761833190918
# samples 675033
# chromosome chr11 order 6
# genome 1808681051 1943767673
# hilbert 2398 2578
# length 180
# individual False
# done in: 0.04147791862487793
# samples 669260
# chromosome chr12 order 6
# genome 1943767673 2077042982
# hilbert 2578 2754
# length 176
# individual False
# done in: 0.04112076759338379
# samples 575850
# chromosome chr13 order 6
# genome 2077042982 2191407310
# hilbert 2754 2906
# length 152
# individual False
# done in: 0.03534579277038574
# samples 536748
# chromosome chr14 order 6
# genome 2191407310 2298451028
# hilbert 2906 3048
# length 142
# individual False
# done in: 0.03372693061828613
# samples 512657
# chromosome chr15 order 6
# genome 2298451028 2400442217
# hilbert 3048 3183
# length 135
# individual False
# done in: 0.033799171447753906
# samples 451774
# chromosome chr16 order 6
# genome 2400442217 2490780562
# hilbert 3183 3303
# length 120
# individual False
# done in: 0.028954744338989258
# samples 405977
# chromosome chr17 order 6
# genome 2490780562 2574038003
# hilbert 3303 3413
# length 110
# individual False
# done in: 0.02497100830078125
# samples 390387
# chromosome chr18 order 6
# genome 2574038003 2654411288
# hilbert 3413 3520
# length 107
# individual False
# done in: 0.024122953414916992
# samples 295645
# chromosome chr19 order 6
# genome 2654411288 2713028904
# hilbert 3520 3598
# length 78
# individual False
# done in: 0.018175125122070312
# samples 315128
# chromosome chr20 order 6
# genome 2713028904 2777473071
# hilbert 3598 3683
# length 85
# individual False
# done in: 0.01964426040649414
# samples 240650
# chromosome chr21 order 6
# genome 2777473071 2824183054
# hilbert 3683 3745
# length 62
# individual False
# done in: 0.014098882675170898
# samples 256523
# chromosome chr22 order 6
# genome 2824183054 2875001522
# hilbert 3745 3813
# length 68
# individual False
# done in: 0.01549077033996582
# samples 776353
# chromosome chrX order 6
# genome 2875001522 3031042417
# hilbert 3813 4020
# length 207
# individual False
# done in: 0.04725384712219238
# samples 296868
# chromosome chrY order 6
# genome 3031042417 3088269832
# hilbert 4020 4096
# length 76
# individual False
# done in: 0.018667936325073242
# ['hilbert_genome_cooler_data/parquet_data/chr1_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_6.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_6.parquet']
# samples 1246254
# chromosome chr1 order 7
# genome 0 248956422
# hilbert 0 1320
# length 1320
# individual False
# done in: 0.08811306953430176
# samples 1215997
# chromosome chr2 order 7
# genome 248956422 491149951
# hilbert 1320 2605
# length 1285
# individual False
# done in: 0.08054089546203613
# samples 990113
# chromosome chr3 order 7
# genome 491149951 689445510
# hilbert 2605 3657
# length 1052
# individual False
# done in: 0.06731081008911133
# samples 955772
# chromosome chr4 order 7
# genome 689445510 879660065
# hilbert 3657 4666
# length 1009
# individual False
# done in: 0.06729817390441895
# samples 904577
# chromosome chr5 order 7
# genome 879660065 1061198324
# hilbert 4666 5629
# length 963
# individual False
# done in: 0.06038308143615723
# samples 855576
# chromosome chr6 order 7
# genome 1061198324 1232004303
# hilbert 5629 6536
# length 907
# individual False
# done in: 0.058145999908447266
# samples 795694
# chromosome chr7 order 7
# genome 1232004303 1391350276
# hilbert 6536 7381
# length 845
# individual False
# done in: 0.05358409881591797
# samples 731821
# chromosome chr8 order 7
# genome 1391350276 1536488912
# hilbert 7381 8151
# length 770
# individual False
# done in: 0.05056619644165039
# samples 706068
# chromosome chr9 order 7
# genome 1536488912 1674883629
# hilbert 8151 8885
# length 734
# individual False
# done in: 0.04796123504638672
# samples 677674
# chromosome chr10 order 7
# genome 1674883629 1808681051
# hilbert 8885 9595
# length 710
# individual False
# done in: 0.045989036560058594
# samples 675033
# chromosome chr11 order 7
# genome 1808681051 1943767673
# hilbert 9595 10312
# length 717
# individual False
# done in: 0.04557013511657715
# samples 669260
# chromosome chr12 order 7
# genome 1943767673 2077042982
# hilbert 10312 11019
# length 707
# individual False
# done in: 0.044938087463378906
# samples 575850
# chromosome chr13 order 7
# genome 2077042982 2191407310
# hilbert 11019 11625
# length 606
# individual False
# done in: 0.03964400291442871
# samples 536748
# chromosome chr14 order 7
# genome 2191407310 2298451028
# hilbert 11625 12193
# length 568
# individual False
# done in: 0.037973880767822266
# samples 512657
# chromosome chr15 order 7
# genome 2298451028 2400442217
# hilbert 12193 12734
# length 541
# individual False
# done in: 0.03521418571472168
# samples 451774
# chromosome chr16 order 7
# genome 2400442217 2490780562
# hilbert 12734 13214
# length 480
# individual False
# done in: 0.030643939971923828
# samples 405977
# chromosome chr17 order 7
# genome 2490780562 2574038003
# hilbert 13214 13655
# length 441
# individual False
# done in: 0.02754497528076172
# samples 390387
# chromosome chr18 order 7
# genome 2574038003 2654411288
# hilbert 13655 14082
# length 427
# individual False
# done in: 0.026506423950195312
# samples 295645
# chromosome chr19 order 7
# genome 2654411288 2713028904
# hilbert 14082 14393
# length 311
# individual False
# done in: 0.01970386505126953
# samples 315128
# chromosome chr20 order 7
# genome 2713028904 2777473071
# hilbert 14393 14735
# length 342
# individual False
# done in: 0.0213320255279541
# samples 240650
# chromosome chr21 order 7
# genome 2777473071 2824183054
# hilbert 14735 14982
# length 247
# individual False
# done in: 0.01634502410888672
# samples 256523
# chromosome chr22 order 7
# genome 2824183054 2875001522
# hilbert 14982 15252
# length 270
# individual False
# done in: 0.017635107040405273
# samples 776353
# chromosome chrX order 7
# genome 2875001522 3031042417
# hilbert 15252 16080
# length 828
# individual False
# done in: 0.05501914024353027
# samples 296868
# chromosome chrY order 7
# genome 3031042417 3088269832
# hilbert 16080 16384
# length 304
# individual False
# done in: 0.020625829696655273
# ['hilbert_genome_cooler_data/parquet_data/chr1_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_7.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_7.parquet']
# samples 1246254
# chromosome chr1 order 8
# genome 0 248956422
# hilbert 0 5283
# length 5283
# individual False
# done in: 0.11381793022155762
# samples 1215997
# chromosome chr2 order 8
# genome 248956422 491149951
# hilbert 5283 10422
# length 5139
# individual False
# done in: 0.11229491233825684
# samples 990113
# chromosome chr3 order 8
# genome 491149951 689445510
# hilbert 10422 14630
# length 4208
# individual False
# done in: 0.09163403511047363
# samples 955772
# chromosome chr4 order 8
# genome 689445510 879660065
# hilbert 14630 18667
# length 4037
# individual False
# done in: 0.0880119800567627
# samples 904577
# chromosome chr5 order 8
# genome 879660065 1061198324
# hilbert 18667 22519
# length 3852
# individual False
# done in: 0.08631396293640137
# samples 855576
# chromosome chr6 order 8
# genome 1061198324 1232004303
# hilbert 22519 26144
# length 3625
# individual False
# done in: 0.07889008522033691
# samples 795694
# chromosome chr7 order 8
# genome 1232004303 1391350276
# hilbert 26144 29525
# length 3381
# individual False
# done in: 0.07333207130432129
# samples 731821
# chromosome chr8 order 8
# genome 1391350276 1536488912
# hilbert 29525 32605
# length 3080
# individual False
# done in: 0.06830310821533203
# samples 706068
# chromosome chr9 order 8
# genome 1536488912 1674883629
# hilbert 32605 35542
# length 2937
# individual False
# done in: 0.06754899024963379
# samples 677674
# chromosome chr10 order 8
# genome 1674883629 1808681051
# hilbert 35542 38381
# length 2839
# individual False
# done in: 0.06249284744262695
# samples 675033
# chromosome chr11 order 8
# genome 1808681051 1943767673
# hilbert 38381 41248
# length 2867
# individual False
# done in: 0.06321001052856445
# samples 669260
# chromosome chr12 order 8
# genome 1943767673 2077042982
# hilbert 41248 44076
# length 2828
# individual False
# done in: 0.06573009490966797
# samples 575850
# chromosome chr13 order 8
# genome 2077042982 2191407310
# hilbert 44076 46503
# length 2427
# individual False
# done in: 0.05297398567199707
# samples 536748
# chromosome chr14 order 8
# genome 2191407310 2298451028
# hilbert 46503 48775
# length 2272
# individual False
# done in: 0.049757957458496094
# samples 512657
# chromosome chr15 order 8
# genome 2298451028 2400442217
# hilbert 48775 50939
# length 2164
# individual False
# done in: 0.04732680320739746
# samples 451774
# chromosome chr16 order 8
# genome 2400442217 2490780562
# hilbert 50939 52856
# length 1917
# individual False
# done in: 0.041564226150512695
# samples 405977
# chromosome chr17 order 8
# genome 2490780562 2574038003
# hilbert 52856 54623
# length 1767
# individual False
# done in: 0.039263010025024414
# samples 390387
# chromosome chr18 order 8
# genome 2574038003 2654411288
# hilbert 54623 56329
# length 1706
# individual False
# done in: 0.03679203987121582
# samples 295645
# chromosome chr19 order 8
# genome 2654411288 2713028904
# hilbert 56329 57573
# length 1244
# individual False
# done in: 0.02726006507873535
# samples 315128
# chromosome chr20 order 8
# genome 2713028904 2777473071
# hilbert 57573 58940
# length 1367
# individual False
# done in: 0.02920675277709961
# samples 240650
# chromosome chr21 order 8
# genome 2777473071 2824183054
# hilbert 58940 59931
# length 991
# individual False
# done in: 0.021595001220703125
# samples 256523
# chromosome chr22 order 8
# genome 2824183054 2875001522
# hilbert 59931 61010
# length 1079
# individual False
# done in: 0.023648977279663086
# samples 776353
# chromosome chrX order 8
# genome 2875001522 3031042417
# hilbert 61010 64321
# length 3311
# individual False
# done in: 0.07393479347229004
# samples 296868
# chromosome chrY order 8
# genome 3031042417 3088269832
# hilbert 64321 65536
# length 1215
# individual False
# done in: 0.027449846267700195
# ['hilbert_genome_cooler_data/parquet_data/chr1_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_8.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_8.parquet']
# samples 1246254
# chromosome chr1 order 9
# genome 0 248956422
# hilbert 0 21132
# length 21132
# individual False
# done in: 0.2255110740661621
# samples 1215997
# chromosome chr2 order 9
# genome 248956422 491149951
# hilbert 21132 41690
# length 20558
# individual False
# done in: 0.21035099029541016
# samples 990113
# chromosome chr3 order 9
# genome 491149951 689445510
# hilbert 41690 58522
# length 16832
# individual False
# done in: 0.17494726181030273
# samples 955772
# chromosome chr4 order 9
# genome 689445510 879660065
# hilbert 58522 74668
# length 16146
# individual False
# done in: 0.17532706260681152
# samples 904577
# chromosome chr5 order 9
# genome 879660065 1061198324
# hilbert 74668 90078
# length 15410
# individual False
# done in: 0.15748381614685059
# samples 855576
# chromosome chr6 order 9
# genome 1061198324 1232004303
# hilbert 90078 104577
# length 14499
# individual False
# done in: 0.15963435173034668
# samples 795694
# chromosome chr7 order 9
# genome 1232004303 1391350276
# hilbert 104577 118103
# length 13526
# individual False
# done in: 0.14009594917297363
# samples 731821
# chromosome chr8 order 9
# genome 1391350276 1536488912
# hilbert 118103 130422
# length 12319
# individual False
# done in: 0.13275599479675293
# samples 706068
# chromosome chr9 order 9
# genome 1536488912 1674883629
# hilbert 130422 142170
# length 11748
# individual False
# done in: 0.12195372581481934
# samples 677674
# chromosome chr10 order 9
# genome 1674883629 1808681051
# hilbert 142170 153527
# length 11357
# individual False
# done in: 0.12029004096984863
# samples 675033
# chromosome chr11 order 9
# genome 1808681051 1943767673
# hilbert 153527 164994
# length 11467
# individual False
# done in: 0.11893916130065918
# samples 669260
# chromosome chr12 order 9
# genome 1943767673 2077042982
# hilbert 164994 176307
# length 11313
# individual False
# done in: 0.11949706077575684
# samples 575850
# chromosome chr13 order 9
# genome 2077042982 2191407310
# hilbert 176307 186014
# length 9707
# individual False
# done in: 0.10258293151855469
# samples 536748
# chromosome chr14 order 9
# genome 2191407310 2298451028
# hilbert 186014 195101
# length 9087
# individual False
# done in: 0.09464406967163086
# samples 512657
# chromosome chr15 order 9
# genome 2298451028 2400442217
# hilbert 195101 203758
# length 8657
# individual False
# done in: 0.09467816352844238
# samples 451774
# chromosome chr16 order 9
# genome 2400442217 2490780562
# hilbert 203758 211426
# length 7668
# individual False
# done in: 0.07958817481994629
# samples 405977
# chromosome chr17 order 9
# genome 2490780562 2574038003
# hilbert 211426 218494
# length 7068
# individual False
# done in: 0.0712130069732666
# samples 390387
# chromosome chr18 order 9
# genome 2574038003 2654411288
# hilbert 218494 225316
# length 6822
# individual False
# done in: 0.0706479549407959
# samples 295645
# chromosome chr19 order 9
# genome 2654411288 2713028904
# hilbert 225316 230292
# length 4976
# individual False
# done in: 0.05265522003173828
# samples 315128
# chromosome chr20 order 9
# genome 2713028904 2777473071
# hilbert 230292 235762
# length 5470
# individual False
# done in: 0.05637407302856445
# samples 240650
# chromosome chr21 order 9
# genome 2777473071 2824183054
# hilbert 235762 239727
# length 3965
# individual False
# done in: 0.0408320426940918
# samples 256523
# chromosome chr22 order 9
# genome 2824183054 2875001522
# hilbert 239727 244040
# length 4313
# individual False
# done in: 0.04448080062866211
# samples 776353
# chromosome chrX order 9
# genome 2875001522 3031042417
# hilbert 244040 257286
# length 13246
# individual False
# done in: 0.15028905868530273
# samples 296868
# chromosome chrY order 9
# genome 3031042417 3088269832
# hilbert 257286 262144
# length 4858
# individual False
# done in: 0.05142617225646973
# ['hilbert_genome_cooler_data/parquet_data/chr1_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_9.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_9.parquet']
# samples 1246254
# chromosome chr1 order 10
# genome 0 248956422
# hilbert 0 84529
# length 84529
# individual False
# done in: 0.635977029800415
# samples 1215997
# chromosome chr2 order 10
# genome 248956422 491149951
# hilbert 84529 166762
# length 82233
# individual False
# done in: 0.6084916591644287
# samples 990113
# chromosome chr3 order 10
# genome 491149951 689445510
# hilbert 166762 234090
# length 67328
# individual False
# done in: 0.5029871463775635
# samples 955772
# chromosome chr4 order 10
# genome 689445510 879660065
# hilbert 234090 298675
# length 64585
# individual False
# done in: 0.48076295852661133
# samples 904577
# chromosome chr5 order 10
# genome 879660065 1061198324
# hilbert 298675 360314
# length 61639
# individual False
# done in: 0.4665968418121338
# samples 855576
# chromosome chr6 order 10
# genome 1061198324 1232004303
# hilbert 360314 418308
# length 57994
# individual False
# done in: 0.4532160758972168
# samples 795694
# chromosome chr7 order 10
# genome 1232004303 1391350276
# hilbert 418308 472412
# length 54104
# individual False
# done in: 0.41609811782836914
# samples 731821
# chromosome chr8 order 10
# genome 1391350276 1536488912
# hilbert 472412 521691
# length 49279
# individual False
# done in: 0.38627004623413086
# samples 706068
# chromosome chr9 order 10
# genome 1536488912 1674883629
# hilbert 521691 568681
# length 46990
# individual False
# done in: 0.3676259517669678
# samples 677674
# chromosome chr10 order 10
# genome 1674883629 1808681051
# hilbert 568681 614110
# length 45429
# individual False
# done in: 0.3519101142883301
# samples 675033
# chromosome chr11 order 10
# genome 1808681051 1943767673
# hilbert 614110 659977
# length 45867
# individual False
# done in: 0.35230493545532227
# samples 669260
# chromosome chr12 order 10
# genome 1943767673 2077042982
# hilbert 659977 705228
# length 45251
# individual False
# done in: 0.346405029296875
# samples 575850
# chromosome chr13 order 10
# genome 2077042982 2191407310
# hilbert 705228 744059
# length 38831
# individual False
# done in: 0.2995138168334961
# samples 536748
# chromosome chr14 order 10
# genome 2191407310 2298451028
# hilbert 744059 780404
# length 36345
# individual False
# done in: 0.2783639430999756
# samples 512657
# chromosome chr15 order 10
# genome 2298451028 2400442217
# hilbert 780404 815034
# length 34630
# individual False
# done in: 0.26272010803222656
# samples 451774
# chromosome chr16 order 10
# genome 2400442217 2490780562
# hilbert 815034 845707
# length 30673
# individual False
# done in: 0.2339940071105957
# samples 405977
# chromosome chr17 order 10
# genome 2490780562 2574038003
# hilbert 845707 873976
# length 28269
# individual False
# done in: 0.21500802040100098
# samples 390387
# chromosome chr18 order 10
# genome 2574038003 2654411288
# hilbert 873976 901265
# length 27289
# individual False
# done in: 0.20365691184997559
# samples 295645
# chromosome chr19 order 10
# genome 2654411288 2713028904
# hilbert 901265 921168
# length 19903
# individual False
# done in: 0.15235114097595215
# samples 315128
# chromosome chr20 order 10
# genome 2713028904 2777473071
# hilbert 921168 943049
# length 21881
# individual False
# done in: 0.17376017570495605
# samples 240650
# chromosome chr21 order 10
# genome 2777473071 2824183054
# hilbert 943049 958909
# length 15860
# individual False
# done in: 0.1210031509399414
# samples 256523
# chromosome chr22 order 10
# genome 2824183054 2875001522
# hilbert 958909 976163
# length 17254
# individual False
# done in: 0.1358201503753662
# samples 776353
# chromosome chrX order 10
# genome 2875001522 3031042417
# hilbert 976163 1029145
# length 52982
# individual False
# done in: 0.427440881729126
# samples 296868
# chromosome chrY order 10
# genome 3031042417 3088269832
# hilbert 1029145 1048576
# length 19431
# individual False
# done in: 0.14962124824523926
# ['hilbert_genome_cooler_data/parquet_data/chr1_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_10.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_10.parquet']
# samples 1246254
# chromosome chr1 order 11
# genome 0 248956422
# hilbert 0 338117
# length 338117
# individual False
# done in: 2.246259927749634
# samples 1215997
# chromosome chr2 order 11
# genome 248956422 491149951
# hilbert 338117 667050
# length 328933
# individual False
# done in: 2.2114529609680176
# samples 990113
# chromosome chr3 order 11
# genome 491149951 689445510
# hilbert 667050 936363
# length 269313
# individual False
# done in: 1.8346478939056396
# samples 955772
# chromosome chr4 order 11
# genome 689445510 879660065
# hilbert 936363 1194701
# length 258338
# individual False
# done in: 1.7941722869873047
# samples 904577
# chromosome chr5 order 11
# genome 879660065 1061198324
# hilbert 1194701 1441256
# length 246555
# individual False
# done in: 1.719787836074829
# samples 855576
# chromosome chr6 order 11
# genome 1061198324 1232004303
# hilbert 1441256 1673234
# length 231978
# individual False
# done in: 1.600766897201538
# samples 795694
# chromosome chr7 order 11
# genome 1232004303 1391350276
# hilbert 1673234 1889649
# length 216415
# individual False
# done in: 1.5051162242889404
# samples 731821
# chromosome chr8 order 11
# genome 1391350276 1536488912
# hilbert 1889649 2086767
# length 197118
# individual False
# done in: 1.374479055404663
# samples 706068
# chromosome chr9 order 11
# genome 1536488912 1674883629
# hilbert 2086767 2274727
# length 187960
# individual False
# done in: 1.300649881362915
# samples 677674
# chromosome chr10 order 11
# genome 1674883629 1808681051
# hilbert 2274727 2456442
# length 181715
# individual False
# done in: 1.2482280731201172
# samples 675033
# chromosome chr11 order 11
# genome 1808681051 1943767673
# hilbert 2456442 2639909
# length 183467
# individual False
# done in: 1.2531492710113525
# samples 669260
# chromosome chr12 order 11
# genome 1943767673 2077042982
# hilbert 2639909 2820915
# length 181006
# individual False
# done in: 1.235020637512207
# samples 575850
# chromosome chr13 order 11
# genome 2077042982 2191407310
# hilbert 2820915 2976238
# length 155323
# individual False
# done in: 1.0795040130615234
# samples 536748
# chromosome chr14 order 11
# genome 2191407310 2298451028
# hilbert 2976238 3121619
# length 145381
# individual False
# done in: 1.019834041595459
# samples 512657
# chromosome chr15 order 11
# genome 2298451028 2400442217
# hilbert 3121619 3260137
# length 138518
# individual False
# done in: 0.9624810218811035
# samples 451774
# chromosome chr16 order 11
# genome 2400442217 2490780562
# hilbert 3260137 3382829
# length 122692
# individual False
# done in: 0.8710520267486572
# samples 405977
# chromosome chr17 order 11
# genome 2490780562 2574038003
# hilbert 3382829 3495904
# length 113075
# individual False
# done in: 0.773219108581543
# samples 390387
# chromosome chr18 order 11
# genome 2574038003 2654411288
# hilbert 3495904 3605063
# length 109159
# individual False
# done in: 0.7606189250946045
# samples 295645
# chromosome chr19 order 11
# genome 2654411288 2713028904
# hilbert 3605063 3684674
# length 79611
# individual False
# done in: 0.5623078346252441
# samples 315128
# chromosome chr20 order 11
# genome 2713028904 2777473071
# hilbert 3684674 3772198
# length 87524
# individual False
# done in: 0.6086881160736084
# samples 240650
# chromosome chr21 order 11
# genome 2777473071 2824183054
# hilbert 3772198 3835637
# length 63439
# individual False
# done in: 0.4503822326660156
# samples 256523
# chromosome chr22 order 11
# genome 2824183054 2875001522
# hilbert 3835637 3904655
# length 69018
# individual False
# done in: 0.47582006454467773
# samples 776353
# chromosome chrX order 11
# genome 2875001522 3031042417
# hilbert 3904655 4116581
# length 211926
# individual False
# done in: 1.4688210487365723
# samples 296868
# chromosome chrY order 11
# genome 3031042417 3088269832
# hilbert 4116581 4194304
# length 77723
# individual False
# done in: 0.541384220123291
# ['hilbert_genome_cooler_data/parquet_data/chr1_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_11.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_11.parquet']
# samples 1246254
# chromosome chr1 order 12
# genome 0 248956422
# hilbert 0 1352471
# length 1352471
# individual True
# done in: 3.5260119438171387
# samples 1215997
# chromosome chr2 order 12
# genome 248956422 491149951
# hilbert 1352471 2668202
# length 1315731
# individual True
# done in: 3.6063621044158936
# samples 990113
# chromosome chr3 order 12
# genome 491149951 689445510
# hilbert 2668202 3745455
# length 1077253
# individual True
# done in: 2.98905611038208
# samples 955772
# chromosome chr4 order 12
# genome 689445510 879660065
# hilbert 3745455 4778807
# length 1033352
# individual True
# done in: 3.0115981101989746
# samples 904577
# chromosome chr5 order 12
# genome 879660065 1061198324
# hilbert 4778807 5765025
# length 986218
# individual True
# done in: 2.9374148845672607
# samples 855576
# chromosome chr6 order 12
# genome 1061198324 1232004303
# hilbert 5765025 6692939
# length 927914
# individual True
# done in: 2.9592339992523193
# samples 795694
# chromosome chr7 order 12
# genome 1232004303 1391350276
# hilbert 6692939 7558596
# length 865657
# individual True
# done in: 2.793489933013916
# samples 731821
# chromosome chr8 order 12
# genome 1391350276 1536488912
# hilbert 7558596 8347070
# length 788474
# individual True
# done in: 2.311433792114258
# samples 706068
# chromosome chr9 order 12
# genome 1536488912 1674883629
# hilbert 8347070 9098908
# length 751838
# individual True
# done in: 2.188890218734741
# samples 677674
# chromosome chr10 order 12
# genome 1674883629 1808681051
# hilbert 9098908 9825771
# length 726863
# individual True
# done in: 2.1508140563964844
# samples 675033
# chromosome chr11 order 12
# genome 1808681051 1943767673
# hilbert 9825771 10559637
# length 733866
# individual True
# done in: 2.1358048915863037
# samples 669260
# chromosome chr12 order 12
# genome 1943767673 2077042982
# hilbert 10559637 11283663
# length 724026
# individual True
# done in: 2.17116117477417
# samples 575850
# chromosome chr13 order 12
# genome 2077042982 2191407310
# hilbert 11283663 11904955
# length 621292
# individual True
# done in: 1.8100941181182861
# samples 536748
# chromosome chr14 order 12
# genome 2191407310 2298451028
# hilbert 11904955 12486476
# length 581521
# individual True
# done in: 1.6642990112304688
# samples 512657
# chromosome chr15 order 12
# genome 2298451028 2400442217
# hilbert 12486476 13040550
# length 554074
# individual True
# done in: 1.5954198837280273
# samples 451774
# chromosome chr16 order 12
# genome 2400442217 2490780562
# hilbert 13040550 13531318
# length 490768
# individual True
# done in: 1.4310531616210938
# samples 405977
# chromosome chr17 order 12
# genome 2490780562 2574038003
# hilbert 13531318 13983619
# length 452301
# individual True
# done in: 1.3089160919189453
# samples 390387
# chromosome chr18 order 12
# genome 2574038003 2654411288
# hilbert 13983619 14420252
# length 436633
# individual True
# done in: 1.2457170486450195
# samples 295645
# chromosome chr19 order 12
# genome 2654411288 2713028904
# hilbert 14420252 14738696
# length 318444
# individual True
# done in: 0.910330057144165
# samples 315128
# chromosome chr20 order 12
# genome 2713028904 2777473071
# hilbert 14738696 15088793
# length 350097
# individual True
# done in: 1.007143259048462
# samples 240650
# chromosome chr21 order 12
# genome 2777473071 2824183054
# hilbert 15088793 15342548
# length 253755
# individual True
# done in: 0.7207469940185547
# samples 256523
# chromosome chr22 order 12
# genome 2824183054 2875001522
# hilbert 15342548 15618622
# length 276074
# individual True
# done in: 0.813122034072876
# samples 776353
# chromosome chrX order 12
# genome 2875001522 3031042417
# hilbert 15618622 16466324
# length 847702
# individual True
# done in: 2.4374639987945557
# samples 296868
# chromosome chrY order 12
# genome 3031042417 3088269832
# hilbert 16466324 16777216
# length 310892
# individual True
# done in: 0.8974997997283936
# ['hilbert_genome_cooler_data/parquet_data/chr1_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_12.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_12.parquet']
# samples 1246254
# chromosome chr1 order 13
# genome 0 248956422
# hilbert 0 5409884
# length 5409884
# individual True
# done in: 14.454028129577637
# samples 1215997
# chromosome chr2 order 13
# genome 248956422 491149951
# hilbert 5409884 10672809
# length 5262925
# individual True
# done in: 14.740015029907227
# samples 990113
# chromosome chr3 order 13
# genome 491149951 689445510
# hilbert 10672809 14981820
# length 4309011
# individual True
# done in: 11.563521146774292
# samples 955772
# chromosome chr4 order 13
# genome 689445510 879660065
# hilbert 14981820 19115229
# length 4133409
# individual True
# done in: 11.502116918563843
# samples 904577
# chromosome chr5 order 13
# genome 879660065 1061198324
# hilbert 19115229 23060100
# length 3944871
# individual True
# done in: 11.018712997436523
# samples 855576
# chromosome chr6 order 13
# genome 1061198324 1232004303
# hilbert 23060100 26771756
# length 3711656
# individual True
# done in: 10.354384899139404
# samples 795694
# chromosome chr7 order 13
# genome 1232004303 1391350276
# hilbert 26771756 30234384
# length 3462628
# individual True
# done in: 9.555432319641113
# samples 731821
# chromosome chr8 order 13
# genome 1391350276 1536488912
# hilbert 30234384 33388282
# length 3153898
# individual True
# done in: 8.721851110458374
# samples 706068
# chromosome chr9 order 13
# genome 1536488912 1674883629
# hilbert 33388282 36395633
# length 3007351
# individual True
# done in: 8.291478872299194
# samples 677674
# chromosome chr10 order 13
# genome 1674883629 1808681051
# hilbert 36395633 39303084
# length 2907451
# individual True
# done in: 8.024194240570068
# samples 675033
# chromosome chr11 order 13
# genome 1808681051 1943767673
# hilbert 39303084 42238550
# length 2935466
# individual True
# done in: 8.055574178695679
# samples 669260
# chromosome chr12 order 13
# genome 1943767673 2077042982
# hilbert 42238550 45134655
# length 2896105
# individual True
# done in: 7.9133570194244385
# samples 575850
# chromosome chr13 order 13
# genome 2077042982 2191407310
# hilbert 45134655 47619820
# length 2485165
# individual True
# done in: 6.9262402057647705
# samples 536748
# chromosome chr14 order 13
# genome 2191407310 2298451028
# hilbert 47619820 49945906
# length 2326086
# individual True
# done in: 6.486814022064209
# samples 512657
# chromosome chr15 order 13
# genome 2298451028 2400442217
# hilbert 49945906 52162200
# length 2216294
# individual True
# done in: 6.208042144775391
# samples 451774
# chromosome chr16 order 13
# genome 2400442217 2490780562
# hilbert 52162200 54125275
# length 1963075
# individual True
# done in: 5.437325954437256
# samples 405977
# chromosome chr17 order 13
# genome 2490780562 2574038003
# hilbert 54125275 55934479
# length 1809204
# individual True
# done in: 4.9481401443481445
# samples 390387
# chromosome chr18 order 13
# genome 2574038003 2654411288
# hilbert 55934479 57681011
# length 1746532
# individual True
# done in: 4.813538074493408
# samples 295645
# chromosome chr19 order 13
# genome 2654411288 2713028904
# hilbert 57681011 58954786
# length 1273775
# individual True
# done in: 3.4792399406433105
# samples 315128
# chromosome chr20 order 13
# genome 2713028904 2777473071
# hilbert 58954786 60355173
# length 1400387
# individual True
# done in: 3.8902039527893066
# samples 240650
# chromosome chr21 order 13
# genome 2777473071 2824183054
# hilbert 60355173 61370193
# length 1015020
# individual True
# done in: 2.787947177886963
# samples 256523
# chromosome chr22 order 13
# genome 2824183054 2875001522
# hilbert 61370193 62474491
# length 1104298
# individual True
# done in: 2.9904260635375977
# samples 776353
# chromosome chrX order 13
# genome 2875001522 3031042417
# hilbert 62474491 65865298
# length 3390807
# individual True
# done in: 9.374361038208008
# samples 296868
# chromosome chrY order 13
# genome 3031042417 3088269832
# hilbert 65865298 67108864
# length 1243566
# individual True
# done in: 3.399247169494629
# ['hilbert_genome_cooler_data/parquet_data/chr1_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_13.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_13.parquet']

# %%
# this will take a while
for o in range(14, 17):
    for c in genome.chromosomes:
        write_parquet(c, o)
    combine(o)
# Out:
# chromosome chr1 order 14
# genome 0 248956422
# hilbert 0 21639537
# length 21639537
# samples 1246254
# done in: 55.57538604736328
# chromosome chr2 order 14
# genome 248956422 491149951
# hilbert 21639537 42691237
# length 21051700
# samples 1215997
# done in: 53.453176975250244
# chromosome chr3 order 14
# genome 491149951 689445510
# hilbert 42691237 59927282
# length 17236045
# samples 990113
# done in: 43.61011290550232
# chromosome chr4 order 14
# genome 689445510 879660065
# hilbert 59927282 76460919
# length 16533637
# samples 955772
# done in: 43.18458390235901
# chromosome chr5 order 14
# genome 879660065 1061198324
# hilbert 76460919 92240403
# length 15779484
# samples 904577
# done in: 41.49327898025513
# chromosome chr6 order 14
# genome 1061198324 1232004303
# hilbert 92240403 107087027
# length 14846624
# samples 855576
# done in: 39.69519782066345
# chromosome chr7 order 14
# genome 1232004303 1391350276
# hilbert 107087027 120937536
# length 13850509
# samples 795694
# done in: 36.93603491783142
# chromosome chr8 order 14
# genome 1391350276 1536488912
# hilbert 120937536 133553129
# length 12615593
# samples 731821
# done in: 33.64228582382202
# chromosome chr9 order 14
# genome 1536488912 1674883629
# hilbert 133553129 145582534
# length 12029405
# samples 706068
# done in: 32.74801683425903
# chromosome chr10 order 14
# genome 1674883629 1808681051
# hilbert 145582534 157212338
# length 11629804
# samples 677674
# done in: 30.89502191543579
# chromosome chr11 order 14
# genome 1808681051 1943767673
# hilbert 157212338 168954200
# length 11741862
# samples 675033
# done in: 30.809612035751343
# chromosome chr12 order 14
# genome 1943767673 2077042982
# hilbert 168954200 180538622
# length 11584422
# samples 669260
# done in: 30.868088722229004
# chromosome chr13 order 14
# genome 2077042982 2191407310
# hilbert 180538622 190479282
# length 9940660
# samples 575850
# done in: 26.554851055145264
# chromosome chr14 order 14
# genome 2191407310 2298451028
# hilbert 190479282 199783627
# length 9304345
# samples 536748
# done in: 24.700143814086914
# chromosome chr15 order 14
# genome 2298451028 2400442217
# hilbert 199783627 208648802
# length 8865175
# samples 512657
# done in: 23.30322289466858
# chromosome chr16 order 14
# genome 2400442217 2490780562
# hilbert 208648802 216501100
# length 7852298
# samples 451774
# done in: 20.98725199699402
# chromosome chr17 order 14
# genome 2490780562 2574038003
# hilbert 216501100 223737918
# length 7236818
# samples 405977
# done in: 19.49946689605713
# chromosome chr18 order 14
# genome 2574038003 2654411288
# hilbert 223737918 230724044
# length 6986126
# samples 390387
# done in: 19.096235990524292
# chromosome chr19 order 14
# genome 2654411288 2713028904
# hilbert 230724044 235819144
# length 5095100
# samples 295645
# done in: 13.501117944717407
# chromosome chr20 order 14
# genome 2713028904 2777473071
# hilbert 235819144 241420695
# length 5601551
# samples 315128
# done in: 14.897510290145874
# chromosome chr21 order 14
# genome 2777473071 2824183054
# hilbert 241420695 245480773
# length 4060078
# samples 240650
# done in: 10.924565076828003
# chromosome chr22 order 14
# genome 2824183054 2875001522
# hilbert 245480773 249897964
# length 4417191
# samples 256523
# done in: 11.825094938278198
# chromosome chrX order 14
# genome 2875001522 3031042417
# hilbert 249897964 263461192
# length 13563228
# samples 776353
# done in: 36.108004093170166
# chromosome chrY order 14
# genome 3031042417 3088269832
# hilbert 263461192 268435456
# length 4974264
# samples 296868
# done in: 13.062144041061401
# ['chr1_14.parquet', 'chr2_14.parquet', 'chr3_14.parquet', 'chr4_14.parquet', 'chr5_14.parquet', 'chr6_14.parquet', 'chr7_14.parquet', 'chr8_14.parquet', 'chr9_14.parquet', 'chr10_14.parquet', 'chr11_14.parquet', 'chr12_14.parquet', 'chr13_14.parquet', 'chr14_14.parquet', 'chr15_14.parquet', 'chr16_14.parquet', 'chr17_14.parquet', 'chr18_14.parquet', 'chr19_14.parquet', 'chr20_14.parquet', 'chr21_14.parquet', 'chr22_14.parquet', 'chrX_14.parquet', 'chrY_14.parquet']
# chromosome chr1 order 15
# genome 0 248956422
# hilbert 0 86558149
# length 86558149
# samples 1246254
# done in: 220.41641807556152
# chromosome chr2 order 15
# genome 248956422 491149951
# hilbert 86558149 170764950
# length 84206801
# samples 1215997
# done in: 214.18885779380798
# chromosome chr3 order 15
# genome 491149951 689445510
# hilbert 170764950 239709131
# length 68944181
# samples 990113
# done in: 175.2343099117279
# chromosome chr4 order 15
# genome 689445510 879660065
# hilbert 239709131 305843677
# length 66134546
# samples 955772
# done in: 169.4146330356598
# chromosome chr5 order 15
# genome 879660065 1061198324
# hilbert 305843677 368961614
# length 63117937
# samples 904577
# done in: 162.75835800170898
# chromosome chr6 order 15
# genome 1061198324 1232004303
# hilbert 368961614 428348110
# length 59386496
# samples 855576
# done in: 159.57573199272156
# chromosome chr7 order 15
# genome 1232004303 1391350276
# hilbert 428348110 483750146
# length 55402036
# samples 795694
# done in: 150.1441900730133
# chromosome chr8 order 15
# genome 1391350276 1536488912
# hilbert 483750146 534212519
# length 50462373
# samples 731821
# done in: 132.8312520980835
# chromosome chr9 order 15
# genome 1536488912 1674883629
# hilbert 534212519 582330139
# length 48117620
# samples 706068
# done in: 126.08613896369934
# chromosome chr10 order 15
# genome 1674883629 1808681051
# hilbert 582330139 628849354
# length 46519215
# samples 677674
# done in: 121.40321516990662
# chromosome chr11 order 15
# genome 1808681051 1943767673
# hilbert 628849354 675816803
# length 46967449
# samples 675033
# done in: 122.47648620605469
# chromosome chr12 order 15
# genome 1943767673 2077042982
# hilbert 675816803 722154488
# length 46337685
# samples 669260
# done in: 120.72427105903625
# chromosome chr13 order 15
# genome 2077042982 2191407310
# hilbert 722154488 761917128
# length 39762640
# samples 575850
# done in: 105.90322828292847
# chromosome chr14 order 15
# genome 2191407310 2298451028
# hilbert 761917128 799134510
# length 37217382
# samples 536748
# done in: 1030.9203369617462
# chromosome chr15 order 15
# genome 2298451028 2400442217
# hilbert 799134510 834595208
# length 35460698
# samples 512657
# done in: 92.62697911262512
# chromosome chr16 order 15
# genome 2400442217 2490780562
# hilbert 834595208 866004400
# length 31409192
# samples 451774
# done in: 82.15000987052917
# chromosome chr17 order 15
# genome 2490780562 2574038003
# hilbert 866004400 894951675
# length 28947275
# samples 405977
# done in: 75.56400799751282
# chromosome chr18 order 15
# genome 2574038003 2654411288
# hilbert 894951675 922896176
# length 27944501
# samples 390387
# done in: 73.15709376335144
# chromosome chr19 order 15
# genome 2654411288 2713028904
# hilbert 922896176 943276579
# length 20380403
# samples 295645
# done in: 53.46446895599365
# chromosome chr20 order 15
# genome 2713028904 2777473071
# hilbert 943276579 965682781
# length 22406202
# samples 315128
# done in: 58.74816298484802
# chromosome chr21 order 15
# genome 2777473071 2824183054
# hilbert 965682781 981923092
# length 16240311
# samples 240650
# done in: 41.92209601402283
# chromosome chr22 order 15
# genome 2824183054 2875001522
# hilbert 981923092 999591857
# length 17668765
# samples 256523
# done in: 46.28410506248474
# chromosome chrX order 15
# genome 2875001522 3031042417
# hilbert 999591857 1053844770
# length 54252913
# samples 776353
# done in: 151.04093074798584
# chromosome chrY order 15
# genome 3031042417 3088269832
# hilbert 1053844770 1073741824
# length 19897054
# samples 296868
# done in: 213.66583704948425
# ['chr1_15.parquet', 'chr2_15.parquet', 'chr3_15.parquet', 'chr4_15.parquet', 'chr5_15.parquet', 'chr6_15.parquet', 'chr7_15.parquet', 'chr8_15.parquet', 'chr9_15.parquet', 'chr10_15.parquet', 'chr11_15.parquet', 'chr12_15.parquet', 'chr13_15.parquet', 'chr14_15.parquet', 'chr15_15.parquet', 'chr16_15.parquet', 'chr17_15.parquet', 'chr18_15.parquet', 'chr19_15.parquet', 'chr20_15.parquet', 'chr21_15.parquet', 'chr22_15.parquet', 'chrX_15.parquet', 'chrY_15.parquet']
# chromosome chr1 order 16
# genome 0 248956422
# hilbert 0 346232599
# length 346232599
# samples 1246254
# done in: 13499.487573862076
# chromosome chr2 order 16
# genome 248956422 491149951
# hilbert 346232599 683059801
# length 336827202
# samples 1215997
# done in: 15388.34305715561
# chromosome chr3 order 16
# genome 491149951 689445510
# hilbert 683059801 958836526
# length 275776725
# samples 990113
# done in: 1648.8900711536407
# chromosome chr4 order 16
# genome 689445510 879660065
# hilbert 958836526 1223374710
# length 264538184
# samples 955772
# done in: 577.60125207901
# chromosome chr5 order 16
# genome 879660065 1061198324
# hilbert 1223374710 1475846459
# length 252471749
# samples 904577
# done in: 554.6817569732666
# chromosome chr6 order 16
# genome 1061198324 1232004303
# hilbert 1475846459 1713392442
# length 237545983
# samples 855576
# done in: 523.9524297714233
# chromosome chr7 order 16
# genome 1232004303 1391350276
# hilbert 1713392442 1935000585
# length 221608143
# samples 795694
# done in: 4193.353150844574
# chromosome chr8 order 16
# genome 1391350276 1536488912
# hilbert 1935000585 2136850077
# length 201849492
# samples 731821
# done in: 446.4800748825073
# chromosome chr9 order 16
# genome 1536488912 1674883629
# hilbert 2136850077 2329320559
# length 192470482
# samples 706068
# done in: 424.7898647785187
# chromosome chr10 order 16
# genome 1674883629 1808681051
# hilbert 2329320559 2515397418
# length 186076859
# samples 677674
# done in: 413.3677101135254
# chromosome chr11 order 16
# genome 1808681051 1943767673
# hilbert 2515397418 2703267215
# length 187869797
# samples 675033
# done in: 416.712571144104
# chromosome chr12 order 16
# genome 1943767673 2077042982
# hilbert 2703267215 2888617953
# length 185350738
# samples 669260
# done in: 412.031898021698
# chromosome chr13 order 16
# genome 2077042982 2191407310
# hilbert 2888617953 3047668514
# length 159050561
# samples 575850
# done in: 354.28405714035034
# chromosome chr14 order 16
# genome 2191407310 2298451028
# hilbert 3047668514 3196538040
# length 148869526
# samples 536748
# done in: 332.33447885513306
# chromosome chr15 order 16
# genome 2298451028 2400442217
# hilbert 3196538040 3338380834
# length 141842794
# samples 512657
# done in: 313.5896909236908
# chromosome chr16 order 16
# genome 2400442217 2490780562
# hilbert 3338380834 3464017601
# length 125636767
# samples 451774
# done in: 280.3888199329376
# chromosome chr17 order 16
# genome 2490780562 2574038003
# hilbert 3464017601 3579806702
# length 115789101
# samples 405977
# done in: 258.1199369430542
# chromosome chr18 order 16
# genome 2574038003 2654411288
# hilbert 3579806702 3691584704
# length 111778002
# samples 390387
# done in: 1231.9378089904785
# chromosome chr19 order 16
# genome 2654411288 2713028904
# hilbert 3691584704 3773106318
# length 81521614
# samples 295645
# done in: 179.9536530971527
# chromosome chr20 order 16
# genome 2713028904 2777473071
# hilbert 3773106318 3862731126
# length 89624808
# samples 315128
# done in: 198.07986688613892
# chromosome chr21 order 16
# genome 2777473071 2824183054
# hilbert 3862731126 3927692370
# length 64961244
# samples 240650
# done in: 144.2008719444275
# chromosome chr22 order 16
# genome 2824183054 2875001522
# hilbert 3927692370 3998367431
# length 70675061
# samples 256523
# done in: 156.79219675064087
# chromosome chrX order 16
# genome 2875001522 3031042417
# hilbert 3998367431 4215379083
# length 217011652
# samples 776353
# done in: 478.62061500549316
# chromosome chrY order 16
# genome 3031042417 3088269832
# hilbert 4215379083 4294967296
# length 79588213
# samples 296868
# done in: 176.66773128509521
# ['chr1_16.parquet', 'chr2_16.parquet', 'chr3_16.parquet', 'chr4_16.parquet', 'chr5_16.parquet', 'chr6_16.parquet', 'chr7_16.parquet', 'chr8_16.parquet', 'chr9_16.parquet', 'chr10_16.parquet', 'chr11_16.parquet', 'chr12_16.parquet', 'chr13_16.parquet', 'chr14_16.parquet', 'chr15_16.parquet', 'chr16_16.parquet', 'chr17_16.parquet', 'chr18_16.parquet', 'chr19_16.parquet', 'chr20_16.parquet', 'chr21_16.parquet', 'chr22_16.parquet', 'chrX_16.parquet', 'chrY_16.parquet']

# %%
# %timeit
combine(5)
# Out:
# ['hilbert_genome_cooler_data/parquet_data/chr1_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr2_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr3_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr4_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr5_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr6_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr7_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr8_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr9_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr10_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr11_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr12_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr13_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr14_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr15_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr16_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr17_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr18_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr19_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr20_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr21_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chr22_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chrX_5.parquet', 'hilbert_genome_cooler_data/parquet_data/chrY_5.parquet']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[56], line 1
# ----> 1 combine(5)
#
# Cell In[55], line 4, in combine(order)
#       2 paths = [os.path.join(parquet_data_dir, (c + "_" + str(order) + ".parquet")) for c in genome.chromosomes]
#       3 print(paths)
# ----> 4 coalesce_parquets(paths, "order_" + str(order) + ".parquet")
#
# Cell In[53], line 74, in coalesce_parquets(paths, outpath, max_size)
#      72 table_groups = coalesce(tables, max_size)
#      73 coalesced_tables = (pa.concat_tables(group) for group in table_groups)
# ---> 74 stream_to_parquet(outpath, coalesced_tables)
#
# Cell In[53], line 17, in stream_to_parquet(path, tables)
#      15 def stream_to_parquet(path: Path, tables: Iterable[pa.Table]) -> None:
#      16     try:
# ---> 17         first = next(tables)
#      18     except StopIteration:
#      19         return
#
# Cell In[53], line 73, in <genexpr>(.0)
#      69 # Instead of coalescing using number of rows as your metric, you could
#      70 # use pa.Table.nbytes or something.
#      71 # table_groups = coalesce(tables, max_size, sizer=lambda t: t.nbytes)
#      72 table_groups = coalesce(tables, max_size)
# ---> 73 coalesced_tables = (pa.concat_tables(group) for group in table_groups)
#      74 stream_to_parquet(outpath, coalesced_tables)
#
# Cell In[53], line 55, in coalesce(items, max_size, sizer)
#      53 batch = []
#      54 current_size = 0
# ---> 55 for item in items:
#      56     this_size = sizer(item)
#      57     if current_size + this_size > max_size:
#
# Cell In[53], line 36, in stream_from_parquets(paths)
#      34 def stream_from_parquets(paths: Iterable[Path]) -> Iterable[pa.Table]:
#      35     for path in paths:
# ---> 36         yield from stream_from_parquet(path)
#
# Cell In[53], line 29, in stream_from_parquet(path)
#      28 def stream_from_parquet(path: Path) -> Iterable[pa.Table]:
# ---> 29     reader = pq.ParquetFile(path)
#      30     for batch in reader.iter_batches():
#      31         yield pa.Table.from_batches([batch])
#
# File /opt/miniconda3/envs/altius/lib/python3.9/site-packages/pyarrow/parquet/core.py:308, in ParquetFile.__init__(self, source, metadata, common_metadata, read_dictionary, memory_map, buffer_size, pre_buffer, coerce_int96_timestamp_unit, decryption_properties, thrift_string_size_limit, thrift_container_size_limit)
#     302 def __init__(self, source, *, metadata=None, common_metadata=None,
#     303              read_dictionary=None, memory_map=False, buffer_size=0,
#     304              pre_buffer=False, coerce_int96_timestamp_unit=None,
#     305              decryption_properties=None, thrift_string_size_limit=None,
#     306              thrift_container_size_limit=None):
#     307     self.reader = ParquetReader()
# --> 308     self.reader.open(
#     309         source, use_memory_map=memory_map,
#     310         buffer_size=buffer_size, pre_buffer=pre_buffer,
#     311         read_dictionary=read_dictionary, metadata=metadata,
#     312         coerce_int96_timestamp_unit=coerce_int96_timestamp_unit,
#     313         decryption_properties=decryption_properties,
#     314         thrift_string_size_limit=thrift_string_size_limit,
#     315         thrift_container_size_limit=thrift_container_size_limit,
#     316     )
#     317     self._close_source = getattr(source, 'closed', True)
#     318     self.common_metadata = common_metadata
#
# File /opt/miniconda3/envs/altius/lib/python3.9/site-packages/pyarrow/_parquet.pyx:1224, in pyarrow._parquet.ParquetReader.open()
#
# File /opt/miniconda3/envs/altius/lib/python3.9/site-packages/pyarrow/io.pxi:1761, in pyarrow.lib.get_reader()
#
# File /opt/miniconda3/envs/altius/lib/python3.9/site-packages/pyarrow/io.pxi:1752, in pyarrow.lib.get_native_file()
#
# File /opt/miniconda3/envs/altius/lib/python3.9/site-packages/pyarrow/io.pxi:995, in pyarrow.lib.OSFile.__cinit__()
#
# File /opt/miniconda3/envs/altius/lib/python3.9/site-packages/pyarrow/io.pxi:1005, in pyarrow.lib.OSFile._open_readable()
#
# File /opt/miniconda3/envs/altius/lib/python3.9/site-packages/pyarrow/error.pxi:144, in pyarrow.lib.pyarrow_internal_check_status()
#
# File /opt/miniconda3/envs/altius/lib/python3.9/site-packages/pyarrow/error.pxi:113, in pyarrow.lib.check_status()
#
# FileNotFoundError: [Errno 2] Failed to open local file 'hilbert_genome_cooler_data/parquet_data/chr1_5.parquet'. Detail: [errno 2] No such file or directory

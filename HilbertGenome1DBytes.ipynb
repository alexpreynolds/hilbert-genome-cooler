# %%
import os
import json
import gzip
import time
import math
import hilbert
import pyarrow
import pandas as pd
import numpy as np
import pyarrow as pa
import pyarrow.parquet as pq

# %% [markdown]
# ## Prepare the signal data

# %%
chromosomes_to_exclude = ['chrY']

# %%
# setup the data directory if it doesn't already exist
data_dir = 'hilbert_genome_cooler_data'
if not os.path.exists(data_dir): 
    os.makedirs(data_dir)

# %%
# setup the data directory if it doesn't already exist
bytes_data_dir = 'hilbert_genome_cooler_data/bytes_data'
if not os.path.exists(bytes_data_dir): 
    os.makedirs(bytes_data_dir)

# %%
signal_categories = 18
input_signal_NA_category_value = signal_categories - 1

# %%
# Get the data file and store it locally
#
# ref. /net/seq/data/projects/Epilogos
#          /multivec-for-browser-2022-redo/epilogos_tracks/single/human
#          /Boix_et_al_833_sample/hg19/18/All_833_biosamples/S1/scores.txt.filledGap.versionSorted.txt.gz
#
signal_remote_URI = 'https://resources.altius.org/~areynolds/public/Boix_et_al_833_sample.hg19.18.All_833_biosamples.S1.scores.txt.gz'
signal_local_fn = os.path.join(data_dir, 'Boix_et_al_833_sample.hg19.18.All_833_biosamples.S1.scores.txt.gz')

# %%
if not os.path.exists(signal_local_fn):
    try:
        r = requests.get(signal_remote_URI)
        with open(signal_local_fn, "wb") as ofh:
            b = io.BytesIO(r.content)
            ofh.write(b.getbuffer())
    except requests.exceptions.RequestException as e:
        raise SystemExit(e)

# %%
input_signal_dir = os.path.split(os.path.abspath(signal_local_fn))[0]

# %%
def generate_categorical_data(ifn):
    signals = {}
    signals['__all'] = []
    with gzip.open(ifn, 'rb') as ifh:
        for line in ifh:
            elems = line.decode().rstrip().split('\t')
            chromosome = elems[0]
            signal = np.array([float(x) for x in elems[3:]])
            if chromosome not in signals:
                signals[chromosome] = []
            if chromosome not in chromosomes_to_exclude:
                signals[chromosome].append({'argmax': np.argmax(signal), 'sum': np.sum(signal)})
                signals['__all'].append({'argmax': np.argmax(signal), 'sum': np.sum(signal)})
            else:
                signals[chromosome].append({'argmax': input_signal_NA_category_value, 'sum': 0})
                signals['__all'].append({'argmax': input_signal_NA_category_value, 'sum': 0})
    return signals

# %%
def generate_categorical_data_file(ofn, categorical_data):
    with gzip.open(ofn, 'wb') as ofh:
        categorical_data_json = json.dumps(categorical_data, cls=NumpyEncoder)
        ofh.write(categorical_data_json.encode())

# %%
class NumpyEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        if isinstance(obj, np.bool_):
            return bool(obj)
        return super(NumpyEncoder, self).default(obj)

# %%
categorical_data_fn = os.path.join(data_dir,'{}.categorical_data.json.gz'.format(os.path.basename(signal_local_fn)))

# %%
if not os.path.exists(categorical_data_fn):
    categorical_data = generate_categorical_data(signal_local_fn)
    generate_categorical_data_file(categorical_data_fn, categorical_data)
else:
    with gzip.open(categorical_data_fn, 'rb') as ifh:
        categorical_data = json.load(ifh)

# %% [markdown]
# ## Hilbert Genome

# %%
import hilbertgenome.chromsizes

# %%
genome = hilbertgenome.chromsizes["hg38"]

# %%
genome.total_size
# Out:
# 3088269832

# %%
maxOrder = 16 # 16 is the order that can contain the full genome

# %%
pow(4, maxOrder)
# Out:
# 4294967296

# %%
# convert a hilbert position from one order to another
def hilbert_pos_to_order(pos, fro, to):
    return math.floor(pos / pow(4, fro - to))

# %%
# spread our genome positions evenly across the 16th order hilbert curve
def spread_scale(gpos):
    i_min = 0
    i_max = genome.total_size
    o_min = 0
    o_max = pow(4, maxOrder)
    return round(o_min + (gpos - i_min) * ((o_max - o_min) / (i_max - i_min)))

# %%
# get the genome position for a given hilbert position (may return duplicates)
def spread_scale_invert(pos):
    i_min = 0
    i_max = genome.total_size
    o_min = 0
    o_max = pow(4, maxOrder)
    return round((pos - o_min) / ((o_max - o_min) / (i_max - i_min)) + i_min)

# %%
# get the global genome position from something like "chr2:12345"
def get_genome_from_base(start):
    chr = start.split(":")[0]
    offset = int(start.split(":")[1])
    return genome.sizes_acc[chr] + offset

# %%
def get_hilbert_from_genome(gpos):
    return spread_scale(gpos)

# %%
def get_genome_from_hilbert(pos):
  gpos = spread_scale_invert(pos)
  if pos != spread_scale(gpos): 
    return None
  return gpos;

# %%
# get the first base at the maximum order resolution 
# that comes after the starting pos and before the next pos at the current order
def scan_spread(pos, order):
  if(order == maxOrder):
    return get_genome_from_hilbert(pos)
  start = hilbert_pos_to_order(pos, order, maxOrder)
  found = get_genome_from_hilbert(start)
  # need to scan everything at the highest order
  # but only until we find something which should usually happen in a few loops
  for l in range(pow(4, maxOrder - order)):
    if found is not None:
        return found
    found = get_genome_from_hilbert(start+l)

# %%
# get the last base at the maximum order resolution 
# that comes after the starting pos and before the next pos at the current order
def scan_spread_reverse(pos, order):
  start = hilbert_pos_to_order(pos+1, order, maxOrder) - 1
  found = get_genome_from_hilbert(start)
  # need to scan everything at the highest order
  # but only until we find something which should usually happen in a few loops
  for l in range(pow(4, maxOrder - order)):
    if found is not None:
        return found
    found = get_genome_from_hilbert(start-l)

# %%
def get_hilbert_genome_resolution(order):
    hpos = hilbert_pos_to_order(1, order, maxOrder)
    gpos = scan_spread_reverse(1, order)

# %%
scan_spread(0, 15)
# Out:
# 0

# %%
scan_spread_reverse(1, 15)
# Out:
# 5

# %%
# order 0 doesn't really make sense
hilbert_genome_resolutions = [scan_spread_reverse(0, o) + 1 for o in range(0, 17)]

# %%
hilbert_genome_resolutions
# Out:
# [3088269832,
#  772067458,
#  193016865,
#  48254216,
#  12063554,
#  3015889,
#  753972,
#  188493,
#  47123,
#  11781,
#  2945,
#  736,
#  184,
#  46,
#  12,
#  3,
#  1]

# %%
hilbert_genome_resolutions[8]
# Out:
# 47123

# %% [markdown]
# ## Aggregation

# %%
#find_maxvecsum_label = lambda x: x[np.argmax(np.array([i['sum'] for i in x]))]['argmax']
def aggregate(data):
    return data[np.argmax(np.array([i['sum'] for i in data]))]['argmax']
#     return sum([d['argmax'] for d in data])

# %%
def accessor(d):
    return d["argmax"]

# %%
signal_resolution = 200
# signal_resolution = 25000

# %%
def aggregate_range(chromosome, order, hstart, hstop, gstart, individual, dtype="int8"):
    print(chromosome, order, hstart, hstop, gstart, individual, dtype)
    #print("start", hstart, hstop)
    #start_time = time.time()
    samples = categorical_data[chromosome]
    nsamples = len(samples)
    #hp = Hilbert(order, hstart, hstop)
    hp = np.arange(hstart, hstop, dtype=np.int32)
    v = np.arange(hstart, hstop, dtype=np.dtype(dtype))
    print("len v", len(v))
    print("samples", nsamples)
    # loop over the hilbert points for this order
    # can get bounds in genome position
    for i, pos in enumerate(hp):
        # global genome pos
        gpos = scan_spread(pos, order)          
        # at order 16 we may get None values for individual hilbert coordinates
        if(gpos is None):
            v[i] = input_signal_NA_category_value
            continue
        
        # local position
        lpos = gpos - gstart                    
        if(lpos < 0):
            lpos = 0
        
        # the starting index in our sample
        datum_idx = round(lpos/signal_resolution)              
        
        if individual:
            # we have a single point, this will happen for higher orders
            # print("single data",  pos, lpos, slpos, datum_idx)
            if datum_idx >= nsamples:
                v[i] = input_signal_NA_category_value
                #print(i,pos,datum_idx)
            else:
                v[i] = accessor(samples[datum_idx])
        else:
            # we know multiple samples will fit in our hilbert cell
            # so we get the last genome pos in the hilbert cell
            sgpos = scan_spread_reverse(pos, order) # global genome pos           
            slpos = sgpos - gstart                  # local position
            sdatum_idx = round(slpos/signal_resolution)            #the ending index in our samples
            # we need to aggregate at lower orders
            # we grab all the samples from the starting index to the ending index
            data = samples[datum_idx:sdatum_idx+1]  # include the last sample
            # if there are no samples in our list, we save NA
            if(len(data) == 0):
                #print("aggregate data", pos, gpos, lpos, slpos, datum_idx, sdatum_idx, len(data))
                v[i] = input_signal_NA_category_value
            else:
                # we save the output of the user supplied aggregate function
                v[i] = aggregate(data)

    # can convert genome position bounds to sample index range (multiple of 200)
    # collect the datapoints that have the same point
    #print("done in: %s" % (time.time() - start_time))
    fn = aggregate_filename(chromosome, order, hstart, dtype)
    with open(fn, 'wb') as f:
        f.write(v.tobytes())
    #return [hp,v]

# %%
bed_data = {
    "chr1": [
        { 'start': 0, 'stop':25000, 'argmax': 1 },
        { 'start': 25001, 'stop':50000, 'argmax': 2 },
        { 'start': 50001, 'stop':75000, 'argmax': 3 },
        { 'start': 75001, 'stop':100000, 'argmax': 4 },
        { 'start': 125001, 'stop':150000, 'argmax': 5 },
        
        { 'start': 225001, 'stop':250000, 'argmax': 6 },
        { 'start': 250001, 'stop':275000, 'argmax': 7 },
    ]
}

# %%
bed_data["chr1"][2:]
# Out:
# [{'start': 50001, 'stop': 75000, 'argmax': 3},
#  {'start': 75001, 'stop': 100000, 'argmax': 4},
#  {'start': 125001, 'stop': 150000, 'argmax': 5},
#  {'start': 225001, 'stop': 250000, 'argmax': 6},
#  {'start': 250001, 'stop': 275000, 'argmax': 7}]

# %%
# Want an alternative "sampling" aggregate_range where we look up if the hilbert coordinate is within a BED file range
# could filter down the "samples" that overlap with the hilbert region before iterating
# again we will have the case where there are many samples in one hilbert index
# or that we are a tiny hilbert index hitting the same sample over and over
# the above code assumes coverage of whole chromosome by samples, but we want to search regions
# this does assume that regions dont overlap and are sorted
def aggregate_range_region(chromosome, order, hstart, hstop, gstart, individual, dtype="int8"):
    print(chromosome, order, hstart, hstop, gstart, individual, dtype)

    # each sample will have a start, stop and some value
    samples = bed_data[chromosome]
    # nsamples = len(samples)
    #hp = Hilbert(order, hstart, hstop)
    hp = np.arange(hstart, hstop, dtype=np.int32)
    v = np.arange(hstart, hstop, dtype=np.dtype(dtype))
    #print("len v", len(v))
    #print("samples", nsamples)
    # loop over the hilbert points for this order
    # can get bounds in genome position
    
    last_idx = 0
    for i, pos in enumerate(hp):
        # global genome pos
        gpos = scan_spread(pos, order)          
        # at order 16 we may get None values for individual hilbert coordinates
        if(gpos is None):
            v[i] = input_signal_NA_category_value
            continue
        
        # local position
        lpos = gpos - gstart                    
        if(lpos < 0):
            lpos = 0
        
        if individual:
            # our hilbert pos is smaller than the signal resolution
            # loop thru the samples
            found = False
            for idx,s in enumerate(samples[last_idx:]):
                if(lpos > s['start']):
                    # we are inside a sample
                    v[i] = accessor(samples[idx])
                    last_idx = idx
                    found = True
                    break
            if not found:
                v[i] = input_signal_NA_category_value
                    
        else:
            # we know multiple samples will fit in our hilbert cell
            # so we get the last genome pos in the hilbert cell
            sgpos = scan_spread_reverse(pos, order) # global genome pos           
            slpos = sgpos - gstart                  # local position stop
            
            # get the samples that fall within the hilbert range
            data = []
            print(lpos, slpos)
            for idx,s in enumerate(samples[last_idx:]):
                if(lpos <= s['start'] and slpos >= s['start']):
                    # our sample is inside the hilbert cell
                    data.append(s)
                    last_idx += 1
                if(lpos > s['stop']):
                    break
                    
            #print("data", data, pos, last_idx)
            # if there are no samples in our list, we save NA
            if(len(data) == 0):
                #print("aggregate data", pos, gpos, lpos, slpos, datum_idx, sdatum_idx, len(data))
                v[i] = input_signal_NA_category_value
            else:
                # we save the output of the user supplied aggregate function
                v[i] = aggregate(data)

    # can convert genome position bounds to sample index range (multiple of 200)
    # collect the datapoints that have the same point
    #print("done in: %s" % (time.time() - start_time))
    
#     fn = aggregate_filename(chromosome, order, hstart, dtype)
#     with open(fn, 'wb') as f:
#         f.write(v.tobytes())
        
    return [hp,v]

# %%
files8 = files_for_order(8)
# Out:
# samples 1246254
# chromosome chr1 order 8
# genome 0 248956422
# hilbert 0 5283
# length 5283
# individual False
# samples 1215997
# chromosome chr2 order 8
# genome 248956422 491149951
# hilbert 5283 10422
# length 5139
# individual False
# samples 990113
# chromosome chr3 order 8
# genome 491149951 689445510
# hilbert 10422 14630
# length 4208
# individual False
# samples 955772
# chromosome chr4 order 8
# genome 689445510 879660065
# hilbert 14630 18667
# length 4037
# individual False
# samples 904577
# chromosome chr5 order 8
# genome 879660065 1061198324
# hilbert 18667 22519
# length 3852
# individual False
# samples 855576
# chromosome chr6 order 8
# genome 1061198324 1232004303
# hilbert 22519 26144
# length 3625
# individual False
# samples 795694
# chromosome chr7 order 8
# genome 1232004303 1391350276
# hilbert 26144 29525
# length 3381
# individual False
# samples 731821
# chromosome chr8 order 8
# genome 1391350276 1536488912
# hilbert 29525 32605
# length 3080
# individual False
# samples 706068
# chromosome chr9 order 8
# genome 1536488912 1674883629
# hilbert 32605 35542
# length 2937
# individual False
# samples 677674
# chromosome chr10 order 8
# genome 1674883629 1808681051
# hilbert 35542 38381
# length 2839
# individual False
# samples 675033
# chromosome chr11 order 8
# genome 1808681051 1943767673
# hilbert 38381 41248
# length 2867
# individual False
# samples 669260
# chromosome chr12 order 8
# genome 1943767673 2077042982
# hilbert 41248 44076
# length 2828
# individual False
# samples 575850
# chromosome chr13 order 8
# genome 2077042982 2191407310
# hilbert 44076 46503
# length 2427
# individual False
# samples 536748
# chromosome chr14 order 8
# genome 2191407310 2298451028
# hilbert 46503 48775
# length 2272
# individual False
# samples 512657
# chromosome chr15 order 8
# genome 2298451028 2400442217
# hilbert 48775 50939
# length 2164
# individual False
# samples 451774
# chromosome chr16 order 8
# genome 2400442217 2490780562
# hilbert 50939 52856
# length 1917
# individual False
# samples 405977
# chromosome chr17 order 8
# genome 2490780562 2574038003
# hilbert 52856 54623
# length 1767
# individual False
# samples 390387
# chromosome chr18 order 8
# genome 2574038003 2654411288
# hilbert 54623 56329
# length 1706
# individual False
# samples 295645
# chromosome chr19 order 8
# genome 2654411288 2713028904
# hilbert 56329 57573
# length 1244
# individual False
# samples 315128
# chromosome chr20 order 8
# genome 2713028904 2777473071
# hilbert 57573 58940
# length 1367
# individual False
# samples 240650
# chromosome chr21 order 8
# genome 2777473071 2824183054
# hilbert 58940 59931
# length 991
# individual False
# samples 256523
# chromosome chr22 order 8
# genome 2824183054 2875001522
# hilbert 59931 61010
# length 1079
# individual False
# samples 776353
# chromosome chrX order 8
# genome 2875001522 3031042417
# hilbert 61010 64321
# length 3311
# individual False
# samples 296868
# chromosome chrY order 8
# genome 3031042417 3088269832
# hilbert 64321 65536
# length 1215
# individual False

# %%
files8
# Out:
# [{'chromosome': 'chr1',
#   'order': 8,
#   'hstart': 0,
#   'hstop': 5283,
#   'gstart': 0,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr2',
#   'order': 8,
#   'hstart': 5283,
#   'hstop': 10422,
#   'gstart': 248956422,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr3',
#   'order': 8,
#   'hstart': 10422,
#   'hstop': 14630,
#   'gstart': 491149951,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr4',
#   'order': 8,
#   'hstart': 14630,
#   'hstop': 18667,
#   'gstart': 689445510,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr5',
#   'order': 8,
#   'hstart': 18667,
#   'hstop': 22519,
#   'gstart': 879660065,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr6',
#   'order': 8,
#   'hstart': 22519,
#   'hstop': 26144,
#   'gstart': 1061198324,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr7',
#   'order': 8,
#   'hstart': 26144,
#   'hstop': 29525,
#   'gstart': 1232004303,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr8',
#   'order': 8,
#   'hstart': 29525,
#   'hstop': 32605,
#   'gstart': 1391350276,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr9',
#   'order': 8,
#   'hstart': 32605,
#   'hstop': 35542,
#   'gstart': 1536488912,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr10',
#   'order': 8,
#   'hstart': 35542,
#   'hstop': 38381,
#   'gstart': 1674883629,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr11',
#   'order': 8,
#   'hstart': 38381,
#   'hstop': 41248,
#   'gstart': 1808681051,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr12',
#   'order': 8,
#   'hstart': 41248,
#   'hstop': 44076,
#   'gstart': 1943767673,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr13',
#   'order': 8,
#   'hstart': 44076,
#   'hstop': 46503,
#   'gstart': 2077042982,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr14',
#   'order': 8,
#   'hstart': 46503,
#   'hstop': 48775,
#   'gstart': 2191407310,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr15',
#   'order': 8,
#   'hstart': 48775,
#   'hstop': 50939,
#   'gstart': 2298451028,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr16',
#   'order': 8,
#   'hstart': 50939,
#   'hstop': 52856,
#   'gstart': 2400442217,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr17',
#   'order': 8,
#   'hstart': 52856,
#   'hstop': 54623,
#   'gstart': 2490780562,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr18',
#   'order': 8,
#   'hstart': 54623,
#   'hstop': 56329,
#   'gstart': 2574038003,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr19',
#   'order': 8,
#   'hstart': 56329,
#   'hstop': 57573,
#   'gstart': 2654411288,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr20',
#   'order': 8,
#   'hstart': 57573,
#   'hstop': 58940,
#   'gstart': 2713028904,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr21',
#   'order': 8,
#   'hstart': 58940,
#   'hstop': 59931,
#   'gstart': 2777473071,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chr22',
#   'order': 8,
#   'hstart': 59931,
#   'hstop': 61010,
#   'gstart': 2824183054,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chrX',
#   'order': 8,
#   'hstart': 61010,
#   'hstop': 64321,
#   'gstart': 2875001522,
#   'individual': False,
#   'dtype': 'int8'},
#  {'chromosome': 'chrY',
#   'order': 8,
#   'hstart': 64321,
#   'hstop': 65536,
#   'gstart': 3031042417,
#   'individual': False,
#   'dtype': 'int8'}]

# %%
agg = aggregate_range_region(**files8[0])
# Out:
# chr1 8 0 5283 0 False int8
# 0 47122
# data [{'start': 0, 'stop': 25000, 'argmax': 1}, {'start': 25001, 'stop': 50000, 'argmax': 2}] 0 2
# 47123 94246
# data [{'start': 50001, 'stop': 75000, 'argmax': 3}, {'start': 75001, 'stop': 100000, 'argmax': 4}] 1 4
# 94247 141369
# data [{'start': 125001, 'stop': 150000, 'argmax': 5}] 2 5
# 141370 188492
# data [] 3 5
# 188493 235615
# data [{'start': 225001, 'stop': 250000, 'argmax': 6}] 4 6
# 235616 282739
# data [{'start': 250001, 'stop': 275000, 'argmax': 7}] 5 7
# 282740 329862
# data [] 6 7
# 329863 376985
# data [] 7 7
# 376986 424108
# data [] 8 7
# 424109 471232
# data [] 9 7
# 471233 518355
# data [] 10 7
# 518356 565478
# data [] 11 7
# 565479 612601
# data [] 12 7
# 612602 659725
# data [] 13 7
# 659726 706848
# data [] 14 7
# 706849 753971
# data [] 15 7
# 753972 801095
# data [] 16 7
# 801096 848218
# data [] 17 7
# 848219 895341
# data [] 18 7
# 895342 942464
# data [] 19 7
# 942465 989588
# data [] 20 7
# 989589 1036711
# data [] 21 7
# 1036712 1083834
# data [] 22 7
# 1083835 1130957
# data [] 23 7
# 1130958 1178081
# data [] 24 7
# 1178082 1225204
# data [] 25 7
# 1225205 1272327
# data [] 26 7
# 1272328 1319450
# data [] 27 7
# 1319451 1366574
# data [] 28 7
# 1366575 1413697
# data [] 29 7
# 1413698 1460820
# data [] 30 7
# 1460821 1507943
# data [] 31 7
# 1507944 1555067
# data [] 32 7
# 1555068 1602190
# data [] 33 7
# 1602191 1649313
# data [] 34 7
# 1649314 1696436
# data [] 35 7
# 1696437 1743560
# data [] 36 7
# 1743561 1790683
# data [] 37 7
# 1790684 1837806
# data [] 38 7
# 1837807 1884929
# data [] 39 7
# 1884930 1932053
# data [] 40 7
# 1932054 1979176
# data [] 41 7
# 1979177 2026299
# data [] 42 7
# 2026300 2073422
# data [] 43 7
# 2073423 2120546
# data [] 44 7
# 2120547 2167669
# data [] 45 7
# 2167670 2214792
# data [] 46 7
# 2214793 2261916
# data [] 47 7
# 2261917 2309039
# data [] 48 7
# 2309040 2356162
# data [] 49 7
# 2356163 2403285
# data [] 50 7
# 2403286 2450409
# data [] 51 7
# 2450410 2497532
# data [] 52 7
# 2497533 2544655
# data [] 53 7
# 2544656 2591778
# data [] 54 7
# 2591779 2638902
# data [] 55 7
# 2638903 2686025
# data [] 56 7
# 2686026 2733148
# data [] 57 7
# 2733149 2780271
# data [] 58 7
# 2780272 2827395
# data [] 59 7
# 2827396 2874518
# data [] 60 7
# 2874519 2921641
# data [] 61 7
# 2921642 2968764
# data [] 62 7
# 2968765 3015888
# data [] 63 7
# 3015889 3063011
# data [] 64 7
# 3063012 3110134
# data [] 65 7
# 3110135 3157257
# data [] 66 7
# 3157258 3204381
# data [] 67 7
# 3204382 3251504
# data [] 68 7
# 3251505 3298627
# data [] 69 7
# 3298628 3345750
# data [] 70 7
# 3345751 3392874
# data [] 71 7
# 3392875 3439997
# data [] 72 7
# 3439998 3487120
# data [] 73 7
# 3487121 3534243
# data [] 74 7
# 3534244 3581367
# data [] 75 7
# 3581368 3628490
# data [] 76 7
# 3628491 3675613
# data [] 77 7
# 3675614 3722737
# data [] 78 7
# 3722738 3769860
# data [] 79 7
# 3769861 3816983
# data [] 80 7
# 3816984 3864106
# data [] 81 7
# 3864107 3911230
# data [] 82 7
# 3911231 3958353
# data [] 83 7
# 3958354 4005476
# data [] 84 7
# 4005477 4052599
# data [] 85 7
# 4052600 4099723
# data [] 86 7
# 4099724 4146846
# data [] 87 7
# 4146847 4193969
# data [] 88 7
# 4193970 4241092
# data [] 89 7
# 4241093 4288216
# data [] 90 7
# 4288217 4335339
# data [] 91 7
# 4335340 4382462
# data [] 92 7
# 4382463 4429585
# data [] 93 7
# 4429586 4476709
# data [] 94 7
# 4476710 4523832
# data [] 95 7
# 4523833 4570955
# data [] 96 7
# 4570956 4618078
# data [] 97 7
# 4618079 4665202
# data [] 98 7
# 4665203 4712325
# data [] 99 7
# 4712326 4759448
# data [] 100 7
# 4759449 4806571
# data [] 101 7
# 4806572 4853695
# data [] 102 7
# 4853696 4900818
# data [] 103 7
# 4900819 4947941
# data [] 104 7
# 4947942 4995064
# data [] 105 7
# 4995065 5042188
# data [] 106 7
# 5042189 5089311
# data [] 107 7
# 5089312 5136434
# data [] 108 7
# 5136435 5183558
# data [] 109 7
# 5183559 5230681
# data [] 110 7
# 5230682 5277804
# data [] 111 7
# 5277805 5324927
# data [] 112 7
# 5324928 5372051
# data [] 113 7
# 5372052 5419174
# data [] 114 7
# 5419175 5466297
# data [] 115 7
# 5466298 5513420
# data [] 116 7
# 5513421 5560544
# data [] 117 7
# 5560545 5607667
# data [] 118 7
# 5607668 5654790
# data [] 119 7
# 5654791 5701913
# data [] 120 7
# 5701914 5749037
# data [] 121 7
# 5749038 5796160
# data [] 122 7
# 5796161 5843283
# data [] 123 7
# 5843284 5890406
# data [] 124 7
# 5890407 5937530
# data [] 125 7
# 5937531 5984653
# data [] 126 7
# 5984654 6031776
# data [] 127 7
# 6031777 6078899
# data [] 128 7
# 6078900 6126023
# data [] 129 7
# 6126024 6173146
# data [] 130 7
# 6173147 6220269
# data [] 131 7
# 6220270 6267392
# data [] 132 7
# 6267393 6314516
# data [] 133 7
# 6314517 6361639
# data [] 134 7
# 6361640 6408762
# data [] 135 7
# 6408763 6455885
# data [] 136 7
# 6455886 6503009
# data [] 137 7
# 6503010 6550132
# data [] 138 7
# 6550133 6597255
# data [] 139 7
# 6597256 6644379
# data [] 140 7
# 6644380 6691502
# data [] 141 7
# 6691503 6738625
# data [] 142 7
# 6738626 6785748
# data [] 143 7
# 6785749 6832872
# data [] 144 7
# 6832873 6879995
# data [] 145 7
# 6879996 6927118
# data [] 146 7
# 6927119 6974241
# data [] 147 7
# 6974242 7021365
# data [] 148 7
# 7021366 7068488
# data [] 149 7
# 7068489 7115611
# data [] 150 7
# 7115612 7162734
# data [] 151 7
# 7162735 7209858
# data [] 152 7
# 7209859 7256981
# data [] 153 7
# 7256982 7304104
# data [] 154 7
# 7304105 7351227
# data [] 155 7
# 7351228 7398351
# data [] 156 7
# 7398352 7445474
# data [] 157 7
# 7445475 7492597
# data [] 158 7
# 7492598 7539720
# data [] 159 7
# 7539721 7586844
# data [] 160 7
# 7586845 7633967
# data [] 161 7
# 7633968 7681090
# data [] 162 7
# 7681091 7728213
# data [] 163 7
# 7728214 7775337
# data [] 164 7
# 7775338 7822460
# data [] 165 7
# 7822461 7869583
# data [] 166 7
# 7869584 7916706
# data [] 167 7
# 7916707 7963830
# data [] 168 7
# 7963831 8010953
# data [] 169 7
# 8010954 8058076
# data [] 170 7
# 8058077 8105200
# data [] 171 7
# 8105201 8152323
# data [] 172 7
# 8152324 8199446
# data [] 173 7
# 8199447 8246569
# data [] 174 7
# 8246570 8293693
# data [] 175 7
# 8293694 8340816
# data [] 176 7
# 8340817 8387939
# data [] 177 7
# 8387940 8435062
# data [] 178 7
# 8435063 8482186
# data [] 179 7
# 8482187 8529309
# data [] 180 7
# 8529310 8576432
# data [] 181 7
# 8576433 8623555
# data [] 182 7
# 8623556 8670679
# data [] 183 7
# 8670680 8717802
# data [] 184 7
# 8717803 8764925
# data [] 185 7
# 8764926 8812048
# data [] 186 7
# 8812049 8859172
# data [] 187 7
# 8859173 8906295
# data [] 188 7
# 8906296 8953418
# data [] 189 7
# 8953419 9000541
# data [] 190 7
# 9000542 9047665
# data [] 191 7
# 9047666 9094788
# data [] 192 7
# 9094789 9141911
# data [] 193 7
# 9141912 9189034
# data [] 194 7
# 9189035 9236158
# data [] 195 7
# 9236159 9283281
# data [] 196 7
# 9283282 9330404
# data [] 197 7
# 9330405 9377527
# data [] 198 7
# 9377528 9424651
# data [] 199 7
# 9424652 9471774
# data [] 200 7
# 9471775 9518897
# data [] 201 7
# 9518898 9566021
# data [] 202 7
# 9566022 9613144
# data [] 203 7
# 9613145 9660267
# data [] 204 7
# 9660268 9707390
# data [] 205 7
# 9707391 9754514
# data [] 206 7
# 9754515 9801637
# data [] 207 7
# 9801638 9848760
# data [] 208 7
# 9848761 9895883
# data [] 209 7
# 9895884 9943007
# data [] 210 7
# 9943008 9990130
# data [] 211 7
# 9990131 10037253
# data [] 212 7
# 10037254 10084376
# data [] 213 7
# 10084377 10131500
# data [] 214 7
# 10131501 10178623
# data [] 215 7
# 10178624 10225746
# data [] 216 7
# 10225747 10272869
# data [] 217 7
# 10272870 10319993
# data [] 218 7
# 10319994 10367116
# data [] 219 7
# 10367117 10414239
# data [] 220 7
# 10414240 10461362
# data [] 221 7
# 10461363 10508486
# data [] 222 7
# 10508487 10555609
# data [] 223 7
# 10555610 10602732
# data [] 224 7
# 10602733 10649855
# data [] 225 7
# 10649856 10696979
# data [] 226 7
# 10696980 10744102
# data [] 227 7
# 10744103 10791225
# data [] 228 7
# 10791226 10838348
# data [] 229 7
# 10838349 10885472
# data [] 230 7
# 10885473 10932595
# data [] 231 7
# 10932596 10979718
# data [] 232 7
# 10979719 11026841
# data [] 233 7
# 11026842 11073965
# data [] 234 7
# 11073966 11121088
# data [] 235 7
# 11121089 11168211
# data [] 236 7
# 11168212 11215335
# data [] 237 7
# 11215336 11262458
# data [] 238 7
# 11262459 11309581
# data [] 239 7
# 11309582 11356704
# data [] 240 7
# 11356705 11403828
# data [] 241 7
# 11403829 11450951
# data [] 242 7
# 11450952 11498074
# data [] 243 7
# 11498075 11545197
# data [] 244 7
# 11545198 11592321
# data [] 245 7
# 11592322 11639444
# data [] 246 7
# 11639445 11686567
# data [] 247 7
# 11686568 11733690
# data [] 248 7
# 11733691 11780814
# data [] 249 7
# 11780815 11827937
# data [] 250 7
# 11827938 11875060
# data [] 251 7
# 11875061 11922183
# data [] 252 7
# 11922184 11969307
# data [] 253 7
# 11969308 12016430
# data [] 254 7
# 12016431 12063553
# data [] 255 7
# 12063554 12110676
# data [] 256 7
# 12110677 12157800
# data [] 257 7
# 12157801 12204923
# data [] 258 7
# 12204924 12252046
# data [] 259 7
# 12252047 12299169
# data [] 260 7
# 12299170 12346293
# data [] 261 7
# 12346294 12393416
# data [] 262 7
# 12393417 12440539
# data [] 263 7
# 12440540 12487662
# data [] 264 7
# 12487663 12534786
# data [] 265 7
# 12534787 12581909
# data [] 266 7
# 12581910 12629032
# data [] 267 7
# 12629033 12676156
# data [] 268 7
# 12676157 12723279
# data [] 269 7
# 12723280 12770402
# data [] 270 7
# 12770403 12817525
# data [] 271 7
# 12817526 12864649
# data [] 272 7
# 12864650 12911772
# data [] 273 7
# 12911773 12958895
# data [] 274 7
# 12958896 13006018
# data [] 275 7
# 13006019 13053142
# data [] 276 7
# 13053143 13100265
# data [] 277 7
# 13100266 13147388
# data [] 278 7
# 13147389 13194511
# data [] 279 7
# 13194512 13241635
# data [] 280 7
# 13241636 13288758
# data [] 281 7
# 13288759 13335881
# data [] 282 7
# 13335882 13383004
# data [] 283 7
# 13383005 13430128
# data [] 284 7
# 13430129 13477251
# data [] 285 7
# 13477252 13524374
# data [] 286 7
# 13524375 13571497
# data [] 287 7
# 13571498 13618621
# data [] 288 7
# 13618622 13665744
# data [] 289 7
# 13665745 13712867
# data [] 290 7
# 13712868 13759990
# data [] 291 7
# 13759991 13807114
# data [] 292 7
# 13807115 13854237
# data [] 293 7
# 13854238 13901360
# data [] 294 7
# 13901361 13948483
# data [] 295 7
# 13948484 13995607
# data [] 296 7
# 13995608 14042730
# data [] 297 7
# 14042731 14089853
# data [] 298 7
# 14089854 14136977
# data [] 299 7
# 14136978 14184100
# data [] 300 7
# 14184101 14231223
# data [] 301 7
# 14231224 14278346
# data [] 302 7
# 14278347 14325470
# data [] 303 7
# 14325471 14372593
# data [] 304 7
# 14372594 14419716
# data [] 305 7
# 14419717 14466839
# data [] 306 7
# 14466840 14513963
# data [] 307 7
# 14513964 14561086
# data [] 308 7
# 14561087 14608209
# data [] 309 7
# 14608210 14655332
# data [] 310 7
# 14655333 14702456
# data [] 311 7
# 14702457 14749579
# data [] 312 7
# 14749580 14796702
# data [] 313 7
# 14796703 14843825
# data [] 314 7
# 14843826 14890949
# data [] 315 7
# 14890950 14938072
# data [] 316 7
# 14938073 14985195
# data [] 317 7
# 14985196 15032318
# data [] 318 7
# 15032319 15079442
# data [] 319 7
# 15079443 15126565
# data [] 320 7
# 15126566 15173688
# data [] 321 7
# 15173689 15220811
# data [] 322 7
# 15220812 15267935
# data [] 323 7
# 15267936 15315058
# data [] 324 7
# 15315059 15362181
# data [] 325 7
# 15362182 15409304
# data [] 326 7
# 15409305 15456428
# data [] 327 7
# 15456429 15503551
# data [] 328 7
# 15503552 15550674
# data [] 329 7
# 15550675 15597798
# data [] 330 7
# 15597799 15644921
# data [] 331 7
# 15644922 15692044
# data [] 332 7
# 15692045 15739167
# data [] 333 7
# 15739168 15786291
# data [] 334 7
# 15786292 15833414
# data [] 335 7
# 15833415 15880537
# data [] 336 7
# 15880538 15927660
# data [] 337 7
# 15927661 15974784
# data [] 338 7
# 15974785 16021907
# data [] 339 7
# 16021908 16069030
# data [] 340 7
# 16069031 16116153
# data [] 341 7
# 16116154 16163277
# data [] 342 7
# 16163278 16210400
# data [] 343 7
# 16210401 16257523
# data [] 344 7
# 16257524 16304646
# data [] 345 7
# 16304647 16351770
# data [] 346 7
# 16351771 16398893
# data [] 347 7
# 16398894 16446016
# data [] 348 7
# 16446017 16493139
# data [] 349 7
# 16493140 16540263
# data [] 350 7
# 16540264 16587386
# data [] 351 7
# 16587387 16634509
# data [] 352 7
# 16634510 16681632
# data [] 353 7
# 16681633 16728756
# data [] 354 7
# 16728757 16775879
# data [] 355 7
# 16775880 16823002
# data [] 356 7
# 16823003 16870125
# data [] 357 7
# 16870126 16917249
# data [] 358 7
# 16917250 16964372
# data [] 359 7
# 16964373 17011495
# data [] 360 7
# 17011496 17058619
# data [] 361 7
# 17058620 17105742
# data [] 362 7
# 17105743 17152865
# data [] 363 7
# 17152866 17199988
# data [] 364 7
# 17199989 17247112
# data [] 365 7
# 17247113 17294235
# data [] 366 7
# 17294236 17341358
# data [] 367 7
# 17341359 17388481
# data [] 368 7
# 17388482 17435605
# data [] 369 7
# 17435606 17482728
# data [] 370 7
# 17482729 17529851
# data [] 371 7
# 17529852 17576974
# data [] 372 7
# 17576975 17624098
# data [] 373 7
# 17624099 17671221
# data [] 374 7
# 17671222 17718344
# data [] 375 7
# 17718345 17765467
# data [] 376 7
# 17765468 17812591
# data [] 377 7
# 17812592 17859714
# data [] 378 7
# 17859715 17906837
# data [] 379 7
# 17906838 17953960
# data [] 380 7
# 17953961 18001084
# data [] 381 7
# 18001085 18048207
# data [] 382 7
# 18048208 18095330
# data [] 383 7
# 18095331 18142453
# data [] 384 7
# 18142454 18189577
# data [] 385 7
# 18189578 18236700
# data [] 386 7
# 18236701 18283823
# data [] 387 7
# 18283824 18330946
# data [] 388 7
# 18330947 18378070
# data [] 389 7
# 18378071 18425193
# data [] 390 7
# 18425194 18472316
# data [] 391 7
# 18472317 18519440
# data [] 392 7
# 18519441 18566563
# data [] 393 7
# 18566564 18613686
# data [] 394 7
# 18613687 18660809
# data [] 395 7
# 18660810 18707933
# data [] 396 7
# 18707934 18755056
# data [] 397 7
# 18755057 18802179
# data [] 398 7
# 18802180 18849302
# data [] 399 7
# 18849303 18896426
# data [] 400 7
# 18896427 18943549
# data [] 401 7
# 18943550 18990672
# data [] 402 7
# 18990673 19037795
# data [] 403 7
# 19037796 19084919
# data [] 404 7
# 19084920 19132042
# data [] 405 7
# 19132043 19179165
# data [] 406 7
# 19179166 19226288
# data [] 407 7
# 19226289 19273412
# data [] 408 7
# 19273413 19320535
# data [] 409 7
# 19320536 19367658
# data [] 410 7
# 19367659 19414781
# data [] 411 7
# 19414782 19461905
# data [] 412 7
# 19461906 19509028
# data [] 413 7
# 19509029 19556151
# data [] 414 7
# 19556152 19603274
# data [] 415 7
# 19603275 19650398
# data [] 416 7
# 19650399 19697521
# data [] 417 7
# 19697522 19744644
# data [] 418 7
# 19744645 19791767
# data [] 419 7
# 19791768 19838891
# data [] 420 7
# 19838892 19886014
# data [] 421 7
# 19886015 19933137
# data [] 422 7
# 19933138 19980261
# data [] 423 7
# 19980262 20027384
# data [] 424 7
# 20027385 20074507
# data [] 425 7
# 20074508 20121630
# data [] 426 7
# 20121631 20168754
# data [] 427 7
# 20168755 20215877
# data [] 428 7
# 20215878 20263000
# data [] 429 7
# 20263001 20310123
# data [] 430 7
# 20310124 20357247
# data [] 431 7
# 20357248 20404370
# data [] 432 7
# 20404371 20451493
# data [] 433 7
# 20451494 20498616
# data [] 434 7
# 20498617 20545740
# data [] 435 7
# 20545741 20592863
# data [] 436 7
# 20592864 20639986
# data [] 437 7
# 20639987 20687109
# data [] 438 7
# 20687110 20734233
# data [] 439 7
# 20734234 20781356
# data [] 440 7
# 20781357 20828479
# data [] 441 7
# 20828480 20875602
# data [] 442 7
# 20875603 20922726
# data [] 443 7
# 20922727 20969849
# data [] 444 7
# 20969850 21016972
# data [] 445 7
# 21016973 21064095
# data [] 446 7
# 21064096 21111219
# data [] 447 7
# 21111220 21158342
# data [] 448 7
# 21158343 21205465
# data [] 449 7
# 21205466 21252588
# data [] 450 7
# 21252589 21299712
# data [] 451 7
# 21299713 21346835
# data [] 452 7
# 21346836 21393958
# data [] 453 7
# 21393959 21441082
# data [] 454 7
# 21441083 21488205
# data [] 455 7
# 21488206 21535328
# data [] 456 7
# 21535329 21582451
# data [] 457 7
# 21582452 21629575
# data [] 458 7
# 21629576 21676698
# data [] 459 7
# 21676699 21723821
# data [] 460 7
# 21723822 21770944
# data [] 461 7
# 21770945 21818068
# data [] 462 7
# 21818069 21865191
# data [] 463 7
# 21865192 21912314
# data [] 464 7
# 21912315 21959437
# data [] 465 7
# 21959438 22006561
# data [] 466 7
# 22006562 22053684
# data [] 467 7
# 22053685 22100807
# data [] 468 7
# 22100808 22147930
# data [] 469 7
# 22147931 22195054
# data [] 470 7
# 22195055 22242177
# data [] 471 7
# 22242178 22289300
# data [] 472 7
# 22289301 22336423
# data [] 473 7
# 22336424 22383547
# data [] 474 7
# 22383548 22430670
# data [] 475 7
# 22430671 22477793
# data [] 476 7
# 22477794 22524916
# data [] 477 7
# 22524917 22572040
# data [] 478 7
# 22572041 22619163
# data [] 479 7
# 22619164 22666286
# data [] 480 7
# 22666287 22713409
# data [] 481 7
# 22713410 22760533
# data [] 482 7
# 22760534 22807656
# data [] 483 7
# 22807657 22854779
# data [] 484 7
# 22854780 22901902
# data [] 485 7
# 22901903 22949026
# data [] 486 7
# 22949027 22996149
# data [] 487 7
# 22996150 23043272
# data [] 488 7
# 23043273 23090396
# data [] 489 7
# 23090397 23137519
# data [] 490 7
# 23137520 23184642
# data [] 491 7
# 23184643 23231765
# data [] 492 7
# 23231766 23278889
# data [] 493 7
# 23278890 23326012
# data [] 494 7
# 23326013 23373135
# data [] 495 7
# 23373136 23420258
# data [] 496 7
# 23420259 23467382
# data [] 497 7
# 23467383 23514505
# data [] 498 7
# 23514506 23561628
# data [] 499 7
# 23561629 23608751
# data [] 500 7
# 23608752 23655875
# data [] 501 7
# 23655876 23702998
# data [] 502 7
# 23702999 23750121
# data [] 503 7
# 23750122 23797244
# data [] 504 7
# 23797245 23844368
# data [] 505 7
# 23844369 23891491
# data [] 506 7
# 23891492 23938614
# data [] 507 7
# 23938615 23985737
# data [] 508 7
# 23985738 24032861
# data [] 509 7
# 24032862 24079984
# data [] 510 7
# 24079985 24127107
# data [] 511 7
# 24127108 24174230
# data [] 512 7
# 24174231 24221354
# data [] 513 7
# 24221355 24268477
# data [] 514 7
# 24268478 24315600
# data [] 515 7
# 24315601 24362723
# data [] 516 7
# 24362724 24409847
# data [] 517 7
# 24409848 24456970
# data [] 518 7
# 24456971 24504093
# data [] 519 7
# 24504094 24551217
# data [] 520 7
# 24551218 24598340
# data [] 521 7
# 24598341 24645463
# data [] 522 7
# 24645464 24692586
# data [] 523 7
# 24692587 24739710
# data [] 524 7
# 24739711 24786833
# data [] 525 7
# 24786834 24833956
# data [] 526 7
# 24833957 24881079
# data [] 527 7
# 24881080 24928203
# data [] 528 7
# 24928204 24975326
# data [] 529 7
# 24975327 25022449
# data [] 530 7
# 25022450 25069572
# data [] 531 7
# 25069573 25116696
# data [] 532 7
# 25116697 25163819
# data [] 533 7
# 25163820 25210942
# data [] 534 7
# 25210943 25258065
# data [] 535 7
# 25258066 25305189
# data [] 536 7
# 25305190 25352312
# data [] 537 7
# 25352313 25399435
# data [] 538 7
# 25399436 25446558
# data [] 539 7
# 25446559 25493682
# data [] 540 7
# 25493683 25540805
# data [] 541 7
# 25540806 25587928
# data [] 542 7
# 25587929 25635051
# data [] 543 7
# 25635052 25682175
# data [] 544 7
# 25682176 25729298
# data [] 545 7
# 25729299 25776421
# data [] 546 7
# 25776422 25823544
# data [] 547 7
# 25823545 25870668
# data [] 548 7
# 25870669 25917791
# data [] 549 7
# 25917792 25964914
# data [] 550 7
# 25964915 26012038
# data [] 551 7
# 26012039 26059161
# data [] 552 7
# 26059162 26106284
# data [] 553 7
# 26106285 26153407
# data [] 554 7
# 26153408 26200531
# data [] 555 7
# 26200532 26247654
# data [] 556 7
# 26247655 26294777
# data [] 557 7
# 26294778 26341900
# data [] 558 7
# 26341901 26389024
# data [] 559 7
# 26389025 26436147
# data [] 560 7
# 26436148 26483270
# data [] 561 7
# 26483271 26530393
# data [] 562 7
# 26530394 26577517
# data [] 563 7
# 26577518 26624640
# data [] 564 7
# 26624641 26671763
# data [] 565 7
# 26671764 26718886
# data [] 566 7
# 26718887 26766010
# data [] 567 7
# 26766011 26813133
# data [] 568 7
# 26813134 26860256
# data [] 569 7
# 26860257 26907379
# data [] 570 7
# 26907380 26954503
# data [] 571 7
# 26954504 27001626
# data [] 572 7
# 27001627 27048749
# data [] 573 7
# 27048750 27095872
# data [] 574 7
# 27095873 27142996
# data [] 575 7
# 27142997 27190119
# data [] 576 7
# 27190120 27237242
# data [] 577 7
# 27237243 27284365
# data [] 578 7
# 27284366 27331489
# data [] 579 7
# 27331490 27378612
# data [] 580 7
# 27378613 27425735
# data [] 581 7
# 27425736 27472859
# data [] 582 7
# 27472860 27519982
# data [] 583 7
# 27519983 27567105
# data [] 584 7
# 27567106 27614228
# data [] 585 7
# 27614229 27661352
# data [] 586 7
# 27661353 27708475
# data [] 587 7
# 27708476 27755598
# data [] 588 7
# 27755599 27802721
# data [] 589 7
# 27802722 27849845
# data [] 590 7
# 27849846 27896968
# data [] 591 7
# 27896969 27944091
# data [] 592 7
# 27944092 27991214
# data [] 593 7
# 27991215 28038338
# data [] 594 7
# 28038339 28085461
# data [] 595 7
# 28085462 28132584
# data [] 596 7
# 28132585 28179707
# data [] 597 7
# 28179708 28226831
# data [] 598 7
# 28226832 28273954
# data [] 599 7
# 28273955 28321077
# data [] 600 7
# 28321078 28368200
# data [] 601 7
# 28368201 28415324
# data [] 602 7
# 28415325 28462447
# data [] 603 7
# 28462448 28509570
# data [] 604 7
# 28509571 28556693
# data [] 605 7
# 28556694 28603817
# data [] 606 7
# 28603818 28650940
# data [] 607 7
# 28650941 28698063
# data [] 608 7
# 28698064 28745186
# data [] 609 7
# 28745187 28792310
# data [] 610 7
# 28792311 28839433
# data [] 611 7
# 28839434 28886556
# data [] 612 7
# 28886557 28933680
# data [] 613 7
# 28933681 28980803
# data [] 614 7
# 28980804 29027926
# data [] 615 7
# 29027927 29075049
# data [] 616 7
# 29075050 29122173
# data [] 617 7
# 29122174 29169296
# data [] 618 7
# 29169297 29216419
# data [] 619 7
# 29216420 29263542
# data [] 620 7
# 29263543 29310666
# data [] 621 7
# 29310667 29357789
# data [] 622 7
# 29357790 29404912
# data [] 623 7
# 29404913 29452035
# data [] 624 7
# 29452036 29499159
# data [] 625 7
# 29499160 29546282
# data [] 626 7
# 29546283 29593405
# data [] 627 7
# 29593406 29640528
# data [] 628 7
# 29640529 29687652
# data [] 629 7
# 29687653 29734775
# data [] 630 7
# 29734776 29781898
# data [] 631 7
# 29781899 29829021
# data [] 632 7
# 29829022 29876145
# data [] 633 7
# 29876146 29923268
# data [] 634 7
# 29923269 29970391
# data [] 635 7
# 29970392 30017514
# data [] 636 7
# 30017515 30064638
# data [] 637 7
# 30064639 30111761
# data [] 638 7
# 30111762 30158884
# data [] 639 7
# 30158885 30206007
# data [] 640 7
# 30206008 30253131
# data [] 641 7
# 30253132 30300254
# data [] 642 7
# 30300255 30347377
# data [] 643 7
# 30347378 30394501
# data [] 644 7
# 30394502 30441624
# data [] 645 7
# 30441625 30488747
# data [] 646 7
# 30488748 30535870
# data [] 647 7
# 30535871 30582994
# data [] 648 7
# 30582995 30630117
# data [] 649 7
# 30630118 30677240
# data [] 650 7
# 30677241 30724363
# data [] 651 7
# 30724364 30771487
# data [] 652 7
# 30771488 30818610
# data [] 653 7
# 30818611 30865733
# data [] 654 7
# 30865734 30912856
# data [] 655 7
# 30912857 30959980
# data [] 656 7
# 30959981 31007103
# data [] 657 7
# 31007104 31054226
# data [] 658 7
# 31054227 31101349
# data [] 659 7
# 31101350 31148473
# data [] 660 7
# 31148474 31195596
# data [] 661 7
# 31195597 31242719
# data [] 662 7
# 31242720 31289842
# data [] 663 7
# 31289843 31336966
# data [] 664 7
# 31336967 31384089
# data [] 665 7
# 31384090 31431212
# data [] 666 7
# 31431213 31478335
# data [] 667 7
# 31478336 31525459
# data [] 668 7
# 31525460 31572582
# data [] 669 7
# 31572583 31619705
# data [] 670 7
# 31619706 31666828
# data [] 671 7
# 31666829 31713952
# data [] 672 7
# 31713953 31761075
# data [] 673 7
# 31761076 31808198
# data [] 674 7
# 31808199 31855322
# data [] 675 7
# 31855323 31902445
# data [] 676 7
# 31902446 31949568
# data [] 677 7
# 31949569 31996691
# data [] 678 7
# 31996692 32043815
# data [] 679 7
# 32043816 32090938
# data [] 680 7
# 32090939 32138061
# data [] 681 7
# 32138062 32185184
# data [] 682 7
# 32185185 32232308
# data [] 683 7
# 32232309 32279431
# data [] 684 7
# 32279432 32326554
# data [] 685 7
# 32326555 32373677
# data [] 686 7
# 32373678 32420801
# data [] 687 7
# 32420802 32467924
# data [] 688 7
# 32467925 32515047
# data [] 689 7
# 32515048 32562170
# data [] 690 7
# 32562171 32609294
# data [] 691 7
# 32609295 32656417
# data [] 692 7
# 32656418 32703540
# data [] 693 7
# 32703541 32750663
# data [] 694 7
# 32750664 32797787
# data [] 695 7
# 32797788 32844910
# data [] 696 7
# 32844911 32892033
# data [] 697 7
# 32892034 32939156
# data [] 698 7
# 32939157 32986280
# data [] 699 7
# 32986281 33033403
# data [] 700 7
# 33033404 33080526
# data [] 701 7
# 33080527 33127649
# data [] 702 7
# 33127650 33174773
# data [] 703 7
# 33174774 33221896
# data [] 704 7
# 33221897 33269019
# data [] 705 7
# 33269020 33316143
# data [] 706 7
# 33316144 33363266
# data [] 707 7
# 33363267 33410389
# data [] 708 7
# 33410390 33457512
# data [] 709 7
# 33457513 33504636
# data [] 710 7
# 33504637 33551759
# data [] 711 7
# 33551760 33598882
# data [] 712 7
# 33598883 33646005
# data [] 713 7
# 33646006 33693129
# data [] 714 7
# 33693130 33740252
# data [] 715 7
# 33740253 33787375
# data [] 716 7
# 33787376 33834498
# data [] 717 7
# 33834499 33881622
# data [] 718 7
# 33881623 33928745
# data [] 719 7
# 33928746 33975868
# data [] 720 7
# 33975869 34022991
# data [] 721 7
# 34022992 34070115
# data [] 722 7
# 34070116 34117238
# data [] 723 7
# 34117239 34164361
# data [] 724 7
# 34164362 34211484
# data [] 725 7
# 34211485 34258608
# data [] 726 7
# 34258609 34305731
# data [] 727 7
# 34305732 34352854
# data [] 728 7
# 34352855 34399977
# data [] 729 7
# 34399978 34447101
# data [] 730 7
# 34447102 34494224
# data [] 731 7
# 34494225 34541347
# data [] 732 7
# 34541348 34588470
# data [] 733 7
# 34588471 34635594
# data [] 734 7
# 34635595 34682717
# data [] 735 7
# 34682718 34729840
# data [] 736 7
# 34729841 34776963
# data [] 737 7
# 34776964 34824087
# data [] 738 7
# 34824088 34871210
# data [] 739 7
# 34871211 34918333
# data [] 740 7
# 34918334 34965457
# data [] 741 7
# 34965458 35012580
# data [] 742 7
# 35012581 35059703
# data [] 743 7
# 35059704 35106826
# data [] 744 7
# 35106827 35153950
# data [] 745 7
# 35153951 35201073
# data [] 746 7
# 35201074 35248196
# data [] 747 7
# 35248197 35295319
# data [] 748 7
# 35295320 35342443
# data [] 749 7
# 35342444 35389566
# data [] 750 7
# 35389567 35436689
# data [] 751 7
# 35436690 35483812
# data [] 752 7
# 35483813 35530936
# data [] 753 7
# 35530937 35578059
# data [] 754 7
# 35578060 35625182
# data [] 755 7
# 35625183 35672305
# data [] 756 7
# 35672306 35719429
# data [] 757 7
# 35719430 35766552
# data [] 758 7
# 35766553 35813675
# data [] 759 7
# 35813676 35860798
# data [] 760 7
# 35860799 35907922
# data [] 761 7
# 35907923 35955045
# data [] 762 7
# 35955046 36002168
# data [] 763 7
# 36002169 36049291
# data [] 764 7
# 36049292 36096415
# data [] 765 7
# 36096416 36143538
# data [] 766 7
# 36143539 36190661
# data [] 767 7
# 36190662 36237784
# data [] 768 7
# 36237785 36284908
# data [] 769 7
# 36284909 36332031
# data [] 770 7
# 36332032 36379154
# data [] 771 7
# 36379155 36426278
# data [] 772 7
# 36426279 36473401
# data [] 773 7
# 36473402 36520524
# data [] 774 7
# 36520525 36567647
# data [] 775 7
# 36567648 36614771
# data [] 776 7
# 36614772 36661894
# data [] 777 7
# 36661895 36709017
# data [] 778 7
# 36709018 36756140
# data [] 779 7
# 36756141 36803264
# data [] 780 7
# 36803265 36850387
# data [] 781 7
# 36850388 36897510
# data [] 782 7
# 36897511 36944633
# data [] 783 7
# 36944634 36991757
# data [] 784 7
# 36991758 37038880
# data [] 785 7
# 37038881 37086003
# data [] 786 7
# 37086004 37133126
# data [] 787 7
# 37133127 37180250
# data [] 788 7
# 37180251 37227373
# data [] 789 7
# 37227374 37274496
# data [] 790 7
# 37274497 37321619
# data [] 791 7
# 37321620 37368743
# data [] 792 7
# 37368744 37415866
# data [] 793 7
# 37415867 37462989
# data [] 794 7
# 37462990 37510112
# data [] 795 7
# 37510113 37557236
# data [] 796 7
# 37557237 37604359
# data [] 797 7
# 37604360 37651482
# data [] 798 7
# 37651483 37698605
# data [] 799 7
# 37698606 37745729
# data [] 800 7
# 37745730 37792852
# data [] 801 7
# 37792853 37839975
# data [] 802 7
# 37839976 37887099
# data [] 803 7
# 37887100 37934222
# data [] 804 7
# 37934223 37981345
# data [] 805 7
# 37981346 38028468
# data [] 806 7
# 38028469 38075592
# data [] 807 7
# 38075593 38122715
# data [] 808 7
# 38122716 38169838
# data [] 809 7
# 38169839 38216961
# data [] 810 7
# 38216962 38264085
# data [] 811 7
# 38264086 38311208
# data [] 812 7
# 38311209 38358331
# data [] 813 7
# 38358332 38405454
# data [] 814 7
# 38405455 38452578
# data [] 815 7
# 38452579 38499701
# data [] 816 7
# 38499702 38546824
# data [] 817 7
# 38546825 38593947
# data [] 818 7
# 38593948 38641071
# data [] 819 7
# 38641072 38688194
# data [] 820 7
# 38688195 38735317
# data [] 821 7
# 38735318 38782440
# data [] 822 7
# 38782441 38829564
# data [] 823 7
# 38829565 38876687
# data [] 824 7
# 38876688 38923810
# data [] 825 7
# 38923811 38970933
# data [] 826 7
# 38970934 39018057
# data [] 827 7
# 39018058 39065180
# data [] 828 7
# 39065181 39112303
# data [] 829 7
# 39112304 39159426
# data [] 830 7
# 39159427 39206550
# data [] 831 7
# 39206551 39253673
# data [] 832 7
# 39253674 39300796
# data [] 833 7
# 39300797 39347920
# data [] 834 7
# 39347921 39395043
# data [] 835 7
# 39395044 39442166
# data [] 836 7
# 39442167 39489289
# data [] 837 7
# 39489290 39536413
# data [] 838 7
# 39536414 39583536
# data [] 839 7
# 39583537 39630659
# data [] 840 7
# 39630660 39677782
# data [] 841 7
# 39677783 39724906
# data [] 842 7
# 39724907 39772029
# data [] 843 7
# 39772030 39819152
# data [] 844 7
# 39819153 39866275
# data [] 845 7
# 39866276 39913399
# data [] 846 7
# 39913400 39960522
# data [] 847 7
# 39960523 40007645
# data [] 848 7
# 40007646 40054768
# data [] 849 7
# 40054769 40101892
# data [] 850 7
# 40101893 40149015
# data [] 851 7
# 40149016 40196138
# data [] 852 7
# 40196139 40243261
# data [] 853 7
# 40243262 40290385
# data [] 854 7
# 40290386 40337508
# data [] 855 7
# 40337509 40384631
# data [] 856 7
# 40384632 40431754
# data [] 857 7
# 40431755 40478878
# data [] 858 7
# 40478879 40526001
# data [] 859 7
# 40526002 40573124
# data [] 860 7
# 40573125 40620247
# data [] 861 7
# 40620248 40667371
# data [] 862 7
# 40667372 40714494
# data [] 863 7
# 40714495 40761617
# data [] 864 7
# 40761618 40808741
# data [] 865 7
# 40808742 40855864
# data [] 866 7
# 40855865 40902987
# data [] 867 7
# 40902988 40950110
# data [] 868 7
# 40950111 40997234
# data [] 869 7
# 40997235 41044357
# data [] 870 7
# 41044358 41091480
# data [] 871 7
# 41091481 41138603
# data [] 872 7
# 41138604 41185727
# data [] 873 7
# 41185728 41232850
# data [] 874 7
# 41232851 41279973
# data [] 875 7
# 41279974 41327096
# data [] 876 7
# 41327097 41374220
# data [] 877 7
# 41374221 41421343
# data [] 878 7
# 41421344 41468466
# data [] 879 7
# 41468467 41515589
# data [] 880 7
# 41515590 41562713
# data [] 881 7
# 41562714 41609836
# data [] 882 7
# 41609837 41656959
# data [] 883 7
# 41656960 41704082
# data [] 884 7
# 41704083 41751206
# data [] 885 7
# 41751207 41798329
# data [] 886 7
# 41798330 41845452
# data [] 887 7
# 41845453 41892575
# data [] 888 7
# 41892576 41939699
# data [] 889 7
# 41939700 41986822
# data [] 890 7
# 41986823 42033945
# data [] 891 7
# 42033946 42081068
# data [] 892 7
# 42081069 42128192
# data [] 893 7
# 42128193 42175315
# data [] 894 7
# 42175316 42222438
# data [] 895 7
# 42222439 42269562
# data [] 896 7
# 42269563 42316685
# data [] 897 7
# 42316686 42363808
# data [] 898 7
# 42363809 42410931
# data [] 899 7
# 42410932 42458055
# data [] 900 7
# 42458056 42505178
# data [] 901 7
# 42505179 42552301
# data [] 902 7
# 42552302 42599424
# data [] 903 7
# 42599425 42646548
# data [] 904 7
# 42646549 42693671
# data [] 905 7
# 42693672 42740794
# data [] 906 7
# 42740795 42787917
# data [] 907 7
# 42787918 42835041
# data [] 908 7
# 42835042 42882164
# data [] 909 7
# 42882165 42929287
# data [] 910 7
# 42929288 42976410
# data [] 911 7
# 42976411 43023534
# data [] 912 7
# 43023535 43070657
# data [] 913 7
# 43070658 43117780
# data [] 914 7
# 43117781 43164903
# data [] 915 7
# 43164904 43212027
# data [] 916 7
# 43212028 43259150
# data [] 917 7
# 43259151 43306273
# data [] 918 7
# 43306274 43353396
# data [] 919 7
# 43353397 43400520
# data [] 920 7
# 43400521 43447643
# data [] 921 7
# 43447644 43494766
# data [] 922 7
# 43494767 43541889
# data [] 923 7
# 43541890 43589013
# data [] 924 7
# 43589014 43636136
# data [] 925 7
# 43636137 43683259
# data [] 926 7
# 43683260 43730383
# data [] 927 7
# 43730384 43777506
# data [] 928 7
# 43777507 43824629
# data [] 929 7
# 43824630 43871752
# data [] 930 7
# 43871753 43918876
# data [] 931 7
# 43918877 43965999
# data [] 932 7
# 43966000 44013122
# data [] 933 7
# 44013123 44060245
# data [] 934 7
# 44060246 44107369
# data [] 935 7
# 44107370 44154492
# data [] 936 7
# 44154493 44201615
# data [] 937 7
# 44201616 44248738
# data [] 938 7
# 44248739 44295862
# data [] 939 7
# 44295863 44342985
# data [] 940 7
# 44342986 44390108
# data [] 941 7
# 44390109 44437231
# data [] 942 7
# 44437232 44484355
# data [] 943 7
# 44484356 44531478
# data [] 944 7
# 44531479 44578601
# data [] 945 7
# 44578602 44625724
# data [] 946 7
# 44625725 44672848
# data [] 947 7
# 44672849 44719971
# data [] 948 7
# 44719972 44767094
# data [] 949 7
# 44767095 44814217
# data [] 950 7
# 44814218 44861341
# data [] 951 7
# 44861342 44908464
# data [] 952 7
# 44908465 44955587
# data [] 953 7
# 44955588 45002710
# data [] 954 7
# 45002711 45049834
# data [] 955 7
# 45049835 45096957
# data [] 956 7
# 45096958 45144080
# data [] 957 7
# 45144081 45191203
# data [] 958 7
# 45191204 45238327
# data [] 959 7
# 45238328 45285450
# data [] 960 7
# 45285451 45332573
# data [] 961 7
# 45332574 45379697
# data [] 962 7
# 45379698 45426820
# data [] 963 7
# 45426821 45473943
# data [] 964 7
# 45473944 45521066
# data [] 965 7
# 45521067 45568190
# data [] 966 7
# 45568191 45615313
# data [] 967 7
# 45615314 45662436
# data [] 968 7
# 45662437 45709559
# data [] 969 7
# 45709560 45756683
# data [] 970 7
# 45756684 45803806
# data [] 971 7
# 45803807 45850929
# data [] 972 7
# 45850930 45898052
# data [] 973 7
# 45898053 45945176
# data [] 974 7
# 45945177 45992299
# data [] 975 7
# 45992300 46039422
# data [] 976 7
# 46039423 46086545
# data [] 977 7
# 46086546 46133669
# data [] 978 7
# 46133670 46180792
# data [] 979 7
# 46180793 46227915
# data [] 980 7
# 46227916 46275038
# data [] 981 7
# 46275039 46322162
# data [] 982 7
# 46322163 46369285
# data [] 983 7
# 46369286 46416408
# data [] 984 7
# 46416409 46463531
# data [] 985 7
# 46463532 46510655
# data [] 986 7
# 46510656 46557778
# data [] 987 7
# 46557779 46604901
# data [] 988 7
# 46604902 46652024
# data [] 989 7
# 46652025 46699148
# data [] 990 7
# 46699149 46746271
# data [] 991 7
# 46746272 46793394
# data [] 992 7
# 46793395 46840518
# data [] 993 7
# 46840519 46887641
# data [] 994 7
# 46887642 46934764
# data [] 995 7
# 46934765 46981887
# data [] 996 7
# 46981888 47029011
# data [] 997 7
# 47029012 47076134
# data [] 998 7
# 47076135 47123257
# data [] 999 7
# 47123258 47170380
# data [] 1000 7
# 47170381 47217504
# data [] 1001 7
# 47217505 47264627
# data [] 1002 7
# 47264628 47311750
# data [] 1003 7
# 47311751 47358873
# data [] 1004 7
# 47358874 47405997
# data [] 1005 7
# 47405998 47453120
# data [] 1006 7
# 47453121 47500243
# data [] 1007 7
# 47500244 47547366
# data [] 1008 7
# 47547367 47594490
# data [] 1009 7
# 47594491 47641613
# data [] 1010 7
# 47641614 47688736
# data [] 1011 7
# 47688737 47735859
# data [] 1012 7
# 47735860 47782983
# data [] 1013 7
# 47782984 47830106
# data [] 1014 7
# 47830107 47877229
# data [] 1015 7
# 47877230 47924352
# data [] 1016 7
# 47924353 47971476
# data [] 1017 7
# 47971477 48018599
# data [] 1018 7
# 48018600 48065722
# data [] 1019 7
# 48065723 48112845
# data [] 1020 7
# 48112846 48159969
# data [] 1021 7
# 48159970 48207092
# data [] 1022 7
# 48207093 48254215
# data [] 1023 7
# 48254216 48301339
# data [] 1024 7
# 48301340 48348462
# data [] 1025 7
# 48348463 48395585
# data [] 1026 7
# 48395586 48442708
# data [] 1027 7
# 48442709 48489832
# data [] 1028 7
# 48489833 48536955
# data [] 1029 7
# 48536956 48584078
# data [] 1030 7
# 48584079 48631201
# data [] 1031 7
# 48631202 48678325
# data [] 1032 7
# 48678326 48725448
# data [] 1033 7
# 48725449 48772571
# data [] 1034 7
# 48772572 48819694
# data [] 1035 7
# 48819695 48866818
# data [] 1036 7
# 48866819 48913941
# data [] 1037 7
# 48913942 48961064
# data [] 1038 7
# 48961065 49008187
# data [] 1039 7
# 49008188 49055311
# data [] 1040 7
# 49055312 49102434
# data [] 1041 7
# 49102435 49149557
# data [] 1042 7
# 49149558 49196680
# data [] 1043 7
# 49196681 49243804
# data [] 1044 7
# 49243805 49290927
# data [] 1045 7
# 49290928 49338050
# data [] 1046 7
# 49338051 49385173
# data [] 1047 7
# 49385174 49432297
# data [] 1048 7
# 49432298 49479420
# data [] 1049 7
# 49479421 49526543
# data [] 1050 7
# 49526544 49573666
# data [] 1051 7
# 49573667 49620790
# data [] 1052 7
# 49620791 49667913
# data [] 1053 7
# 49667914 49715036
# data [] 1054 7
# 49715037 49762160
# data [] 1055 7
# 49762161 49809283
# data [] 1056 7
# 49809284 49856406
# data [] 1057 7
# 49856407 49903529
# data [] 1058 7
# 49903530 49950653
# data [] 1059 7
# 49950654 49997776
# data [] 1060 7
# 49997777 50044899
# data [] 1061 7
# 50044900 50092022
# data [] 1062 7
# 50092023 50139146
# data [] 1063 7
# 50139147 50186269
# data [] 1064 7
# 50186270 50233392
# data [] 1065 7
# 50233393 50280515
# data [] 1066 7
# 50280516 50327639
# data [] 1067 7
# 50327640 50374762
# data [] 1068 7
# 50374763 50421885
# data [] 1069 7
# 50421886 50469008
# data [] 1070 7
# 50469009 50516132
# data [] 1071 7
# 50516133 50563255
# data [] 1072 7
# 50563256 50610378
# data [] 1073 7
# 50610379 50657501
# data [] 1074 7
# 50657502 50704625
# data [] 1075 7
# 50704626 50751748
# data [] 1076 7
# 50751749 50798871
# data [] 1077 7
# 50798872 50845994
# data [] 1078 7
# 50845995 50893118
# data [] 1079 7
# 50893119 50940241
# data [] 1080 7
# 50940242 50987364
# data [] 1081 7
# 50987365 51034487
# data [] 1082 7
# 51034488 51081611
# data [] 1083 7
# 51081612 51128734
# data [] 1084 7
# 51128735 51175857
# data [] 1085 7
# 51175858 51222981
# data [] 1086 7
# 51222982 51270104
# data [] 1087 7
# 51270105 51317227
# data [] 1088 7
# 51317228 51364350
# data [] 1089 7
# 51364351 51411474
# data [] 1090 7
# 51411475 51458597
# data [] 1091 7
# 51458598 51505720
# data [] 1092 7
# 51505721 51552843
# data [] 1093 7
# 51552844 51599967
# data [] 1094 7
# 51599968 51647090
# data [] 1095 7
# 51647091 51694213
# data [] 1096 7
# 51694214 51741336
# data [] 1097 7
# 51741337 51788460
# data [] 1098 7
# 51788461 51835583
# data [] 1099 7
# 51835584 51882706
# data [] 1100 7
# 51882707 51929829
# data [] 1101 7
# 51929830 51976953
# data [] 1102 7
# 51976954 52024076
# data [] 1103 7
# 52024077 52071199
# data [] 1104 7
# 52071200 52118322
# data [] 1105 7
# 52118323 52165446
# data [] 1106 7
# 52165447 52212569
# data [] 1107 7
# 52212570 52259692
# data [] 1108 7
# 52259693 52306815
# data [] 1109 7
# 52306816 52353939
# data [] 1110 7
# 52353940 52401062
# data [] 1111 7
# 52401063 52448185
# data [] 1112 7
# 52448186 52495308
# data [] 1113 7
# 52495309 52542432
# data [] 1114 7
# 52542433 52589555
# data [] 1115 7
# 52589556 52636678
# data [] 1116 7
# 52636679 52683802
# data [] 1117 7
# 52683803 52730925
# data [] 1118 7
# 52730926 52778048
# data [] 1119 7
# 52778049 52825171
# data [] 1120 7
# 52825172 52872295
# data [] 1121 7
# 52872296 52919418
# data [] 1122 7
# 52919419 52966541
# data [] 1123 7
# 52966542 53013664
# data [] 1124 7
# 53013665 53060788
# data [] 1125 7
# 53060789 53107911
# data [] 1126 7
# 53107912 53155034
# data [] 1127 7
# 53155035 53202157
# data [] 1128 7
# 53202158 53249281
# data [] 1129 7
# 53249282 53296404
# data [] 1130 7
# 53296405 53343527
# data [] 1131 7
# 53343528 53390650
# data [] 1132 7
# 53390651 53437774
# data [] 1133 7
# 53437775 53484897
# data [] 1134 7
# 53484898 53532020
# data [] 1135 7
# 53532021 53579143
# data [] 1136 7
# 53579144 53626267
# data [] 1137 7
# 53626268 53673390
# data [] 1138 7
# 53673391 53720513
# data [] 1139 7
# 53720514 53767636
# data [] 1140 7
# 53767637 53814760
# data [] 1141 7
# 53814761 53861883
# data [] 1142 7
# 53861884 53909006
# data [] 1143 7
# 53909007 53956129
# data [] 1144 7
# 53956130 54003253
# data [] 1145 7
# 54003254 54050376
# data [] 1146 7
# 54050377 54097499
# data [] 1147 7
# 54097500 54144623
# data [] 1148 7
# 54144624 54191746
# data [] 1149 7
# 54191747 54238869
# data [] 1150 7
# 54238870 54285992
# data [] 1151 7
# 54285993 54333116
# data [] 1152 7
# 54333117 54380239
# data [] 1153 7
# 54380240 54427362
# data [] 1154 7
# 54427363 54474485
# data [] 1155 7
# 54474486 54521609
# data [] 1156 7
# 54521610 54568732
# data [] 1157 7
# 54568733 54615855
# data [] 1158 7
# 54615856 54662978
# data [] 1159 7
# 54662979 54710102
# data [] 1160 7
# 54710103 54757225
# data [] 1161 7
# 54757226 54804348
# data [] 1162 7
# 54804349 54851471
# data [] 1163 7
# 54851472 54898595
# data [] 1164 7
# 54898596 54945718
# data [] 1165 7
# 54945719 54992841
# data [] 1166 7
# 54992842 55039964
# data [] 1167 7
# 55039965 55087088
# data [] 1168 7
# 55087089 55134211
# data [] 1169 7
# 55134212 55181334
# data [] 1170 7
# 55181335 55228457
# data [] 1171 7
# 55228458 55275581
# data [] 1172 7
# 55275582 55322704
# data [] 1173 7
# 55322705 55369827
# data [] 1174 7
# 55369828 55416950
# data [] 1175 7
# 55416951 55464074
# data [] 1176 7
# 55464075 55511197
# data [] 1177 7
# 55511198 55558320
# data [] 1178 7
# 55558321 55605444
# data [] 1179 7
# 55605445 55652567
# data [] 1180 7
# 55652568 55699690
# data [] 1181 7
# 55699691 55746813
# data [] 1182 7
# 55746814 55793937
# data [] 1183 7
# 55793938 55841060
# data [] 1184 7
# 55841061 55888183
# data [] 1185 7
# 55888184 55935306
# data [] 1186 7
# 55935307 55982430
# data [] 1187 7
# 55982431 56029553
# data [] 1188 7
# 56029554 56076676
# data [] 1189 7
# 56076677 56123799
# data [] 1190 7
# 56123800 56170923
# data [] 1191 7
# 56170924 56218046
# data [] 1192 7
# 56218047 56265169
# data [] 1193 7
# 56265170 56312292
# data [] 1194 7
# 56312293 56359416
# data [] 1195 7
# 56359417 56406539
# data [] 1196 7
# 56406540 56453662
# data [] 1197 7
# 56453663 56500785
# data [] 1198 7
# 56500786 56547909
# data [] 1199 7
# 56547910 56595032
# data [] 1200 7
# 56595033 56642155
# data [] 1201 7
# 56642156 56689278
# data [] 1202 7
# 56689279 56736402
# data [] 1203 7
# 56736403 56783525
# data [] 1204 7
# 56783526 56830648
# data [] 1205 7
# 56830649 56877771
# data [] 1206 7
# 56877772 56924895
# data [] 1207 7
# 56924896 56972018
# data [] 1208 7
# 56972019 57019141
# data [] 1209 7
# 57019142 57066264
# data [] 1210 7
# 57066265 57113388
# data [] 1211 7
# 57113389 57160511
# data [] 1212 7
# 57160512 57207634
# data [] 1213 7
# 57207635 57254758
# data [] 1214 7
# 57254759 57301881
# data [] 1215 7
# 57301882 57349004
# data [] 1216 7
# 57349005 57396127
# data [] 1217 7
# 57396128 57443251
# data [] 1218 7
# 57443252 57490374
# data [] 1219 7
# 57490375 57537497
# data [] 1220 7
# 57537498 57584620
# data [] 1221 7
# 57584621 57631744
# data [] 1222 7
# 57631745 57678867
# data [] 1223 7
# 57678868 57725990
# data [] 1224 7
# 57725991 57773113
# data [] 1225 7
# 57773114 57820237
# data [] 1226 7
# 57820238 57867360
# data [] 1227 7
# 57867361 57914483
# data [] 1228 7
# 57914484 57961606
# data [] 1229 7
# 57961607 58008730
# data [] 1230 7
# 58008731 58055853
# data [] 1231 7
# 58055854 58102976
# data [] 1232 7
# 58102977 58150099
# data [] 1233 7
# 58150100 58197223
# data [] 1234 7
# 58197224 58244346
# data [] 1235 7
# 58244347 58291469
# data [] 1236 7
# 58291470 58338592
# data [] 1237 7
# 58338593 58385716
# data [] 1238 7
# 58385717 58432839
# data [] 1239 7
# 58432840 58479962
# data [] 1240 7
# 58479963 58527085
# data [] 1241 7
# 58527086 58574209
# data [] 1242 7
# 58574210 58621332
# data [] 1243 7
# 58621333 58668455
# data [] 1244 7
# 58668456 58715579
# data [] 1245 7
# 58715580 58762702
# data [] 1246 7
# 58762703 58809825
# data [] 1247 7
# 58809826 58856948
# data [] 1248 7
# 58856949 58904072
# data [] 1249 7
# 58904073 58951195
# data [] 1250 7
# 58951196 58998318
# data [] 1251 7
# 58998319 59045441
# data [] 1252 7
# 59045442 59092565
# data [] 1253 7
# 59092566 59139688
# data [] 1254 7
# 59139689 59186811
# data [] 1255 7
# 59186812 59233934
# data [] 1256 7
# 59233935 59281058
# data [] 1257 7
# 59281059 59328181
# data [] 1258 7
# 59328182 59375304
# data [] 1259 7
# 59375305 59422427
# data [] 1260 7
# 59422428 59469551
# data [] 1261 7
# 59469552 59516674
# data [] 1262 7
# 59516675 59563797
# data [] 1263 7
# 59563798 59610920
# data [] 1264 7
# 59610921 59658044
# data [] 1265 7
# 59658045 59705167
# data [] 1266 7
# 59705168 59752290
# data [] 1267 7
# 59752291 59799413
# data [] 1268 7
# 59799414 59846537
# data [] 1269 7
# 59846538 59893660
# data [] 1270 7
# 59893661 59940783
# data [] 1271 7
# 59940784 59987906
# data [] 1272 7
# 59987907 60035030
# data [] 1273 7
# 60035031 60082153
# data [] 1274 7
# 60082154 60129276
# data [] 1275 7
# 60129277 60176400
# data [] 1276 7
# 60176401 60223523
# data [] 1277 7
# 60223524 60270646
# data [] 1278 7
# 60270647 60317769
# data [] 1279 7
# 60317770 60364893
# data [] 1280 7
# 60364894 60412016
# data [] 1281 7
# 60412017 60459139
# data [] 1282 7
# 60459140 60506262
# data [] 1283 7
# 60506263 60553386
# data [] 1284 7
# 60553387 60600509
# data [] 1285 7
# 60600510 60647632
# data [] 1286 7
# 60647633 60694755
# data [] 1287 7
# 60694756 60741879
# data [] 1288 7
# 60741880 60789002
# data [] 1289 7
# 60789003 60836125
# data [] 1290 7
# 60836126 60883248
# data [] 1291 7
# 60883249 60930372
# data [] 1292 7
# 60930373 60977495
# data [] 1293 7
# 60977496 61024618
# data [] 1294 7
# 61024619 61071741
# data [] 1295 7
# 61071742 61118865
# data [] 1296 7
# 61118866 61165988
# data [] 1297 7
# 61165989 61213111
# data [] 1298 7
# 61213112 61260234
# data [] 1299 7
# 61260235 61307358
# data [] 1300 7
# 61307359 61354481
# data [] 1301 7
# 61354482 61401604
# data [] 1302 7
# 61401605 61448727
# data [] 1303 7
# 61448728 61495851
# data [] 1304 7
# 61495852 61542974
# data [] 1305 7
# 61542975 61590097
# data [] 1306 7
# 61590098 61637221
# data [] 1307 7
# 61637222 61684344
# data [] 1308 7
# 61684345 61731467
# data [] 1309 7
# 61731468 61778590
# data [] 1310 7
# 61778591 61825714
# data [] 1311 7
# 61825715 61872837
# data [] 1312 7
# 61872838 61919960
# data [] 1313 7
# 61919961 61967083
# data [] 1314 7
# 61967084 62014207
# data [] 1315 7
# 62014208 62061330
# data [] 1316 7
# 62061331 62108453
# data [] 1317 7
# 62108454 62155576
# data [] 1318 7
# 62155577 62202700
# data [] 1319 7
# 62202701 62249823
# data [] 1320 7
# 62249824 62296946
# data [] 1321 7
# 62296947 62344069
# data [] 1322 7
# 62344070 62391193
# data [] 1323 7
# 62391194 62438316
# data [] 1324 7
# 62438317 62485439
# data [] 1325 7
# 62485440 62532562
# data [] 1326 7
# 62532563 62579686
# data [] 1327 7
# 62579687 62626809
# data [] 1328 7
# 62626810 62673932
# data [] 1329 7
# 62673933 62721055
# data [] 1330 7
# 62721056 62768179
# data [] 1331 7
# 62768180 62815302
# data [] 1332 7
# 62815303 62862425
# data [] 1333 7
# 62862426 62909548
# data [] 1334 7
# 62909549 62956672
# data [] 1335 7
# 62956673 63003795
# data [] 1336 7
# 63003796 63050918
# data [] 1337 7
# 63050919 63098042
# data [] 1338 7
# 63098043 63145165
# data [] 1339 7
# 63145166 63192288
# data [] 1340 7
# 63192289 63239411
# data [] 1341 7
# 63239412 63286535
# data [] 1342 7
# 63286536 63333658
# data [] 1343 7
# 63333659 63380781
# data [] 1344 7
# 63380782 63427904
# data [] 1345 7
# 63427905 63475028
# data [] 1346 7
# 63475029 63522151
# data [] 1347 7
# 63522152 63569274
# data [] 1348 7
# 63569275 63616397
# data [] 1349 7
# 63616398 63663521
# data [] 1350 7
# 63663522 63710644
# data [] 1351 7
# 63710645 63757767
# data [] 1352 7
# 63757768 63804890
# data [] 1353 7
# 63804891 63852014
# data [] 1354 7
# 63852015 63899137
# data [] 1355 7
# 63899138 63946260
# data [] 1356 7
# 63946261 63993383
# data [] 1357 7
# 63993384 64040507
# data [] 1358 7
# 64040508 64087630
# data [] 1359 7
# 64087631 64134753
# data [] 1360 7
# 64134754 64181876
# data [] 1361 7
# 64181877 64229000
# data [] 1362 7
# 64229001 64276123
# data [] 1363 7
# 64276124 64323246
# data [] 1364 7
# 64323247 64370369
# data [] 1365 7
# 64370370 64417493
# data [] 1366 7
# 64417494 64464616
# data [] 1367 7
# 64464617 64511739
# data [] 1368 7
# 64511740 64558863
# data [] 1369 7
# 64558864 64605986
# data [] 1370 7
# 64605987 64653109
# data [] 1371 7
# 64653110 64700232
# data [] 1372 7
# 64700233 64747356
# data [] 1373 7
# 64747357 64794479
# data [] 1374 7
# 64794480 64841602
# data [] 1375 7
# 64841603 64888725
# data [] 1376 7
# 64888726 64935849
# data [] 1377 7
# 64935850 64982972
# data [] 1378 7
# 64982973 65030095
# data [] 1379 7
# 65030096 65077218
# data [] 1380 7
# 65077219 65124342
# data [] 1381 7
# 65124343 65171465
# data [] 1382 7
# 65171466 65218588
# data [] 1383 7
# 65218589 65265711
# data [] 1384 7
# 65265712 65312835
# data [] 1385 7
# 65312836 65359958
# data [] 1386 7
# 65359959 65407081
# data [] 1387 7
# 65407082 65454204
# data [] 1388 7
# 65454205 65501328
# data [] 1389 7
# 65501329 65548451
# data [] 1390 7
# 65548452 65595574
# data [] 1391 7
# 65595575 65642697
# data [] 1392 7
# 65642698 65689821
# data [] 1393 7
# 65689822 65736944
# data [] 1394 7
# 65736945 65784067
# data [] 1395 7
# 65784068 65831190
# data [] 1396 7
# 65831191 65878314
# data [] 1397 7
# 65878315 65925437
# data [] 1398 7
# 65925438 65972560
# data [] 1399 7
# 65972561 66019684
# data [] 1400 7
# 66019685 66066807
# data [] 1401 7
# 66066808 66113930
# data [] 1402 7
# 66113931 66161053
# data [] 1403 7
# 66161054 66208177
# data [] 1404 7
# 66208178 66255300
# data [] 1405 7
# 66255301 66302423
# data [] 1406 7
# 66302424 66349546
# data [] 1407 7
# 66349547 66396670
# data [] 1408 7
# 66396671 66443793
# data [] 1409 7
# 66443794 66490916
# data [] 1410 7
# 66490917 66538039
# data [] 1411 7
# 66538040 66585163
# data [] 1412 7
# 66585164 66632286
# data [] 1413 7
# 66632287 66679409
# data [] 1414 7
# 66679410 66726532
# data [] 1415 7
# 66726533 66773656
# data [] 1416 7
# 66773657 66820779
# data [] 1417 7
# 66820780 66867902
# data [] 1418 7
# 66867903 66915025
# data [] 1419 7
# 66915026 66962149
# data [] 1420 7
# 66962150 67009272
# data [] 1421 7
# 67009273 67056395
# data [] 1422 7
# 67056396 67103518
# data [] 1423 7
# 67103519 67150642
# data [] 1424 7
# 67150643 67197765
# data [] 1425 7
# 67197766 67244888
# data [] 1426 7
# 67244889 67292011
# data [] 1427 7
# 67292012 67339135
# data [] 1428 7
# 67339136 67386258
# data [] 1429 7
# 67386259 67433381
# data [] 1430 7
# 67433382 67480505
# data [] 1431 7
# 67480506 67527628
# data [] 1432 7
# 67527629 67574751
# data [] 1433 7
# 67574752 67621874
# data [] 1434 7
# 67621875 67668998
# data [] 1435 7
# 67668999 67716121
# data [] 1436 7
# 67716122 67763244
# data [] 1437 7
# 67763245 67810367
# data [] 1438 7
# 67810368 67857491
# data [] 1439 7
# 67857492 67904614
# data [] 1440 7
# 67904615 67951737
# data [] 1441 7
# 67951738 67998860
# data [] 1442 7
# 67998861 68045984
# data [] 1443 7
# 68045985 68093107
# data [] 1444 7
# 68093108 68140230
# data [] 1445 7
# 68140231 68187353
# data [] 1446 7
# 68187354 68234477
# data [] 1447 7
# 68234478 68281600
# data [] 1448 7
# 68281601 68328723
# data [] 1449 7
# 68328724 68375846
# data [] 1450 7
# 68375847 68422970
# data [] 1451 7
# 68422971 68470093
# data [] 1452 7
# 68470094 68517216
# data [] 1453 7
# 68517217 68564339
# data [] 1454 7
# 68564340 68611463
# data [] 1455 7
# 68611464 68658586
# data [] 1456 7
# 68658587 68705709
# data [] 1457 7
# 68705710 68752832
# data [] 1458 7
# 68752833 68799956
# data [] 1459 7
# 68799957 68847079
# data [] 1460 7
# 68847080 68894202
# data [] 1461 7
# 68894203 68941325
# data [] 1462 7
# 68941326 68988449
# data [] 1463 7
# 68988450 69035572
# data [] 1464 7
# 69035573 69082695
# data [] 1465 7
# 69082696 69129819
# data [] 1466 7
# 69129820 69176942
# data [] 1467 7
# 69176943 69224065
# data [] 1468 7
# 69224066 69271188
# data [] 1469 7
# 69271189 69318312
# data [] 1470 7
# 69318313 69365435
# data [] 1471 7
# 69365436 69412558
# data [] 1472 7
# 69412559 69459681
# data [] 1473 7
# 69459682 69506805
# data [] 1474 7
# 69506806 69553928
# data [] 1475 7
# 69553929 69601051
# data [] 1476 7
# 69601052 69648174
# data [] 1477 7
# 69648175 69695298
# data [] 1478 7
# 69695299 69742421
# data [] 1479 7
# 69742422 69789544
# data [] 1480 7
# 69789545 69836667
# data [] 1481 7
# 69836668 69883791
# data [] 1482 7
# 69883792 69930914
# data [] 1483 7
# 69930915 69978037
# data [] 1484 7
# 69978038 70025160
# data [] 1485 7
# 70025161 70072284
# data [] 1486 7
# 70072285 70119407
# data [] 1487 7
# 70119408 70166530
# data [] 1488 7
# 70166531 70213653
# data [] 1489 7
# 70213654 70260777
# data [] 1490 7
# 70260778 70307900
# data [] 1491 7
# ...
# 227416843 227463965
# data [] 4826 7
# 227463966 227511088
# data [] 4827 7
# 227511089 227558212
# data [] 4828 7
# 227558213 227605335
# data [] 4829 7
# 227605336 227652458
# data [] 4830 7
# 227652459 227699581
# data [] 4831 7
# 227699582 227746705
# data [] 4832 7
# 227746706 227793828
# data [] 4833 7
# 227793829 227840951
# data [] 4834 7
# 227840952 227888075
# data [] 4835 7
# 227888076 227935198
# data [] 4836 7
# 227935199 227982321
# data [] 4837 7
# 227982322 228029444
# data [] 4838 7
# 228029445 228076568
# data [] 4839 7
# 228076569 228123691
# data [] 4840 7
# 228123692 228170814
# data [] 4841 7
# 228170815 228217937
# data [] 4842 7
# 228217938 228265061
# data [] 4843 7
# 228265062 228312184
# data [] 4844 7
# 228312185 228359307
# data [] 4845 7
# 228359308 228406430
# data [] 4846 7
# 228406431 228453554
# data [] 4847 7
# 228453555 228500677
# data [] 4848 7
# 228500678 228547800
# data [] 4849 7
# 228547801 228594923
# data [] 4850 7
# 228594924 228642047
# data [] 4851 7
# 228642048 228689170
# data [] 4852 7
# 228689171 228736293
# data [] 4853 7
# 228736294 228783416
# data [] 4854 7
# 228783417 228830540
# data [] 4855 7
# 228830541 228877663
# data [] 4856 7
# 228877664 228924786
# data [] 4857 7
# 228924787 228971909
# data [] 4858 7
# 228971910 229019033
# data [] 4859 7
# 229019034 229066156
# data [] 4860 7
# 229066157 229113279
# data [] 4861 7
# 229113280 229160402
# data [] 4862 7
# 229160403 229207526
# data [] 4863 7
# 229207527 229254649
# data [] 4864 7
# 229254650 229301772
# data [] 4865 7
# 229301773 229348896
# data [] 4866 7
# 229348897 229396019
# data [] 4867 7
# 229396020 229443142
# data [] 4868 7
# 229443143 229490265
# data [] 4869 7
# 229490266 229537389
# data [] 4870 7
# 229537390 229584512
# data [] 4871 7
# 229584513 229631635
# data [] 4872 7
# 229631636 229678758
# data [] 4873 7
# 229678759 229725882
# data [] 4874 7
# 229725883 229773005
# data [] 4875 7
# 229773006 229820128
# data [] 4876 7
# 229820129 229867251
# data [] 4877 7
# 229867252 229914375
# data [] 4878 7
# 229914376 229961498
# data [] 4879 7
# 229961499 230008621
# data [] 4880 7
# 230008622 230055744
# data [] 4881 7
# 230055745 230102868
# data [] 4882 7
# 230102869 230149991
# data [] 4883 7
# 230149992 230197114
# data [] 4884 7
# 230197115 230244237
# data [] 4885 7
# 230244238 230291361
# data [] 4886 7
# 230291362 230338484
# data [] 4887 7
# 230338485 230385607
# data [] 4888 7
# 230385608 230432730
# data [] 4889 7
# 230432731 230479854
# data [] 4890 7
# 230479855 230526977
# data [] 4891 7
# 230526978 230574100
# data [] 4892 7
# 230574101 230621223
# data [] 4893 7
# 230621224 230668347
# data [] 4894 7
# 230668348 230715470
# data [] 4895 7
# 230715471 230762593
# data [] 4896 7
# 230762594 230809717
# data [] 4897 7
# 230809718 230856840
# data [] 4898 7
# 230856841 230903963
# data [] 4899 7
# 230903964 230951086
# data [] 4900 7
# 230951087 230998210
# data [] 4901 7
# 230998211 231045333
# data [] 4902 7
# 231045334 231092456
# data [] 4903 7
# 231092457 231139579
# data [] 4904 7
# 231139580 231186703
# data [] 4905 7
# 231186704 231233826
# data [] 4906 7
# 231233827 231280949
# data [] 4907 7
# 231280950 231328072
# data [] 4908 7
# 231328073 231375196
# data [] 4909 7
# 231375197 231422319
# data [] 4910 7
# 231422320 231469442
# data [] 4911 7
# 231469443 231516565
# data [] 4912 7
# 231516566 231563689
# data [] 4913 7
# 231563690 231610812
# data [] 4914 7
# 231610813 231657935
# data [] 4915 7
# 231657936 231705058
# data [] 4916 7
# 231705059 231752182
# data [] 4917 7
# 231752183 231799305
# data [] 4918 7
# 231799306 231846428
# data [] 4919 7
# 231846429 231893551
# data [] 4920 7
# 231893552 231940675
# data [] 4921 7
# 231940676 231987798
# data [] 4922 7
# 231987799 232034921
# data [] 4923 7
# 232034922 232082044
# data [] 4924 7
# 232082045 232129168
# data [] 4925 7
# 232129169 232176291
# data [] 4926 7
# 232176292 232223414
# data [] 4927 7
# 232223415 232270537
# data [] 4928 7
# 232270538 232317661
# data [] 4929 7
# 232317662 232364784
# data [] 4930 7
# 232364785 232411907
# data [] 4931 7
# 232411908 232459031
# data [] 4932 7
# 232459032 232506154
# data [] 4933 7
# 232506155 232553277
# data [] 4934 7
# 232553278 232600400
# data [] 4935 7
# 232600401 232647524
# data [] 4936 7
# 232647525 232694647
# data [] 4937 7
# 232694648 232741770
# data [] 4938 7
# 232741771 232788893
# data [] 4939 7
# 232788894 232836017
# data [] 4940 7
# 232836018 232883140
# data [] 4941 7
# 232883141 232930263
# data [] 4942 7
# 232930264 232977386
# data [] 4943 7
# 232977387 233024510
# data [] 4944 7
# 233024511 233071633
# data [] 4945 7
# 233071634 233118756
# data [] 4946 7
# 233118757 233165879
# data [] 4947 7
# 233165880 233213003
# data [] 4948 7
# 233213004 233260126
# data [] 4949 7
# 233260127 233307249
# data [] 4950 7
# 233307250 233354372
# data [] 4951 7
# 233354373 233401496
# data [] 4952 7
# 233401497 233448619
# data [] 4953 7
# 233448620 233495742
# data [] 4954 7
# 233495743 233542865
# data [] 4955 7
# 233542866 233589989
# data [] 4956 7
# 233589990 233637112
# data [] 4957 7
# 233637113 233684235
# data [] 4958 7
# 233684236 233731358
# data [] 4959 7
# 233731359 233778482
# data [] 4960 7
# 233778483 233825605
# data [] 4961 7
# 233825606 233872728
# data [] 4962 7
# 233872729 233919852
# data [] 4963 7
# 233919853 233966975
# data [] 4964 7
# 233966976 234014098
# data [] 4965 7
# 234014099 234061221
# data [] 4966 7
# 234061222 234108345
# data [] 4967 7
# 234108346 234155468
# data [] 4968 7
# 234155469 234202591
# data [] 4969 7
# 234202592 234249714
# data [] 4970 7
# 234249715 234296838
# data [] 4971 7
# 234296839 234343961
# data [] 4972 7
# 234343962 234391084
# data [] 4973 7
# 234391085 234438207
# data [] 4974 7
# 234438208 234485331
# data [] 4975 7
# 234485332 234532454
# data [] 4976 7
# 234532455 234579577
# data [] 4977 7
# 234579578 234626700
# data [] 4978 7
# 234626701 234673824
# data [] 4979 7
# 234673825 234720947
# data [] 4980 7
# 234720948 234768070
# data [] 4981 7
# 234768071 234815193
# data [] 4982 7
# 234815194 234862317
# data [] 4983 7
# 234862318 234909440
# data [] 4984 7
# 234909441 234956563
# data [] 4985 7
# 234956564 235003686
# data [] 4986 7
# 235003687 235050810
# data [] 4987 7
# 235050811 235097933
# data [] 4988 7
# 235097934 235145056
# data [] 4989 7
# 235145057 235192179
# data [] 4990 7
# 235192180 235239303
# data [] 4991 7
# 235239304 235286426
# data [] 4992 7
# 235286427 235333549
# data [] 4993 7
# 235333550 235380673
# data [] 4994 7
# 235380674 235427796
# data [] 4995 7
# 235427797 235474919
# data [] 4996 7
# 235474920 235522042
# data [] 4997 7
# 235522043 235569166
# data [] 4998 7
# 235569167 235616289
# data [] 4999 7
# 235616290 235663412
# data [] 5000 7
# 235663413 235710535
# data [] 5001 7
# 235710536 235757659
# data [] 5002 7
# 235757660 235804782
# data [] 5003 7
# 235804783 235851905
# data [] 5004 7
# 235851906 235899028
# data [] 5005 7
# 235899029 235946152
# data [] 5006 7
# 235946153 235993275
# data [] 5007 7
# 235993276 236040398
# data [] 5008 7
# 236040399 236087521
# data [] 5009 7
# 236087522 236134645
# data [] 5010 7
# 236134646 236181768
# data [] 5011 7
# 236181769 236228891
# data [] 5012 7
# 236228892 236276014
# data [] 5013 7
# 236276015 236323138
# data [] 5014 7
# 236323139 236370261
# data [] 5015 7
# 236370262 236417384
# data [] 5016 7
# 236417385 236464507
# data [] 5017 7
# 236464508 236511631
# data [] 5018 7
# 236511632 236558754
# data [] 5019 7
# 236558755 236605877
# data [] 5020 7
# 236605878 236653000
# data [] 5021 7
# 236653001 236700124
# data [] 5022 7
# 236700125 236747247
# data [] 5023 7
# 236747248 236794370
# data [] 5024 7
# 236794371 236841494
# data [] 5025 7
# 236841495 236888617
# data [] 5026 7
# 236888618 236935740
# data [] 5027 7
# 236935741 236982863
# data [] 5028 7
# 236982864 237029987
# data [] 5029 7
# 237029988 237077110
# data [] 5030 7
# 237077111 237124233
# data [] 5031 7
# 237124234 237171356
# data [] 5032 7
# 237171357 237218480
# data [] 5033 7
# 237218481 237265603
# data [] 5034 7
# 237265604 237312726
# data [] 5035 7
# 237312727 237359849
# data [] 5036 7
# 237359850 237406973
# data [] 5037 7
# 237406974 237454096
# data [] 5038 7
# 237454097 237501219
# data [] 5039 7
# 237501220 237548342
# data [] 5040 7
# 237548343 237595466
# data [] 5041 7
# 237595467 237642589
# data [] 5042 7
# 237642590 237689712
# data [] 5043 7
# 237689713 237736835
# data [] 5044 7
# 237736836 237783959
# data [] 5045 7
# 237783960 237831082
# data [] 5046 7
# 237831083 237878205
# data [] 5047 7
# 237878206 237925328
# data [] 5048 7
# 237925329 237972452
# data [] 5049 7
# 237972453 238019575
# data [] 5050 7
# 238019576 238066698
# data [] 5051 7
# 238066699 238113821
# data [] 5052 7
# 238113822 238160945
# data [] 5053 7
# 238160946 238208068
# data [] 5054 7
# 238208069 238255191
# data [] 5055 7
# 238255192 238302315
# data [] 5056 7
# 238302316 238349438
# data [] 5057 7
# 238349439 238396561
# data [] 5058 7
# 238396562 238443684
# data [] 5059 7
# 238443685 238490808
# data [] 5060 7
# 238490809 238537931
# data [] 5061 7
# 238537932 238585054
# data [] 5062 7
# 238585055 238632177
# data [] 5063 7
# 238632178 238679301
# data [] 5064 7
# 238679302 238726424
# data [] 5065 7
# 238726425 238773547
# data [] 5066 7
# 238773548 238820670
# data [] 5067 7
# 238820671 238867794
# data [] 5068 7
# 238867795 238914917
# data [] 5069 7
# 238914918 238962040
# data [] 5070 7
# 238962041 239009163
# data [] 5071 7
# 239009164 239056287
# data [] 5072 7
# 239056288 239103410
# data [] 5073 7
# 239103411 239150533
# data [] 5074 7
# 239150534 239197656
# data [] 5075 7
# 239197657 239244780
# data [] 5076 7
# 239244781 239291903
# data [] 5077 7
# 239291904 239339026
# data [] 5078 7
# 239339027 239386149
# data [] 5079 7
# 239386150 239433273
# data [] 5080 7
# 239433274 239480396
# data [] 5081 7
# 239480397 239527519
# data [] 5082 7
# 239527520 239574642
# data [] 5083 7
# 239574643 239621766
# data [] 5084 7
# 239621767 239668889
# data [] 5085 7
# 239668890 239716012
# data [] 5086 7
# 239716013 239763136
# data [] 5087 7
# 239763137 239810259
# data [] 5088 7
# 239810260 239857382
# data [] 5089 7
# 239857383 239904505
# data [] 5090 7
# 239904506 239951629
# data [] 5091 7
# 239951630 239998752
# data [] 5092 7
# 239998753 240045875
# data [] 5093 7
# 240045876 240092998
# data [] 5094 7
# 240092999 240140122
# data [] 5095 7
# 240140123 240187245
# data [] 5096 7
# 240187246 240234368
# data [] 5097 7
# 240234369 240281491
# data [] 5098 7
# 240281492 240328615
# data [] 5099 7
# 240328616 240375738
# data [] 5100 7
# 240375739 240422861
# data [] 5101 7
# 240422862 240469984
# data [] 5102 7
# 240469985 240517108
# data [] 5103 7
# 240517109 240564231
# data [] 5104 7
# 240564232 240611354
# data [] 5105 7
# 240611355 240658477
# data [] 5106 7
# 240658478 240705601
# data [] 5107 7
# 240705602 240752724
# data [] 5108 7
# 240752725 240799847
# data [] 5109 7
# 240799848 240846970
# data [] 5110 7
# 240846971 240894094
# data [] 5111 7
# 240894095 240941217
# data [] 5112 7
# 240941218 240988340
# data [] 5113 7
# 240988341 241035463
# data [] 5114 7
# 241035464 241082587
# data [] 5115 7
# 241082588 241129710
# data [] 5116 7
# 241129711 241176833
# data [] 5117 7
# 241176834 241223957
# data [] 5118 7
# 241223958 241271080
# data [] 5119 7
# 241271081 241318203
# data [] 5120 7
# 241318204 241365326
# data [] 5121 7
# 241365327 241412450
# data [] 5122 7
# 241412451 241459573
# data [] 5123 7
# 241459574 241506696
# data [] 5124 7
# 241506697 241553819
# data [] 5125 7
# 241553820 241600943
# data [] 5126 7
# 241600944 241648066
# data [] 5127 7
# 241648067 241695189
# data [] 5128 7
# 241695190 241742312
# data [] 5129 7
# 241742313 241789436
# data [] 5130 7
# 241789437 241836559
# data [] 5131 7
# 241836560 241883682
# data [] 5132 7
# 241883683 241930805
# data [] 5133 7
# 241930806 241977929
# data [] 5134 7
# 241977930 242025052
# data [] 5135 7
# 242025053 242072175
# data [] 5136 7
# 242072176 242119298
# data [] 5137 7
# 242119299 242166422
# data [] 5138 7
# 242166423 242213545
# data [] 5139 7
# 242213546 242260668
# data [] 5140 7
# 242260669 242307791
# data [] 5141 7
# 242307792 242354915
# data [] 5142 7
# 242354916 242402038
# data [] 5143 7
# 242402039 242449161
# data [] 5144 7
# 242449162 242496284
# data [] 5145 7
# 242496285 242543408
# data [] 5146 7
# 242543409 242590531
# data [] 5147 7
# 242590532 242637654
# data [] 5148 7
# 242637655 242684778
# data [] 5149 7
# 242684779 242731901
# data [] 5150 7
# 242731902 242779024
# data [] 5151 7
# 242779025 242826147
# data [] 5152 7
# 242826148 242873271
# data [] 5153 7
# 242873272 242920394
# data [] 5154 7
# 242920395 242967517
# data [] 5155 7
# 242967518 243014640
# data [] 5156 7
# 243014641 243061764
# data [] 5157 7
# 243061765 243108887
# data [] 5158 7
# 243108888 243156010
# data [] 5159 7
# 243156011 243203133
# data [] 5160 7
# 243203134 243250257
# data [] 5161 7
# 243250258 243297380
# data [] 5162 7
# 243297381 243344503
# data [] 5163 7
# 243344504 243391626
# data [] 5164 7
# 243391627 243438750
# data [] 5165 7
# 243438751 243485873
# data [] 5166 7
# 243485874 243532996
# data [] 5167 7
# 243532997 243580119
# data [] 5168 7
# 243580120 243627243
# data [] 5169 7
# 243627244 243674366
# data [] 5170 7
# 243674367 243721489
# data [] 5171 7
# 243721490 243768612
# data [] 5172 7
# 243768613 243815736
# data [] 5173 7
# 243815737 243862859
# data [] 5174 7
# 243862860 243909982
# data [] 5175 7
# 243909983 243957105
# data [] 5176 7
# 243957106 244004229
# data [] 5177 7
# 244004230 244051352
# data [] 5178 7
# 244051353 244098475
# data [] 5179 7
# 244098476 244145598
# data [] 5180 7
# 244145599 244192722
# data [] 5181 7
# 244192723 244239845
# data [] 5182 7
# 244239846 244286968
# data [] 5183 7
# 244286969 244334092
# data [] 5184 7
# 244334093 244381215
# data [] 5185 7
# 244381216 244428338
# data [] 5186 7
# 244428339 244475461
# data [] 5187 7
# 244475462 244522585
# data [] 5188 7
# 244522586 244569708
# data [] 5189 7
# 244569709 244616831
# data [] 5190 7
# 244616832 244663954
# data [] 5191 7
# 244663955 244711078
# data [] 5192 7
# 244711079 244758201
# data [] 5193 7
# 244758202 244805324
# data [] 5194 7
# 244805325 244852447
# data [] 5195 7
# 244852448 244899571
# data [] 5196 7
# 244899572 244946694
# data [] 5197 7
# 244946695 244993817
# data [] 5198 7
# 244993818 245040940
# data [] 5199 7
# 245040941 245088064
# data [] 5200 7
# 245088065 245135187
# data [] 5201 7
# 245135188 245182310
# data [] 5202 7
# 245182311 245229433
# data [] 5203 7
# 245229434 245276557
# data [] 5204 7
# 245276558 245323680
# data [] 5205 7
# 245323681 245370803
# data [] 5206 7
# 245370804 245417926
# data [] 5207 7
# 245417927 245465050
# data [] 5208 7
# 245465051 245512173
# data [] 5209 7
# 245512174 245559296
# data [] 5210 7
# 245559297 245606419
# data [] 5211 7
# 245606420 245653543
# data [] 5212 7
# 245653544 245700666
# data [] 5213 7
# 245700667 245747789
# data [] 5214 7
# 245747790 245794913
# data [] 5215 7
# 245794914 245842036
# data [] 5216 7
# 245842037 245889159
# data [] 5217 7
# 245889160 245936282
# data [] 5218 7
# 245936283 245983406
# data [] 5219 7
# 245983407 246030529
# data [] 5220 7
# 246030530 246077652
# data [] 5221 7
# 246077653 246124775
# data [] 5222 7
# 246124776 246171899
# data [] 5223 7
# 246171900 246219022
# data [] 5224 7
# 246219023 246266145
# data [] 5225 7
# 246266146 246313268
# data [] 5226 7
# 246313269 246360392
# data [] 5227 7
# 246360393 246407515
# data [] 5228 7
# 246407516 246454638
# data [] 5229 7
# 246454639 246501761
# data [] 5230 7
# 246501762 246548885
# data [] 5231 7
# 246548886 246596008
# data [] 5232 7
# 246596009 246643131
# data [] 5233 7
# 246643132 246690254
# data [] 5234 7
# 246690255 246737378
# data [] 5235 7
# 246737379 246784501
# data [] 5236 7
# 246784502 246831624
# data [] 5237 7
# 246831625 246878747
# data [] 5238 7
# 246878748 246925871
# data [] 5239 7
# 246925872 246972994
# data [] 5240 7
# 246972995 247020117
# data [] 5241 7
# 247020118 247067240
# data [] 5242 7
# 247067241 247114364
# data [] 5243 7
# 247114365 247161487
# data [] 5244 7
# 247161488 247208610
# data [] 5245 7
# 247208611 247255734
# data [] 5246 7
# 247255735 247302857
# data [] 5247 7
# 247302858 247349980
# data [] 5248 7
# 247349981 247397103
# data [] 5249 7
# 247397104 247444227
# data [] 5250 7
# 247444228 247491350
# data [] 5251 7
# 247491351 247538473
# data [] 5252 7
# 247538474 247585596
# data [] 5253 7
# 247585597 247632720
# data [] 5254 7
# 247632721 247679843
# data [] 5255 7
# 247679844 247726966
# data [] 5256 7
# 247726967 247774089
# data [] 5257 7
# 247774090 247821213
# data [] 5258 7
# 247821214 247868336
# data [] 5259 7
# 247868337 247915459
# data [] 5260 7
# 247915460 247962582
# data [] 5261 7
# 247962583 248009706
# data [] 5262 7
# 248009707 248056829
# data [] 5263 7
# 248056830 248103952
# data [] 5264 7
# 248103953 248151075
# data [] 5265 7
# 248151076 248198199
# data [] 5266 7
# 248198200 248245322
# data [] 5267 7
# 248245323 248292445
# data [] 5268 7
# 248292446 248339568
# data [] 5269 7
# 248339569 248386692
# data [] 5270 7
# 248386693 248433815
# data [] 5271 7
# 248433816 248480938
# data [] 5272 7
# 248480939 248528061
# data [] 5273 7
# 248528062 248575185
# data [] 5274 7
# 248575186 248622308
# data [] 5275 7
# 248622309 248669431
# data [] 5276 7
# 248669432 248716555
# data [] 5277 7
# 248716556 248763678
# data [] 5278 7
# 248763679 248810801
# data [] 5279 7
# 248810802 248857924
# data [] 5280 7
# 248857925 248905048
# data [] 5281 7
# 248905049 248952171
# data [] 5282 7

# %%
agg[1][0:20]
# Out:
# array([ 3,  7,  5, 17,  6,  7, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17, 17,
#        17, 17, 17], dtype=int8)

# %%
def aggregate_parallel(params):
    start_time = time.time()
    aggregate_range(**params)
    print(params['chromosome'], params['order'], params['hstart'], "done in: %s" % (time.time() - start_time))

# %%
def aggregate_chromosome(chromosome, order, chunk_size=4**11, dtype="int8"):
    
    samples = categorical_data[chromosome]
    nsamples = len(samples)
    print("samples", nsamples)
    
    gstart = genome.sizes_acc[chromosome]
    gstop = genome.sizes_acc[chromosome] + genome.sizes[chromosome]
    hbstart = get_hilbert_from_genome(gstart)
    hbstop = get_hilbert_from_genome(gstop)
    
    hstart = hilbert_pos_to_order(hbstart, 16, order)
    hstop = hilbert_pos_to_order(hbstop, 16, order)
    hlen = hstop - hstart
    
    print("chromosome", chromosome, "order", order)
    print("genome", gstart, gstop)
    print("hilbert", hstart, hstop)
    print("length", hlen)

    # if there are more hilbert indices than samples we dont need to aggregate
    # really it should be sample resolution vs hilbert genome resolution...
    # individual = (hlen) / nsamples > 1
    individual = hilbert_genome_resolutions[order] < signal_resolution
    print("individual", individual)
    
    params = []
    if hlen > chunk_size:
        # break up our hlen into chunks
        nchunks = math.ceil(hlen/chunk_size)
        print("chunks", nchunks)
        for i in range(0, nchunks):
            cstart = hstart + chunk_size * i
            cstop = cstart + chunk_size
            if cstop > hstop:
                cstop = hstop
            params.append({
                'chromosome': chromosome,
                'order': order,
                'hstart': cstart,
                'hstop': cstop,
                'gstart': gstart, # this stays the same
                'individual': individual,
                'dtype': dtype
            })
            
    else:
        # TODO: chunk up the hilbert and run the aggregate_range in parallel
        params.append({
            'chromosome': chromosome,
            'order': order,
            'hstart': hstart,
            'hstop': hstop,
            'gstart': gstart,
            'individual': individual,
            'dtype': dtype
        })
    return params
    #return aggregate_range(chromosome, order, hstart, hstop, gstart, individual, dtype)
    # the parallel version can write files to disk
    # then when its done combine them

# %%
def aggregate_filename(chromosome, order, hstart, dtype):
    return os.path.join(bytes_data_dir, chromosome + "_" + str(order) + "_" + str(hstart) + "." + dtype)

# %% [markdown]
# ## Generate byte files

# %%
# def write_bytes(chromosome, order):
#     agg = aggregate_chromosome(chromosome, order)
#     bfn = os.path.join(bytes_data_dir, chromosome + "_" + str(order) + ".int8")
#     with open(bfn, 'wb') as f:
#         f.write(agg[1].tobytes())

# %%
# write_bytes("chr1", 13)

# %%
def files_for_order(order):
    files = []
    for c in genome.chromosomes:
        files += aggregate_chromosome(c, order)
    return files

# %%
files = files_for_order(12)
# Out:
# samples 1246254
# chromosome chr1 order 12
# genome 0 248956422
# hilbert 0 1352471
# length 1352471
# individual True
# samples 1215997
# chromosome chr2 order 12
# genome 248956422 491149951
# hilbert 1352471 2668202
# length 1315731
# individual True
# samples 990113
# chromosome chr3 order 12
# genome 491149951 689445510
# hilbert 2668202 3745455
# length 1077253
# individual True
# samples 955772
# chromosome chr4 order 12
# genome 689445510 879660065
# hilbert 3745455 4778807
# length 1033352
# individual True
# samples 904577
# chromosome chr5 order 12
# genome 879660065 1061198324
# hilbert 4778807 5765025
# length 986218
# individual True
# samples 855576
# chromosome chr6 order 12
# genome 1061198324 1232004303
# hilbert 5765025 6692939
# length 927914
# individual True
# samples 795694
# chromosome chr7 order 12
# genome 1232004303 1391350276
# hilbert 6692939 7558596
# length 865657
# individual True
# samples 731821
# chromosome chr8 order 12
# genome 1391350276 1536488912
# hilbert 7558596 8347070
# length 788474
# individual True
# samples 706068
# chromosome chr9 order 12
# genome 1536488912 1674883629
# hilbert 8347070 9098908
# length 751838
# individual True
# samples 677674
# chromosome chr10 order 12
# genome 1674883629 1808681051
# hilbert 9098908 9825771
# length 726863
# individual True
# samples 675033
# chromosome chr11 order 12
# genome 1808681051 1943767673
# hilbert 9825771 10559637
# length 733866
# individual True
# samples 669260
# chromosome chr12 order 12
# genome 1943767673 2077042982
# hilbert 10559637 11283663
# length 724026
# individual True
# samples 575850
# chromosome chr13 order 12
# genome 2077042982 2191407310
# hilbert 11283663 11904955
# length 621292
# individual True
# samples 536748
# chromosome chr14 order 12
# genome 2191407310 2298451028
# hilbert 11904955 12486476
# length 581521
# individual True
# samples 512657
# chromosome chr15 order 12
# genome 2298451028 2400442217
# hilbert 12486476 13040550
# length 554074
# individual True
# samples 451774
# chromosome chr16 order 12
# genome 2400442217 2490780562
# hilbert 13040550 13531318
# length 490768
# individual True
# samples 405977
# chromosome chr17 order 12
# genome 2490780562 2574038003
# hilbert 13531318 13983619
# length 452301
# individual True
# samples 390387
# chromosome chr18 order 12
# genome 2574038003 2654411288
# hilbert 13983619 14420252
# length 436633
# individual True
# samples 295645
# chromosome chr19 order 12
# genome 2654411288 2713028904
# hilbert 14420252 14738696
# length 318444
# individual True
# samples 315128
# chromosome chr20 order 12
# genome 2713028904 2777473071
# hilbert 14738696 15088793
# length 350097
# individual True
# samples 240650
# chromosome chr21 order 12
# genome 2777473071 2824183054
# hilbert 15088793 15342548
# length 253755
# individual True
# samples 256523
# chromosome chr22 order 12
# genome 2824183054 2875001522
# hilbert 15342548 15618622
# length 276074
# individual True
# samples 776353
# chromosome chrX order 12
# genome 2875001522 3031042417
# hilbert 15618622 16466324
# length 847702
# individual True
# samples 296868
# chromosome chrY order 12
# genome 3031042417 3088269832
# hilbert 16466324 16777216
# length 310892
# individual True

# %%
files
# Out:
# [{'chromosome': 'chr1',
#   'order': 12,
#   'hstart': 0,
#   'hstop': 1352471,
#   'gstart': 0,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr2',
#   'order': 12,
#   'hstart': 1352471,
#   'hstop': 2668202,
#   'gstart': 248956422,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr3',
#   'order': 12,
#   'hstart': 2668202,
#   'hstop': 3745455,
#   'gstart': 491149951,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr4',
#   'order': 12,
#   'hstart': 3745455,
#   'hstop': 4778807,
#   'gstart': 689445510,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr5',
#   'order': 12,
#   'hstart': 4778807,
#   'hstop': 5765025,
#   'gstart': 879660065,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr6',
#   'order': 12,
#   'hstart': 5765025,
#   'hstop': 6692939,
#   'gstart': 1061198324,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr7',
#   'order': 12,
#   'hstart': 6692939,
#   'hstop': 7558596,
#   'gstart': 1232004303,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr8',
#   'order': 12,
#   'hstart': 7558596,
#   'hstop': 8347070,
#   'gstart': 1391350276,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr9',
#   'order': 12,
#   'hstart': 8347070,
#   'hstop': 9098908,
#   'gstart': 1536488912,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr10',
#   'order': 12,
#   'hstart': 9098908,
#   'hstop': 9825771,
#   'gstart': 1674883629,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr11',
#   'order': 12,
#   'hstart': 9825771,
#   'hstop': 10559637,
#   'gstart': 1808681051,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr12',
#   'order': 12,
#   'hstart': 10559637,
#   'hstop': 11283663,
#   'gstart': 1943767673,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr13',
#   'order': 12,
#   'hstart': 11283663,
#   'hstop': 11904955,
#   'gstart': 2077042982,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr14',
#   'order': 12,
#   'hstart': 11904955,
#   'hstop': 12486476,
#   'gstart': 2191407310,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr15',
#   'order': 12,
#   'hstart': 12486476,
#   'hstop': 13040550,
#   'gstart': 2298451028,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr16',
#   'order': 12,
#   'hstart': 13040550,
#   'hstop': 13531318,
#   'gstart': 2400442217,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr17',
#   'order': 12,
#   'hstart': 13531318,
#   'hstop': 13983619,
#   'gstart': 2490780562,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr18',
#   'order': 12,
#   'hstart': 13983619,
#   'hstop': 14420252,
#   'gstart': 2574038003,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr19',
#   'order': 12,
#   'hstart': 14420252,
#   'hstop': 14738696,
#   'gstart': 2654411288,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr20',
#   'order': 12,
#   'hstart': 14738696,
#   'hstop': 15088793,
#   'gstart': 2713028904,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr21',
#   'order': 12,
#   'hstart': 15088793,
#   'hstop': 15342548,
#   'gstart': 2777473071,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chr22',
#   'order': 12,
#   'hstart': 15342548,
#   'hstop': 15618622,
#   'gstart': 2824183054,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chrX',
#   'order': 12,
#   'hstart': 15618622,
#   'hstop': 16466324,
#   'gstart': 2875001522,
#   'individual': True,
#   'dtype': 'int8'},
#  {'chromosome': 'chrY',
#   'order': 12,
#   'hstart': 16466324,
#   'hstop': 16777216,
#   'gstart': 3031042417,
#   'individual': True,
#   'dtype': 'int8'}]

# %%
len(files)
# Out:
# 24

# %%
s = 0
for f in files:
    s += f['hstop'] - f['hstart']
print(s)
# Out:
# 67108864

# %%
4**13
# Out:
# 67108864

# %%
files[0]
# Out:
# {'chromosome': 'chr1',
#  'order': 7,
#  'hstart': 0,
#  'hstop': 1320,
#  'gstart': 0,
#  'individual': False,
#  'dtype': 'int8'}

# %%
# aggregate_parallel(files[0])
# Out:
# chr1 7 0 1320 0 False int8
# len v 1320
# samples 1246254
# chr1 7 0 done in: 0.12947702407836914

# %%
# import multiprocessing as mp
import multiprocess as mp

# %%
def generate_order(order):
    start_time = time.time()
    files = files_for_order(order)
    workers = mp.cpu_count() - 1
    with mp.Pool(workers) as p:
        p.map(aggregate_parallel, files)
    print(len(files), "done in: %s" % (time.time() - start_time))
    print("combining files")
    combine_bytes_files(files, order)
    #return files

# %%
def combine_bytes_files(files, order):
    paths = [aggregate_filename(f['chromosome'], f['order'], f['hstart'], f['dtype']) for f in files]
    print(paths)
    out = os.path.join(bytes_data_dir,"order_" + str(order) + "." + files[0]['dtype'])
    with open(out, "wb") as of:
        for p in paths:
            with open(p, "rb") as rf:
                of.write(rf.read())

# %%
generate_order(12)
# Out:
# samples 1246254
# chromosome chr1 order 12
# genome 0 248956422
# hilbert 0 1352471
# length 1352471
# individual True
# samples 1215997
# chromosome chr2 order 12
# genome 248956422 491149951
# hilbert 1352471 2668202
# length 1315731
# individual True
# samples 990113
# chromosome chr3 order 12
# genome 491149951 689445510
# hilbert 2668202 3745455
# length 1077253
# individual True
# samples 955772
# chromosome chr4 order 12
# genome 689445510 879660065
# hilbert 3745455 4778807
# length 1033352
# individual True
# samples 904577
# chromosome chr5 order 12
# genome 879660065 1061198324
# hilbert 4778807 5765025
# length 986218
# individual True
# samples 855576
# chromosome chr6 order 12
# genome 1061198324 1232004303
# hilbert 5765025 6692939
# length 927914
# individual True
# samples 795694
# chromosome chr7 order 12
# genome 1232004303 1391350276
# hilbert 6692939 7558596
# length 865657
# individual True
# samples 731821
# chromosome chr8 order 12
# genome 1391350276 1536488912
# hilbert 7558596 8347070
# length 788474
# individual True
# samples 706068
# chromosome chr9 order 12
# genome 1536488912 1674883629
# hilbert 8347070 9098908
# length 751838
# individual True
# samples 677674
# chromosome chr10 order 12
# genome 1674883629 1808681051
# hilbert 9098908 9825771
# length 726863
# individual True
# samples 675033
# chromosome chr11 order 12
# genome 1808681051 1943767673
# hilbert 9825771 10559637
# length 733866
# individual True
# samples 669260
# chromosome chr12 order 12
# genome 1943767673 2077042982
# hilbert 10559637 11283663
# length 724026
# individual True
# samples 575850
# chromosome chr13 order 12
# genome 2077042982 2191407310
# hilbert 11283663 11904955
# length 621292
# individual True
# samples 536748
# chromosome chr14 order 12
# genome 2191407310 2298451028
# hilbert 11904955 12486476
# length 581521
# individual True
# samples 512657
# chromosome chr15 order 12
# genome 2298451028 2400442217
# hilbert 12486476 13040550
# length 554074
# individual True
# samples 451774
# chromosome chr16 order 12
# genome 2400442217 2490780562
# hilbert 13040550 13531318
# length 490768
# individual True
# samples 405977
# chromosome chr17 order 12
# genome 2490780562 2574038003
# hilbert 13531318 13983619
# length 452301
# individual True
# samples 390387
# chromosome chr18 order 12
# genome 2574038003 2654411288
# hilbert 13983619 14420252
# length 436633
# individual True
# samples 295645
# chromosome chr19 order 12
# genome 2654411288 2713028904
# hilbert 14420252 14738696
# length 318444
# individual True
# samples 315128
# chromosome chr20 order 12
# genome 2713028904 2777473071
# hilbert 14738696 15088793
# length 350097
# individual True
# samples 240650
# chromosome chr21 order 12
# genome 2777473071 2824183054
# hilbert 15088793 15342548
# length 253755
# individual True
# samples 256523
# chromosome chr22 order 12
# genome 2824183054 2875001522
# hilbert 15342548 15618622
# length 276074
# individual True
# samples 776353
# chromosome chrX order 12
# genome 2875001522 3031042417
# hilbert 15618622 16466324
# length 847702
# individual True
# samples 296868
# chromosome chrY order 12
# genome 3031042417 3088269832
# hilbert 16466324 16777216
# length 310892
# individual True
# chr3chr1chr4chr2chr6chr5chr8chr7chr9         12121212121212 1212      1352471  374545502668202477880757650257558596 83470706692939      2668202  4778807374545513524715765025669293983470707558596 9098908       248956422 6894455104911499510879660065106119832413913502761232004303 1536488912       True TrueTrueTrueTrueTrueTrueTrue True       int8 int8int8int8int8int8int8int8
# int8
#
#
#
#
#
#
#
# len vlen vlen vlen vlen vlen v      986218len v927914103335213157311077253len vlen v1352471
#
#
#
#
#
# samples751838samplessamples788474samplessamplessamples865657
#
#
#  855576samplessamples9045779557721215997990113samples1246254
#
#
#
#
#
# 706068731821795694
#
#
# chr9 12 8347070 done in: 2.8573219776153564
# chr10 12 9098908 9825771 1674883629 True int8
# len v 726863
# samples 677674
# chr8 12 7558596 done in: 3.043879985809326
# chr11 12 9825771 10559637 1808681051 True int8
# len v 733866
# samples 675033
# chr7 12 6692939 done in: 3.3493809700012207
# chr12 12 10559637 11283663 1943767673 True int8
# len v 724026
# samples 669260
# chr6 12 5765025 done in: 3.731260061264038
# chr13 12 11283663 11904955 2077042982 Truechr5  int812
# len v  4778807621292
# done in: 3.8223087787628174samples
#  chr14575850
# 12 11904955 12486476 2191407310 True int8
# len v 581521
# samples 536748
# chr4 12 3745455 done in: 4.017636775970459
# chr15 12 12486476 13040550 2298451028 True int8
# len v 554074
# samples 512657
# chr3 12 2668202 done in: 4.194778919219971
# chr16 12 13040550 13531318 2400442217 True int8
# len v 490768
# samples 451774
# chr2 12 1352471 done in: 5.135021209716797
# chr17 12 13531318 13983619 2490780562 True int8
# len v 452301
# samples 405977
# chr1 12 0 done in: 5.338062047958374
# chr18 12 13983619 14420252 2574038003 True int8
# len v 436633
# samples 390387
# chr10 12 9098908 done in: 3.1862542629241943
# chr19 12 14420252 14738696 2654411288 True int8
# len v 318444
# samples 295645
# chr11 12 9825771 done in: 3.127547025680542
# chr20 12 14738696 15088793 2713028904 True int8
# len v 350097
# samples 315128
# chr14chr16  1212  1190495513040550  done in: 2.5139901638031006done in: 2.1406989097595215
#
# chr21chr22 chr15 1212   1215342548 1508879312486476  15618622 15342548done in: 2.3613078594207764
#  2777473071chrX2824183054  True  12Trueint8  int8
# 15618622
# len v16466324len v   2875001522253755 276074True int8
#
# len v
#  847702
# samples samplessamples776353
#   240650256523
#
# chr13 12 11283663 done in: 2.763676881790161
# chrY 12 16466324 16777216 3031042417 True int8
# len v 310892
# samples 296868
# chr12 12 10559637 done in: 3.2105839252471924
# chr17 12 13531318 done in: 1.8944120407104492
# chr18 12 13983619 done in: 1.817568063735962
# chr21 12 15088793 done in: 0.9849629402160645
# chr19 12 14420252 done in: 1.2578239440917969
# chr22 12 15342548 done in: 1.0638010501861572
# chr20 12 14738696 done in: 1.315892219543457
# chrY 12 16466324 done in: 1.075326919555664
# chrX 12 15618622 done in: 2.6736340522766113
# 24 done in: 9.33641004562378
# combining files
# ['hilbert_genome_cooler_data/bytes_data/chr1_12_0.int8', 'hilbert_genome_cooler_data/bytes_data/chr2_12_1352471.int8', 'hilbert_genome_cooler_data/bytes_data/chr3_12_2668202.int8', 'hilbert_genome_cooler_data/bytes_data/chr4_12_3745455.int8', 'hilbert_genome_cooler_data/bytes_data/chr5_12_4778807.int8', 'hilbert_genome_cooler_data/bytes_data/chr6_12_5765025.int8', 'hilbert_genome_cooler_data/bytes_data/chr7_12_6692939.int8', 'hilbert_genome_cooler_data/bytes_data/chr8_12_7558596.int8', 'hilbert_genome_cooler_data/bytes_data/chr9_12_8347070.int8', 'hilbert_genome_cooler_data/bytes_data/chr10_12_9098908.int8', 'hilbert_genome_cooler_data/bytes_data/chr11_12_9825771.int8', 'hilbert_genome_cooler_data/bytes_data/chr12_12_10559637.int8', 'hilbert_genome_cooler_data/bytes_data/chr13_12_11283663.int8', 'hilbert_genome_cooler_data/bytes_data/chr14_12_11904955.int8', 'hilbert_genome_cooler_data/bytes_data/chr15_12_12486476.int8', 'hilbert_genome_cooler_data/bytes_data/chr16_12_13040550.int8', 'hilbert_genome_cooler_data/bytes_data/chr17_12_13531318.int8', 'hilbert_genome_cooler_data/bytes_data/chr18_12_13983619.int8', 'hilbert_genome_cooler_data/bytes_data/chr19_12_14420252.int8', 'hilbert_genome_cooler_data/bytes_data/chr20_12_14738696.int8', 'hilbert_genome_cooler_data/bytes_data/chr21_12_15088793.int8', 'hilbert_genome_cooler_data/bytes_data/chr22_12_15342548.int8', 'hilbert_genome_cooler_data/bytes_data/chrX_12_15618622.int8', 'hilbert_genome_cooler_data/bytes_data/chrY_12_16466324.int8']

# %%
# order 15 took 400 seconds w/ 9 workers on mbp m1 pro
# order 16 took 2000 seconds (1034 files)
